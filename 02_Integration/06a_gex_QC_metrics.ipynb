# %%
suppressPackageStartupMessages({
    library(Seurat)
    library(dplyr)
    library(here)
    library(tibble)
    library(dittoSeq)
    library(stringr)
    library(data.table)
    library(tidyverse)
    library(patchwork) 
    library(RColorBrewer) 
    library(ggplot2)
    library(dplyr)
    library(magrittr)
    library(patchwork)
    library(Seurat)
    library(scCustomize)
    library(reticulate)
    options(stringsAsFactors = FALSE)
    set.seed(123)
})

# %%
dmg <- readRDS('/projects/0/einf2548/cruiz/dmg/data/rna_dmg_atlas_scglue_embbeding.rds')
dmg
# Out:
# An object of class Seurat
# 19248 features across 397794 samples within 1 assay
# Active assay: RNA (19248 features, 2000 variable features)
#  3 layers present: counts, data, scale.data
#  2 dimensional reductions calculated: pca, umap

# %%
options(repr.plot.height = 4, repr.plot.width = 15)
QC_Plots_UMIs(seurat_object = dmg, group.by = 'ID',
              # low_cutoff = 1200, high_cutoff = 45000, 
              pt.size = 0,
              y_axis_log = TRUE, 
             raster=TRUE)
# Out:
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# plot without title

# %%
ggsave('figures/QC_Plots_UMIs_dmg_atlas.pdf', height = 3, width = 15)

# %%
QC_Plots_Genes(seurat_object = dmg,group.by = 'ID',
              pt.size = 0,
               low_cutoff = 0,
              y_axis_log = TRUE, 
             raster=TRUE)
# Out:
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# plot without title

# %%
ggsave('figures/QC_Plots_Genes_dmg_atlas.pdf', height = 3, width = 15)
# Out:
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”

# %%
QC_Plots_Mito(seurat_object = dmg, 
              group.by = 'ID',
             pt.size = 0,
               low_cutoff = 0,
             raster=TRUE)
# Out:
# plot without title

# %%
ggsave('figures/QC_Plots_Mito_dmg_atlas.pdf', height = 3, width = 15)

# %%
 QC_Plots_Complexity(seurat_object = dmg, high_cutoff = 0.8,
                    group.by = 'ID',
                     pt.size = 0,
                     raster=TRUE)
# Out:
# plot without title

# %%
ggsave('figures/QC_Plots_Complexity_dmg_atlas.pdf', height = 3, width = 15)
