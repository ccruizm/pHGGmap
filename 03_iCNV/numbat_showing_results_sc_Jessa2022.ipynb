# %%
library(numbat)
library(dplyr)
library(Seurat)
library(data.table)
library(ggplot2)
library(dplyr)
library(glue)
library(ggtree)
library(stringr)
library(tidygraph)
library(patchwork)
library(gridExtra)
library(grid)
library(future)
plan("multicore", workers = 12)
options(future.globals.maxSize = 10000 * 1024^10,
        future.rng.onMisuse = 'ignore')
sessionInfo()
# Out:
# Loading required package: Matrix
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: SeuratObject
#
# Loading required package: sp
#
#
# Attaching package: ‘SeuratObject’
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, saveRDS
#
#
# Loading Seurat v5 beta version
# To maintain compatibility with previous workflows, new Seurat objects will use the previous object structure by default
# To use new Seurat v5 assays: Please run: options(Seurat.object.assay.version = 'v5')
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# ggtree v3.6.2 For help: https://yulab-smu.top/treedata-book/
#
# If you use the ggtree package suite in published research, please cite
# the appropriate paper(s):
#
# Guangchuang Yu, David Smith, Huachen Zhu, Yi Guan, Tommy Tsan-Yuk Lam.
# ggtree: an R package for visualization and annotation of phylogenetic
# trees with their covariates and other associated data. Methods in
# Ecology and Evolution. 2017, 8(1):28-36. doi:10.1111/2041-210X.12628
#
# G Yu. Data Integration, Manipulation and Visualization of Phylogenetic
# Trees (1st ed.). Chapman and Hall/CRC. 2022. ISBN: 9781032233574
#
# Guangchuang Yu, Tommy Tsan-Yuk Lam, Huachen Zhu, Yi Guan. Two methods
# for mapping and visualizing associated data on phylogeny using ggtree.
# Molecular Biology and Evolution. 2018, 35(12):3041-3043.
# doi:10.1093/molbev/msy194
#
#
# Attaching package: ‘ggtree’
#
#
# The following object is masked from ‘package:Matrix’:
#
#     expand
#
#
#
# Attaching package: ‘tidygraph’
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
#
# Attaching package: ‘gridExtra’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
# R version 4.2.3 (2023-03-15)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Rocky Linux 8.7 (Green Obsidian)
#
# Matrix products: default
# BLAS/LAPACK: /gpfs/home3/cruiz2/miniconda3/envs/r_python/lib/libopenblasp-r0.3.21.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] grid      stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
#  [1] future_1.32.0           gridExtra_2.3           patchwork_1.1.2
#  [4] tidygraph_1.2.3         stringr_1.5.0           ggtree_3.6.2
#  [7] glue_1.6.2              ggplot2_3.4.1           data.table_1.14.8
# [10] Seurat_4.9.9.9040       SeuratObject_4.9.9.9081 sp_1.6-0
# [13] dplyr_1.1.1             numbat_1.2.3            Matrix_1.5-3
#
# loaded via a namespace (and not attached):
#   [1] uuid_1.1-0             spam_2.9-1             parallelDist_0.2.6
#   [4] fastmatch_1.1-3        plyr_1.8.8             igraph_1.4.1
#   [7] repr_1.1.6             lazyeval_0.2.2         splines_4.2.3
#  [10] RcppHNSW_0.4.1         listenv_0.9.0          scattermore_0.8
#  [13] digest_0.6.31          yulab.utils_0.0.6      htmltools_0.5.5
#  [16] viridis_0.6.2          fansi_1.0.4            magrittr_2.0.3
#  [19] tensor_1.5             cluster_2.1.4          ROCR_1.0-11
#  [22] globals_0.16.2         graphlayouts_0.8.4     RcppParallel_5.1.7
#  [25] matrixStats_0.63.0     spatstat.sparse_3.0-1  colorspace_2.1-0
#  [28] ggrepel_0.9.3          crayon_1.5.2           jsonlite_1.8.4
#  [31] progressr_0.13.0       spatstat.data_3.0-1    survival_3.5-5
#  [34] zoo_1.8-11             phangorn_2.11.1        ape_5.7-1
#  [37] polyclip_1.10-4        gtable_0.3.3           leiden_0.4.3
#  [40] future.apply_1.10.0    abind_1.4-5            scales_1.2.1
#  [43] spatstat.random_3.1-4  miniUI_0.1.1.1         Rcpp_1.0.10
#  [46] viridisLite_0.4.1      xtable_1.8-4           gridGraphics_0.5-1
#  [49] tidytree_0.4.2         reticulate_1.28        dotCall64_1.0-2
#  [52] htmlwidgets_1.6.2      httr_1.4.5             RColorBrewer_1.1-3
#  [55] ellipsis_0.3.2         ica_1.0-3              pkgconfig_2.0.3
#  [58] farver_2.1.1           uwot_0.1.14            deldir_1.0-6
#  [61] utf8_1.2.3             ggplotify_0.1.0        tidyselect_1.2.0
#  [64] rlang_1.1.0            reshape2_1.4.4         later_1.3.0
#  [67] munsell_0.5.0          tools_4.2.3            cli_3.6.1
#  [70] generics_0.1.3         ggridges_0.5.4         evaluate_0.20
#  [73] fastmap_1.1.1          goftest_1.2-3          RhpcBLASctl_0.23-42
#  [76] fitdistrplus_1.1-8     purrr_1.0.1            RANN_2.6.1
#  [79] ggraph_2.1.0           pbapply_1.7-0          nlme_3.1-162
#  [82] mime_0.12              aplot_0.1.10           compiler_4.2.3
#  [85] plotly_4.10.1          png_0.1-8              spatstat.utils_3.0-2
#  [88] treeio_1.22.0          tibble_3.2.1           tweenr_2.0.2
#  [91] stringi_1.7.12         RSpectra_0.16-1        logger_0.2.2
#  [94] lattice_0.20-45        IRdisplay_1.1          vctrs_0.6.1
#  [97] pillar_1.9.0           lifecycle_1.0.3        spatstat.geom_3.1-0
# [100] lmtest_0.9-40          RcppAnnoy_0.0.20       cowplot_1.1.1
# [103] irlba_2.3.5.1          httpuv_1.6.9           R6_2.5.1
# [106] scistreer_1.1.0        promises_1.2.0.1       KernSmooth_2.23-20
# [109] parallelly_1.35.0      codetools_0.2-19       fastDummies_1.6.3
# [112] MASS_7.3-58.3          withr_2.5.0            sctransform_0.3.5
# [115] parallel_4.2.3         quadprog_1.5-8         ggfun_0.0.9
# [118] IRkernel_1.3.2         tidyr_1.3.0            Rtsne_0.16
# [121] pbdZMQ_0.3-9           spatstat.explore_3.1-0 ggforce_0.4.1
# [124] shiny_1.7.4            base64enc_0.1-3

# %%
dmg <- readRDS('/projects/0/einf2548/cruiz/dmg/data/merged_dmg_atlas_qc_filtered.rds')
dmg
# Out:
# An object of class Seurat
# 38576 features across 409561 samples within 6 assays
# Active assay: RNA (19248 features, 2000 variable features)
#  3 layers present: counts, data, scale.data
#  5 other assays present: RAW, prediction.score.annotation_level_1, prediction.score.annotation_level_2, prediction.score.annotation_level_3, prediction.score.annotation_level_4
#  4 dimensional reductions calculated: pca, umap, ref.pca, ref.umap

# %%
dmg <- subset(dmg, Batch_for_correction == '10Xv3_cell_rna')
dmg
# Out:
# An object of class Seurat
# 38576 features across 57305 samples within 6 assays
# Active assay: RNA (19248 features, 2000 variable features)
#  3 layers present: counts, data, scale.data
#  5 other assays present: RAW, prediction.score.annotation_level_1, prediction.score.annotation_level_2, prediction.score.annotation_level_3, prediction.score.annotation_level_4
#  4 dimensional reductions calculated: pca, umap, ref.pca, ref.umap

# %%
gc()
# Out:
#        used      (Mb)   gc trigger (Mb)    max used   (Mb)
# Ncells   5209292  278.3    9117428   487.0    9117428   487
# Vcells 853322237 6510.4 7275309818 55506.3 7548305138 57589

# %%
dittoSeq::dittoDimPlot(dmg, 
             reduction.use = "umap", var = "predicted.annotation_level_3", 
             do.label = T, labels.size = 4, 
             do.raster = TRUE) + NoAxes()
# Out:
# plot without title

# %%
samples <- names(table(dmg$SampleID))
samples <- gsub('_RNA_only', '', samples)
samples
# Out:
# [1] "P-6117_S-8370" "P-6240_S-8628" "P-6328_S-8672" "P-6337_S-8821"
# [5] "P-6519_S-9084"

# %%
options(warn = 0)

# %%
options(repr.plot.height = 9, repr.plot.width = 10)
for(i in seq_along(samples)){

    nb = Numbat$new(out_dir = paste0('sc/', samples[i]))
    
    p0 <- nb$plot_phylo_heatmap(
          clone_bar = TRUE, 
          p_min = 0.9
        )
    
    p0.1 <- nb$plot_consensus()
  
    print(grid.arrange(
                grobTree(textGrob(samples[i], gp = gpar(fontsize = 18, fontface = "bold"))),
                grobTree(arrangeGrob(p0, p0.1)), heights = unit(c(1.5, 9), c("lines", "null"))
    ))
    
    dmg_subset <- subset(dmg, SampleID == paste0(samples[i], '_RNA_only'))
    
    print(dittoSeq::dittoDimPlot(dmg_subset, 
                   reduction.use = "umap", var = "predicted.annotation_level_3", 
                   do.label = T, labels.size = 4, main = samples[i],
                   do.raster = TRUE) + NoAxes()) 

    meta <- nb$clone_post %>% 
            select(cell, p_cnv, p_cnv_x, p_cnv_y, compartment_opt) %>%
            tibble::column_to_rownames('cell')

    dmg_subset <- AddMetaData(dmg_subset, meta)

        p1 <- dittoSeq::dittoDimPlot(dmg_subset, 
                 reduction.use = "umap", var = "p_cnv", 
                 do.raster = TRUE) + NoAxes()
          
        p2 <- dittoSeq::dittoDimPlot(dmg_subset, 
                       reduction.use = "umap", var = "p_cnv_x", 
                       do.raster = TRUE) + NoAxes()
          
        p3 <- dittoSeq::dittoDimPlot(dmg_subset, 
                       reduction.use = "umap", var = "p_cnv_y", 
                       do.raster = TRUE) + NoAxes()
          
        p4 <- dittoSeq::dittoDimPlot(dmg_subset, 
                       reduction.use = "umap", var = "compartment_opt", 
                       do.label = T, labels.size = 4, 
                       do.raster = TRUE) + NoAxes()
        
        # arrange the plots in a 2x2 grid
        print(grid.arrange(
                grobTree(textGrob(samples[i], gp = gpar(fontsize = 14, fontface = "bold"))),
                grobTree(arrangeGrob(p1, p2, p3, p4, ncol=2)), heights = unit(c(1, 9), c("lines", "null"))
        ))
    
    # Sys.sleep(20)
}
# Out:
# Warning message:
# “ggrepel: 4 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 2 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 2 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# TableGrob (2 x 1) "arrange": 2 grobs
#   z     cells    name                  grob
# 1 1 (1-1,1-1) arrange gTree[GRID.gTree.179]
# 2 2 (2-2,1-1) arrange gTree[GRID.gTree.181]
# Warning message:
# “ggrepel: 3 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 1 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# plot without title
# TableGrob (2 x 1) "arrange": 2 grobs
#   z     cells    name                   grob
# 1 1 (1-1,1-1) arrange gTree[GRID.gTree.1516]
# 2 2 (2-2,1-1) arrange gTree[GRID.gTree.1518]
# plot without title
# TableGrob (2 x 1) "arrange": 2 grobs
#   z     cells    name                   grob
# 1 1 (1-1,1-1) arrange gTree[GRID.gTree.1671]
# 2 2 (2-2,1-1) arrange gTree[GRID.gTree.1673]
# plot without title
# plot without title

# %% [markdown]
# ### Extract predictions

# %%
meta_cnv <- list()

for(i in seq_along(samples)){
    
    if (file.exists(paste0('sc/', samples[i],'/bulk_clones_final.tsv.gz')) == TRUE) {
    
    nb = Numbat$new(out_dir = paste0('sc/',samples[i]))

    meta <- nb$clone_post %>% 
            select(cell, p_cnv, p_cnv_x, p_cnv_y, compartment_opt)

    meta_cnv[[i]] <- meta
    } else {next}
}

# %%
length(meta_cnv)
# Out:
# [1] 5

# %%
iCNV <- rbindlist(meta_cnv) %>% tibble::column_to_rownames('cell')
iCNV
# Out:
#                                      p_cnv         p_cnv_x       p_cnv_y
# rna_P-6117_S-8370_AAACCTGAGATCTGCT-1  1.000000e+00  1.000000e+00 0.764149241
# rna_P-6117_S-8370_AAACCTGAGATGCCTT-1  1.000000e+00  1.000000e+00 0.860041493
# rna_P-6117_S-8370_AAACCTGAGCGCCTCA-1  9.999204e-01  9.999760e-01 0.231523000
# rna_P-6117_S-8370_AAACCTGAGGGCTCTC-1  1.000000e+00  1.000000e+00 0.007913233
# rna_P-6117_S-8370_AAACCTGCAAGTCTAC-1  1.000000e+00  1.000000e+00 0.599306553
# rna_P-6117_S-8370_AAACCTGCAATCAGAA-1  1.000000e+00  1.000000e+00 0.974320985
# rna_P-6117_S-8370_AAACCTGCACACATGT-1  1.000000e+00  1.000000e+00 0.858456790
# rna_P-6117_S-8370_AAACCTGCACAGACTT-1  1.000000e+00  1.000000e+00 0.959576411
# rna_P-6117_S-8370_AAACCTGCACATGGGA-1  1.000000e+00  1.000000e+00 0.769368213
# rna_P-6117_S-8370_AAACCTGCAGACGCAA-1  1.000000e+00  1.000000e+00 0.715368044
# rna_P-6117_S-8370_AAACCTGCAGCGTAAG-1  1.000000e+00  1.000000e+00 0.613227701
# rna_P-6117_S-8370_AAACCTGCATGCCACG-1  1.000000e+00  1.000000e+00 0.780278333
# rna_P-6117_S-8370_AAACCTGCATGCCCGA-1  1.000000e+00  1.000000e+00 0.982184632
# rna_P-6117_S-8370_AAACCTGGTATCGCAT-1  1.000000e+00  1.000000e+00 0.720432611
# rna_P-6117_S-8370_AAACCTGGTCAAAGAT-1  1.000000e+00  1.000000e+00 0.371069182
# rna_P-6117_S-8370_AAACCTGGTCTGCGGT-1  1.000000e+00  1.000000e+00 0.850961780
# rna_P-6117_S-8370_AAACCTGGTCTTCAAG-1  1.000000e+00  1.000000e+00 0.789101122
# rna_P-6117_S-8370_AAACCTGGTGTAATGA-1  1.000000e+00  1.000000e+00 0.585062241
# rna_P-6117_S-8370_AAACCTGGTGTGTGCC-1  1.000000e+00  1.000000e+00 0.451694265
# rna_P-6117_S-8370_AAACCTGTCAGGCGAA-1  1.000000e+00  1.000000e+00 0.848112939
# rna_P-6117_S-8370_AAACCTGTCCAAACAC-1  1.000000e+00  1.000000e+00 0.376445329
# rna_P-6117_S-8370_AAACCTGTCCAACCAA-1 7.364135e-123 6.254673e-122 0.105330432
# rna_P-6117_S-8370_AAACCTGTCCTATGTT-1  1.000000e+00  1.000000e+00 0.366811557
# rna_P-6117_S-8370_AAACCTGTCGAGCCCA-1  1.000000e+00  1.000000e+00 0.878323364
# rna_P-6117_S-8370_AAACCTGTCTTGTACT-1  1.000000e+00  1.000000e+00 0.371069182
# rna_P-6117_S-8370_AAACGGGAGAAACCGC-1  1.000000e+00  1.000000e+00 0.585062241
# rna_P-6117_S-8370_AAACGGGAGACACGAC-1  1.000000e+00  1.000000e+00 0.952457344
# rna_P-6117_S-8370_AAACGGGAGATCTGAA-1  1.000000e+00  1.000000e+00 0.533333786
# rna_P-6117_S-8370_AAACGGGAGCTTATCG-1  1.000000e+00  1.000000e+00 0.500000000
# rna_P-6117_S-8370_AAACGGGAGGCCCGTT-1  1.000000e+00  1.000000e+00 0.252488519
# ⋮                                    ⋮             ⋮             ⋮
# rna_P-6519_S-9084_TTTGGTTCAACGTTAC-1 1.000000e+00  1.000000e+00  9.994877e-01
# rna_P-6519_S-9084_TTTGGTTCAATTCTTC-1 1.000000e+00  1.000000e+00  9.893556e-01
# rna_P-6519_S-9084_TTTGGTTCACGAAAGC-1 6.304791e-09  6.154194e-09  2.590893e-01
# rna_P-6519_S-9084_TTTGGTTCAGTTCACA-1 2.011053e-22  2.023797e-20  3.359568e-03
# rna_P-6519_S-9084_TTTGGTTCATATAGCC-1 3.541518e-06  3.412411e-06  2.522995e-01
# rna_P-6519_S-9084_TTTGGTTGTAACCAGG-1 3.742713e-17  3.426867e-14  3.451334e-04
# rna_P-6519_S-9084_TTTGGTTGTAGAGACC-1 1.000000e+00  1.000000e+00  9.068353e-01
# rna_P-6519_S-9084_TTTGGTTGTAGAGTTA-1 1.000000e+00  1.000000e+00  8.512684e-01
# rna_P-6519_S-9084_TTTGGTTGTAGGAGGG-1 9.999999e-01  9.999999e-01  1.380342e-01
# rna_P-6519_S-9084_TTTGGTTGTCGCTTAA-1 1.000000e+00  1.000000e+00  7.691633e-01
# rna_P-6519_S-9084_TTTGGTTGTTAAGTCC-1 1.000000e+00  9.999995e-01  9.535030e-01
# rna_P-6519_S-9084_TTTGGTTGTTGGTGTT-1 9.999998e-01  9.999789e-01  9.700947e-01
# rna_P-6519_S-9084_TTTGGTTGTTTCACAG-1 1.479848e-07  1.533798e-07  2.477420e-01
# rna_P-6519_S-9084_TTTGGTTTCCTACCAC-1 9.999174e-01  9.994679e-01  6.855082e-01
# rna_P-6519_S-9084_TTTGTTGAGCGAAACC-1 1.000000e+00  1.000000e+00  2.705057e-01
# rna_P-6519_S-9084_TTTGTTGAGCGCCTAC-1 1.000000e+00  9.999997e-01  9.141471e-01
# rna_P-6519_S-9084_TTTGTTGAGGTCGCCT-1 2.369775e-03  1.317930e-03  3.750000e-01
# rna_P-6519_S-9084_TTTGTTGAGTCGGCAA-1 1.398038e-14  7.071301e-11  6.738224e-05
# rna_P-6519_S-9084_TTTGTTGAGTGACCTT-1 1.420193e-21  6.714406e-18  7.148025e-05
# rna_P-6519_S-9084_TTTGTTGCAAGAATGT-1 1.000000e+00  1.000000e+00  7.628091e-01
# rna_P-6519_S-9084_TTTGTTGCAAGTGTCT-1 1.000000e+00  1.000000e+00  8.450251e-01
# rna_P-6519_S-9084_TTTGTTGCACCATAAC-1 1.000000e+00  1.000000e+00  1.592903e-01
# rna_P-6519_S-9084_TTTGTTGCACGCTGTG-1 4.240709e-05  4.240709e-05  2.500000e-01
# rna_P-6519_S-9084_TTTGTTGGTACGTACT-1 1.334062e-09  1.285426e-09  2.522995e-01
# rna_P-6519_S-9084_TTTGTTGGTAGCTGTT-1 9.103622e-19  7.306411e-16  4.271737e-04
# rna_P-6519_S-9084_TTTGTTGGTATGTCCA-1 1.000000e+00  1.000000e+00  9.206692e-01
# rna_P-6519_S-9084_TTTGTTGGTCGCATTA-1 5.302841e-10  2.983068e-07  6.080142e-04
# rna_P-6519_S-9084_TTTGTTGGTTATGTGC-1 1.457181e-22  4.056659e-15  1.231885e-08
# rna_P-6519_S-9084_TTTGTTGTCACATTGG-1 1.000000e+00  1.000000e+00  6.877106e-01
# rna_P-6519_S-9084_TTTGTTGTCGAGGCAA-1 7.130093e-14  2.504587e-12  9.597065e-03
#                                      compartment_opt
# rna_P-6117_S-8370_AAACCTGAGATCTGCT-1 tumor
# rna_P-6117_S-8370_AAACCTGAGATGCCTT-1 tumor
# rna_P-6117_S-8370_AAACCTGAGCGCCTCA-1 tumor
# rna_P-6117_S-8370_AAACCTGAGGGCTCTC-1 tumor
# rna_P-6117_S-8370_AAACCTGCAAGTCTAC-1 tumor
# rna_P-6117_S-8370_AAACCTGCAATCAGAA-1 tumor
# rna_P-6117_S-8370_AAACCTGCACACATGT-1 tumor
# rna_P-6117_S-8370_AAACCTGCACAGACTT-1 tumor
# rna_P-6117_S-8370_AAACCTGCACATGGGA-1 tumor
# rna_P-6117_S-8370_AAACCTGCAGACGCAA-1 tumor
# rna_P-6117_S-8370_AAACCTGCAGCGTAAG-1 tumor
# rna_P-6117_S-8370_AAACCTGCATGCCACG-1 tumor
# rna_P-6117_S-8370_AAACCTGCATGCCCGA-1 tumor
# rna_P-6117_S-8370_AAACCTGGTATCGCAT-1 tumor
# rna_P-6117_S-8370_AAACCTGGTCAAAGAT-1 tumor
# rna_P-6117_S-8370_AAACCTGGTCTGCGGT-1 tumor
# rna_P-6117_S-8370_AAACCTGGTCTTCAAG-1 tumor
# rna_P-6117_S-8370_AAACCTGGTGTAATGA-1 tumor
# rna_P-6117_S-8370_AAACCTGGTGTGTGCC-1 tumor
# rna_P-6117_S-8370_AAACCTGTCAGGCGAA-1 tumor
# rna_P-6117_S-8370_AAACCTGTCCAAACAC-1 tumor
# rna_P-6117_S-8370_AAACCTGTCCAACCAA-1 normal
# rna_P-6117_S-8370_AAACCTGTCCTATGTT-1 tumor
# rna_P-6117_S-8370_AAACCTGTCGAGCCCA-1 tumor
# rna_P-6117_S-8370_AAACCTGTCTTGTACT-1 tumor
# rna_P-6117_S-8370_AAACGGGAGAAACCGC-1 tumor
# rna_P-6117_S-8370_AAACGGGAGACACGAC-1 tumor
# rna_P-6117_S-8370_AAACGGGAGATCTGAA-1 tumor
# rna_P-6117_S-8370_AAACGGGAGCTTATCG-1 tumor
# rna_P-6117_S-8370_AAACGGGAGGCCCGTT-1 tumor
# ⋮                                    ⋮
# rna_P-6519_S-9084_TTTGGTTCAACGTTAC-1 tumor
# rna_P-6519_S-9084_TTTGGTTCAATTCTTC-1 tumor
# rna_P-6519_S-9084_TTTGGTTCACGAAAGC-1 normal
# rna_P-6519_S-9084_TTTGGTTCAGTTCACA-1 normal
# rna_P-6519_S-9084_TTTGGTTCATATAGCC-1 normal
# rna_P-6519_S-9084_TTTGGTTGTAACCAGG-1 normal
# rna_P-6519_S-9084_TTTGGTTGTAGAGACC-1 tumor
# rna_P-6519_S-9084_TTTGGTTGTAGAGTTA-1 tumor
# rna_P-6519_S-9084_TTTGGTTGTAGGAGGG-1 tumor
# rna_P-6519_S-9084_TTTGGTTGTCGCTTAA-1 tumor
# rna_P-6519_S-9084_TTTGGTTGTTAAGTCC-1 tumor
# rna_P-6519_S-9084_TTTGGTTGTTGGTGTT-1 tumor
# rna_P-6519_S-9084_TTTGGTTGTTTCACAG-1 normal
# rna_P-6519_S-9084_TTTGGTTTCCTACCAC-1 tumor
# rna_P-6519_S-9084_TTTGTTGAGCGAAACC-1 tumor
# rna_P-6519_S-9084_TTTGTTGAGCGCCTAC-1 tumor
# rna_P-6519_S-9084_TTTGTTGAGGTCGCCT-1 normal
# rna_P-6519_S-9084_TTTGTTGAGTCGGCAA-1 normal
# rna_P-6519_S-9084_TTTGTTGAGTGACCTT-1 normal
# rna_P-6519_S-9084_TTTGTTGCAAGAATGT-1 tumor
# rna_P-6519_S-9084_TTTGTTGCAAGTGTCT-1 tumor
# rna_P-6519_S-9084_TTTGTTGCACCATAAC-1 tumor
# rna_P-6519_S-9084_TTTGTTGCACGCTGTG-1 normal
# rna_P-6519_S-9084_TTTGTTGGTACGTACT-1 normal
# rna_P-6519_S-9084_TTTGTTGGTAGCTGTT-1 normal
# rna_P-6519_S-9084_TTTGTTGGTATGTCCA-1 tumor
# rna_P-6519_S-9084_TTTGTTGGTCGCATTA-1 normal
# rna_P-6519_S-9084_TTTGTTGGTTATGTGC-1 normal
# rna_P-6519_S-9084_TTTGTTGTCACATTGG-1 tumor
# rna_P-6519_S-9084_TTTGTTGTCGAGGCAA-1 normal

# %% [markdown]
# ### Merged

# %%
dmg <-  AddMetaData(dmg, iCNV)

# %%
dittoSeq::dittoDimPlot(dmg, 
             reduction.use = "umap", var = "compartment_opt", 
             do.label = T, labels.size = 4, 
             do.raster = TRUE) + NoAxes()
# Out:
# plot without title

# %%
options(repr.plot.height = 10, repr.plot.width = 20)
dittoSeq::dittoDimPlot(dmg, do.raster = TRUE,
             split.by = 'compartment_opt',
             reduction.use = "umap", var = "compartment_opt", 
             do.label = F, labels.size = 4) + NoAxes()
# Out:
# plot without title

# %%
options(repr.plot.height = 7, repr.plot.width = 10)
dittoSeq::dittoBarPlot(dmg, "compartment_opt", group.by = "predicted.annotation_level_3")
# Out:
# plot without title

# %%
saveRDS(iCNV, 'numbat_sc_Jessa2022.rds')
