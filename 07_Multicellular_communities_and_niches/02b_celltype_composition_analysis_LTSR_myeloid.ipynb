# %% [markdown]
# `conda activate r_env_standr`

# %% [markdown]
# Taken from https://doi.org/10.1038/s43587-024-00613-3

# %%
suppressPackageStartupMessages({
    library(reticulate)
    library(ggplot2)
    library(Seurat)
    library(dplyr)
    library(tidyr)
    library(tibble)
    library(stringr)
    library(lme4)
    library(numDeriv)
    library(dittoSeq)
    library(future)
    library(data.table)
    library(scales)
    plan("multicore", workers = 12)
    options(future.globals.maxSize = 1000 * 1024^5)
    options(stringsAsFactors = FALSE)
    set.seed(123)
})
# Out:
# Warning message:
# “package ‘ggplot2’ was built under R version 4.3.3”

# %%
myeloid <- readRDS('/projects/0/einf2548/cruiz/dmg/data/myeloid_rna.rds')
myeloid
# Out:
# An object of class Seurat
# 19248 features across 60672 samples within 1 assay
# Active assay: RNA (19248 features, 2000 variable features)
#  3 layers present: counts, data, scale.data
#  2 dimensional reductions calculated: pca, umap

# %%
MP_list = readRDS('data/robust_NMF_programs_myeloid_nomt_noribo.rds')

# %%
MP_list = as.data.frame(MP_list) %>% select(c('MP_4','MP_10','MP_7','MP_2','MP_8','MP_9'))

# %%
for (i in 1:ncol(MP_list)) {
  gene_set <- MP_list[[i]]
  myeloid <- AddModuleScore(
    object = myeloid,
    features = list(gene_set),
    name = paste0(colnames(MP_list)[i], '_')
  )
}
# Out:
# Warning message:
# “The following features are not present in the object: C11ORF65, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: C12ORF57, not searching for symbol synonyms”

# %%
# Extracting the scores
scores <- FetchData(
  myeloid,
  vars = paste0(c('MP_4','MP_10','MP_7','MP_2','MP_8','MP_9'), "_1")
)

colnames(scores) <- sub("_1$", "", colnames(scores))
colnames(scores) <- sub("_", "", colnames(scores))

scores
# Out:
#                                            MP4          MP10
# BT042_PD_TGCGATAAGCCATCCG-1                -0.00236428  -0.13057575
# BT042_PD_GAATAGAGTTTATGCG-1                 0.03998572  -0.17807608
# BT042_PD_CCTGCATAGGTCACAG-1                -0.14208201  -0.22154835
# BT042_PD_CGGAGAACAACTGCTA-1                 0.02837985  -0.06634642
# BT042_PD_AGGGCTCCAACTCGTA-1                 0.21526037  -0.06344517
# BT042_PD_GAGGCCTCACAGACGA-1                -0.09419071  -0.15958002
# BT042_PD_ACACTGACATAATCCG-1                -0.03831031  -0.09485660
# BT042_PD_TTCACGCTCGAGTGAG-1                -0.00676619  -0.20783224
# BT042_PD_ATGAGTCCAATCGCAT-1                 0.15557673   0.06482436
# BT042_PD_GGATGTTGTAGAGCTG-1                -0.12840677  -0.05259325
# BT042_PD_TGTGGCGTCTATACTC-1                -0.08617775  -0.14254677
# BT042_PD_AGCGCTGCATTGCAAC-1                -0.01740077  -0.02108589
# BT042_PD_TGACGCGCAAAGGGCT-1                 0.20526791   0.13015961
# BT042_PD_AAGTCGTTCAATCGGT-1                -0.07380693  -0.11980520
# BT042_PD_CGGGTCACACGTGAGA-1                 0.24979926  -0.03995992
# BT042_PD_GTGTTCCTCATTGTTC-1                 0.04826365   0.01593721
# BT042_PD_GCGATCGAGGTATAGT-1                 0.08209183  -0.25336662
# BT042_PD_CCTGTTGAGTGTTCAC-1                -0.02846825  -0.07715237
# BT042_PD_TACTTACCAAGTACCT-1                 0.05977220  -0.28009891
# BT042_PD_TTCAGGAGTAGTGTGG-1                 0.04660388  -0.15984974
# BT042_PD_GTGTTCCTCATTGTTC-1                 0.25384122  -0.005229404
# BT042_PD_GCGATCGAGGTATAGT-1                 0.31227699  -0.113702534
# BT042_PD_CCTGTTGAGTGTTCAC-1                 0.15714822  -0.095003187
# BT042_PD_TACTTACCAAGTACCT-1                -0.03907778   0.059167388
# BT042_PD_TTCAGGAGTAGTGTGG-1                 0.04559428  -0.079656556
# BT042_PD_AGGTGTTGTCGTCGGT-1                 0.06358744  -0.158244626
# BT042_PD_ACCTGTCGTCTGTGAT-1                 0.09228120   0.017613634
# BT042_PD_GAACTGTAGACCTCAT-1                 0.17536345  -0.162981957
# BT042_PD_AAGTCGTAGAGATTCA-1                 0.12260890  -0.044234645
# BT042_PD_TATCAGGAGCCTGACC-1                 0.37351835   0.015327357
# BT042_PD_CTGGCAGAGCTGTTCA-1                 0.24448630  -0.043793849
# BT042_PD_TGCGACGCAGCTGTGC-1                 0.33397227  -0.035782837
# BT042_PD_TTGACCCAGATGGCAC-1                 0.16265128  -0.016319816
# BT042_PD_CTGCTCACATCCTGTC-1                 0.10435986  -0.067817728
# BT042_PD_TAAGTCGGTCGCAGTC-1                 0.33119203   0.001291495
# ⋮                                          ⋮            ⋮
# multiome_P-6774_S-10146_TATTAGGTCGACCTGA-1  0.089269994  0.198402875
# multiome_P-6774_S-10146_TGCGCGAGTCGTAATG-1 -0.006553554  0.049318614
# multiome_P-6774_S-10146_GCTGTACCAAAGCGGC-1  0.079192285  0.503831086
# multiome_P-6774_S-10146_GGCAGGATCAGGGCCT-1 -0.041713802  0.246647773
# multiome_P-6774_S-10146_GGTTGGTGTGCTAGAC-1 -0.068230949  0.207159112
# multiome_P-6774_S-10146_GCATGAAAGGCAATAG-1  0.107468099  0.366380118
# multiome_P-6774_S-10146_GGTCAGGAGGGCTTTG-1  0.021418865  0.186254599
# multiome_P-6774_S-10146_CCTGAGTCACCCTCAC-1  0.012730042  0.129595602
# multiome_P-6774_S-10146_ATGAAGTAGTTATCCT-1  0.010475211  0.021445606
# multiome_P-6774_S-10146_CGGGACAAGATAGACG-1  0.019126458  0.102971995
# multiome_P-6774_S-10146_CATTCCTCACTGACTA-1 -0.003480568  0.124453911
# multiome_P-6774_S-10146_CAAACGCGTTGCAGTA-1  0.088826457 -0.174535747
# multiome_P-6774_S-10146_TTGGATATCGAGGAAC-1  0.221813576  0.038250034
# multiome_P-6774_S-10146_TCCTCTAAGGACCAGG-1  0.212983609  0.496348719
# multiome_P-6774_S-10146_GGAAACTCAAACCCTA-1  0.155501056 -0.028474514
# multiome_P-6774_S-10146_GATTAGTGTTTGCTGT-1  0.224971203  0.134255465
# multiome_P-6774_S-10146_TCGGTTTGTGATGATT-1  0.027939044  0.120565033
# multiome_P-6774_S-10146_GTCCAGGGTCCGTAGG-1  0.259092542  0.207604887
# multiome_P-6774_S-10146_CCGCTTAGTTAACACG-1  0.211852234  0.050933150
# multiome_P-6774_S-10146_GAGTGTTTCTAGCGTG-1  0.155774241  0.264613553
# multiome_P-6774_S-10146_GCGGTTGGTGGATTAT-1  0.059766504  0.165872358
# multiome_P-6774_S-10146_TTGGATTCACGTAAGG-1  0.049006308  0.004286609
# multiome_P-6774_S-10146_GTGCGCAGTAAACAAG-1  0.244848760  0.158785318
# multiome_P-6774_S-10146_GGCTTCAAGTTATGGC-1  0.187338288  0.564555816
# multiome_P-6774_S-10146_TACCGCAAGCGCCTTT-1  0.059636832  0.079780001
# multiome_P-6774_S-10146_GAGTGATCAAGTGTTT-1 -0.051569978  0.090314524
# multiome_P-6774_S-10146_GGTCAGGAGTGCTGTG-1  0.001728055  0.231313208
# multiome_P-6774_S-10146_TGGATTCAGACAAGTG-1  0.005623082  0.280707473
# multiome_P-6774_S-10146_TCCAGGTCAATTGAAG-1  0.087544082  0.064314711
# multiome_P-6774_S-10146_CTAGTAATCTAAGTGC-1  0.020146990  0.153284344

# %%
# as suggested in https://doi.org/10.1038/s41588-023-01570-0
# Normalize scores by subtracting the mean score for each MP
normalized_scores <- apply(scores, 2, function(x) x - mean(x))
                           
# Function to determine the assignment of each cell
assign_to_MP <- function(score_row) {
  sorted_scores <- sort(score_row, decreasing = TRUE)
  top_score <- sorted_scores[1]
  second_score <- sorted_scores[2]

  if (second_score <= 0.95 * top_score) {
    return(names(sorted_scores)[1])
  } else {
    return("unresolved")
  }
}

# Apply the function to each row (cell)
cell_assignments <- apply(normalized_scores, 1, assign_to_MP)

# %%
myeloid$MP_Assignment <- cell_assignments

# %%
myeloid$Material <- recode(myeloid$Batch_for_correction,
                          '10Xv1_nuclei_multiome' = 'nuclei',
                           '10Xv3_cell_rna'='cell',
                           '10Xv3_nuclei_rna'='nuclei',
                           '10Xv3.1_nuclei_rna'='nuclei')

# %%
meta <- myeloid@meta.data
meta
# Out:
#                                            nCount_RNA nFeature_RNA nCount_RAW
# BT042_PD_TGCGATAAGCCATCCG-1                4960       2065         4994
# BT042_PD_GAATAGAGTTTATGCG-1                4726       2219         4867
# BT042_PD_CCTGCATAGGTCACAG-1                4652       1813         4668
# BT042_PD_CGGAGAACAACTGCTA-1                4820       2178         4903
# BT042_PD_AGGGCTCCAACTCGTA-1                4537       1881         4567
# BT042_PD_GAGGCCTCACAGACGA-1                4003       1859         4017
# BT042_PD_ACACTGACATAATCCG-1                3750       1920         3805
# BT042_PD_TTCACGCTCGAGTGAG-1                3620       1835         3644
# BT042_PD_ATGAGTCCAATCGCAT-1                3547       1914         3607
# BT042_PD_GGATGTTGTAGAGCTG-1                3566       2060         3644
# BT042_PD_TGTGGCGTCTATACTC-1                3354       1510         3384
# BT042_PD_AGCGCTGCATTGCAAC-1                3371       1815         3434
# BT042_PD_TGACGCGCAAAGGGCT-1                3090       1720         3107
# BT042_PD_AAGTCGTTCAATCGGT-1                3211       1772         3294
# BT042_PD_CGGGTCACACGTGAGA-1                3143       1768         3280
# BT042_PD_GTGTTCCTCATTGTTC-1                3068       1788         3172
# BT042_PD_GCGATCGAGGTATAGT-1                3042       1513         3072
# BT042_PD_CCTGTTGAGTGTTCAC-1                2906       1549         2982
# BT042_PD_TACTTACCAAGTACCT-1                2848       1260         2858
# BT042_PD_TTCAGGAGTAGTGTGG-1                2931       1594         2977
# BT042_PD_AGGTGTTGTCGTCGGT-1                2877       1467         2904
# BT042_PD_ACCTGTCGTCTGTGAT-1                2751       1678         2796
# BT042_PD_GAACTGTAGACCTCAT-1                2803       1680         2892
# BT042_PD_AAGTCGTAGAGATTCA-1                2694       1608         2747
# BT042_PD_TATCAGGAGCCTGACC-1                2882       1475         2938
# BT042_PD_CTGGCAGAGCTGTTCA-1                2756       1582         2879
# BT042_PD_TGCGACGCAGCTGTGC-1                2744       1543         2781
# BT042_PD_TTGACCCAGATGGCAC-1                2755       1520         2785
# BT042_PD_CTGCTCACATCCTGTC-1                2708       1567         2757
# BT042_PD_TAAGTCGGTCGCAGTC-1                2790       1317         2817
# ⋮                                          ⋮          ⋮            ⋮
# multiome_P-6774_S-10146_TATTAGGTCGACCTGA-1 609        425          857
# multiome_P-6774_S-10146_TGCGCGAGTCGTAATG-1 434        341          807
# multiome_P-6774_S-10146_GCTGTACCAAAGCGGC-1 610        428          815
# multiome_P-6774_S-10146_GGCAGGATCAGGGCCT-1 615        447          807
# multiome_P-6774_S-10146_GGTTGGTGTGCTAGAC-1 550        349          780
# multiome_P-6774_S-10146_GCATGAAAGGCAATAG-1 546        400          776
# multiome_P-6774_S-10146_GGTCAGGAGGGCTTTG-1 548        392          754
# multiome_P-6774_S-10146_CCTGAGTCACCCTCAC-1 521        368          755
# multiome_P-6774_S-10146_ATGAAGTAGTTATCCT-1 541        391          769
# multiome_P-6774_S-10146_CGGGACAAGATAGACG-1 552        410          762
# multiome_P-6774_S-10146_CATTCCTCACTGACTA-1 520        368          754
# multiome_P-6774_S-10146_CAAACGCGTTGCAGTA-1 466        348          723
# multiome_P-6774_S-10146_TTGGATATCGAGGAAC-1 460        330          693
# multiome_P-6774_S-10146_TCCTCTAAGGACCAGG-1 490        358          718
# multiome_P-6774_S-10146_GGAAACTCAAACCCTA-1 461        354          698
# multiome_P-6774_S-10146_GATTAGTGTTTGCTGT-1 444        299          708
# multiome_P-6774_S-10146_TCGGTTTGTGATGATT-1 414        316          646
# multiome_P-6774_S-10146_GTCCAGGGTCCGTAGG-1 415        330          658
# multiome_P-6774_S-10146_CCGCTTAGTTAACACG-1 435        350          651
# multiome_P-6774_S-10146_GAGTGTTTCTAGCGTG-1 439        362          649
# multiome_P-6774_S-10146_GCGGTTGGTGGATTAT-1 403        289          631
# multiome_P-6774_S-10146_TTGGATTCACGTAAGG-1 403        271          600
# multiome_P-6774_S-10146_GTGCGCAGTAAACAAG-1 410        282          621
# multiome_P-6774_S-10146_GGCTTCAAGTTATGGC-1 339        269          557
# multiome_P-6774_S-10146_TACCGCAAGCGCCTTT-1 314        260          544
# multiome_P-6774_S-10146_GAGTGATCAAGTGTTT-1 302        242          525
# multiome_P-6774_S-10146_GGTCAGGAGTGCTGTG-1 342        251          506
# multiome_P-6774_S-10146_TGGATTCAGACAAGTG-1 302        226          461
# multiome_P-6774_S-10146_TCCAGGTCAATTGAAG-1 283        221          447
# multiome_P-6774_S-10146_CTAGTAATCTAAGTGC-1 238        207          408
#                                            nFeature_RAW DF.class DF.score
# BT042_PD_TGCGATAAGCCATCCG-1                2080         Singlet  0.10909091
# BT042_PD_GAATAGAGTTTATGCG-1                2231         Singlet  0.07272727
# BT042_PD_CCTGCATAGGTCACAG-1                1824         Singlet  0.12727273
# BT042_PD_CGGAGAACAACTGCTA-1                2192         Singlet  0.14545455
# BT042_PD_AGGGCTCCAACTCGTA-1                1899         Singlet  0.09090909
# BT042_PD_GAGGCCTCACAGACGA-1                1870         Singlet  0.10909091
# BT042_PD_ACACTGACATAATCCG-1                1938         Singlet  0.10909091
# BT042_PD_GAGGCCTCACAGACGA-1                Singlet           0.39733049
# BT042_PD_ACACTGACATAATCCG-1                Singlet           0.75327098
# BT042_PD_TTCACGCTCGAGTGAG-1                Singlet           0.26683545
# BT042_PD_ATGAGTCCAATCGCAT-1                Singlet           0.51619869
# BT042_PD_GGATGTTGTAGAGCTG-1                Singlet           0.47524789
# BT042_PD_TGTGGCGTCTATACTC-1                Singlet           0.26410073
# BT042_PD_AGCGCTGCATTGCAAC-1                Singlet           0.41683626
# BT042_PD_TGACGCGCAAAGGGCT-1                Singlet           0.44201136
# BT042_PD_AAGTCGTTCAATCGGT-1                Singlet           0.71990490
# BT042_PD_CGGGTCACACGTGAGA-1                Singlet           0.59689492
# BT042_PD_GTGTTCCTCATTGTTC-1                Singlet           0.46599516
# BT042_PD_GCGATCGAGGTATAGT-1                Singlet           0.59356058
# BT042_PD_CCTGTTGAGTGTTCAC-1                Singlet           0.53575867
# BT042_PD_TACTTACCAAGTACCT-1                Singlet           0.48334393
# BT042_PD_TTCAGGAGTAGTGTGG-1                Singlet           0.44463229
# BT042_PD_AGGTGTTGTCGTCGGT-1                Singlet           0.49025270
# BT042_PD_ACCTGTCGTCTGTGAT-1                Singlet           0.46512797
# BT042_PD_GAACTGTAGACCTCAT-1                Singlet           0.40684915
# BT042_PD_AAGTCGTAGAGATTCA-1                Singlet           0.34045538
# BT042_PD_TATCAGGAGCCTGACC-1                Singlet           0.51493543
# BT042_PD_CTGGCAGAGCTGTTCA-1                Singlet           0.63716537
# BT042_PD_TGCGACGCAGCTGTGC-1                Singlet           0.27625191
# BT042_PD_TTGACCCAGATGGCAC-1                Singlet           0.40799543
# BT042_PD_CTGCTCACATCCTGTC-1                Singlet           0.59538001
# BT042_PD_TAAGTCGGTCGCAGTC-1                Singlet           0.18350631
# ⋮                                          ⋮                 ⋮
# multiome_P-6774_S-10146_TATTAGGTCGACCTGA-1 Singlet           3.214233e-05
# multiome_P-6774_S-10146_TGCGCGAGTCGTAATG-1 Singlet           4.980835e-04
# multiome_P-6774_S-10146_GCTGTACCAAAGCGGC-1 Singlet           2.815578e-05
# multiome_P-6774_S-10146_GGCAGGATCAGGGCCT-1 Singlet           3.154331e-05
# multiome_P-6774_S-10146_GGTTGGTGTGCTAGAC-1 Singlet           4.336533e-05
# multiome_P-6774_S-10146_GCATGAAAGGCAATAG-1 Singlet           3.285105e-05
# multiome_P-6774_S-10146_GGTCAGGAGGGCTTTG-1 Singlet           6.526573e-05
# multiome_P-6774_S-10146_CCTGAGTCACCCTCAC-1 Singlet           1.238081e-05
# multiome_P-6774_S-10146_ATGAAGTAGTTATCCT-1 Singlet           1.036416e-04
# multiome_P-6774_S-10146_CGGGACAAGATAGACG-1 Singlet           1.402859e-05
# multiome_P-6774_S-10146_CATTCCTCACTGACTA-1 Singlet           5.437978e-05
# multiome_P-6774_S-10146_CAAACGCGTTGCAGTA-1 Singlet           8.237406e-05
# multiome_P-6774_S-10146_TTGGATATCGAGGAAC-1 Singlet           5.747534e-05
# multiome_P-6774_S-10146_TCCTCTAAGGACCAGG-1 Singlet           3.535008e-05
# multiome_P-6774_S-10146_GGAAACTCAAACCCTA-1 Singlet           2.299240e-04
# multiome_P-6774_S-10146_GATTAGTGTTTGCTGT-1 Singlet           2.032655e-05
# multiome_P-6774_S-10146_TCGGTTTGTGATGATT-1 Singlet           2.145567e-05
# multiome_P-6774_S-10146_GTCCAGGGTCCGTAGG-1 Singlet           1.672766e-05
# multiome_P-6774_S-10146_CCGCTTAGTTAACACG-1 Singlet           2.242342e-05
# multiome_P-6774_S-10146_GAGTGTTTCTAGCGTG-1 Singlet           6.478943e-05
# multiome_P-6774_S-10146_GCGGTTGGTGGATTAT-1 Singlet           1.642857e-04
# multiome_P-6774_S-10146_TTGGATTCACGTAAGG-1 Singlet           3.489021e-05
# multiome_P-6774_S-10146_GTGCGCAGTAAACAAG-1 Singlet           5.685459e-05
# multiome_P-6774_S-10146_GGCTTCAAGTTATGGC-1 Singlet           5.375483e-05
# multiome_P-6774_S-10146_TACCGCAAGCGCCTTT-1 Singlet           5.071286e-05
# multiome_P-6774_S-10146_GAGTGATCAAGTGTTT-1 Singlet           4.204729e-05
# multiome_P-6774_S-10146_GGTCAGGAGTGCTGTG-1 Singlet           4.284992e-05
# multiome_P-6774_S-10146_TGGATTCAGACAAGTG-1 Singlet           5.928063e-05
# multiome_P-6774_S-10146_TCCAGGTCAATTGAAG-1 Singlet           2.334795e-05
# multiome_P-6774_S-10146_CTAGTAATCTAAGTGC-1 Singlet           3.599050e-05
#                                            ID
# BT042_PD_TGCGATAAGCCATCCG-1                T18-90532
# BT042_PD_GAATAGAGTTTATGCG-1                T18-90532
# BT042_PD_CCTGCATAGGTCACAG-1                T18-90532
# BT042_PD_CGGAGAACAACTGCTA-1                T18-90532
# BT042_PD_AGGGCTCCAACTCGTA-1                T18-90532
# BT042_PD_GAGGCCTCACAGACGA-1                T18-90532
# BT042_PD_ACACTGACATAATCCG-1                T18-90532
# BT042_PD_TTCACGCTCGAGTGAG-1                T18-90532
# BT042_PD_ATGAGTCCAATCGCAT-1                T18-90532
# BT042_PD_GGATGTTGTAGAGCTG-1                T18-90532
# BT042_PD_TGTGGCGTCTATACTC-1                T18-90532
# BT042_PD_AGCGCTGCATTGCAAC-1                T18-90532
# BT042_PD_TGACGCGCAAAGGGCT-1                T18-90532
# BT042_PD_AAGTCGTTCAATCGGT-1                T18-90532
# BT042_PD_CGGGTCACACGTGAGA-1                T18-90532
# BT042_PD_GTGTTCCTCATTGTTC-1                T18-90532
# BT042_PD_GCGATCGAGGTATAGT-1                T18-90532
# BT042_PD_CCTGTTGAGTGTTCAC-1                T18-90532
# BT042_PD_TACTTACCAAGTACCT-1                T18-90532
# BT042_PD_TTCAGGAGTAGTGTGG-1                T18-90532
# BT042_PD_AGGTGTTGTCGTCGGT-1                T18-90532
# BT042_PD_ACCTGTCGTCTGTGAT-1                T18-90532
# BT042_PD_GAACTGTAGACCTCAT-1                T18-90532
# BT042_PD_AAGTCGTAGAGATTCA-1                T18-90532
# BT042_PD_TATCAGGAGCCTGACC-1                T18-90532
# BT042_PD_CTGGCAGAGCTGTTCA-1                T18-90532
# BT042_PD_TGCGACGCAGCTGTGC-1                T18-90532
# BT042_PD_TTGACCCAGATGGCAC-1                T18-90532
# BT042_PD_CTGCTCACATCCTGTC-1                T18-90532
# BT042_PD_TAAGTCGGTCGCAGTC-1                T18-90532
# ⋮                                          ⋮
# multiome_P-6774_S-10146_TATTAGGTCGACCTGA-1 P-6774_S-10146
# multiome_P-6774_S-10146_TGCGCGAGTCGTAATG-1 P-6774_S-10146
# multiome_P-6774_S-10146_GCTGTACCAAAGCGGC-1 P-6774_S-10146
# multiome_P-6774_S-10146_GGCAGGATCAGGGCCT-1 P-6774_S-10146
# multiome_P-6774_S-10146_GGTTGGTGTGCTAGAC-1 P-6774_S-10146
# multiome_P-6774_S-10146_GCATGAAAGGCAATAG-1 P-6774_S-10146
# multiome_P-6774_S-10146_GGTCAGGAGGGCTTTG-1 P-6774_S-10146
# multiome_P-6774_S-10146_CCTGAGTCACCCTCAC-1 P-6774_S-10146
# multiome_P-6774_S-10146_ATGAAGTAGTTATCCT-1 P-6774_S-10146
# multiome_P-6774_S-10146_CGGGACAAGATAGACG-1 P-6774_S-10146
# multiome_P-6774_S-10146_CATTCCTCACTGACTA-1 P-6774_S-10146
# multiome_P-6774_S-10146_CAAACGCGTTGCAGTA-1 P-6774_S-10146
# multiome_P-6774_S-10146_TTGGATATCGAGGAAC-1 P-6774_S-10146
# multiome_P-6774_S-10146_TCCTCTAAGGACCAGG-1 P-6774_S-10146
# multiome_P-6774_S-10146_GGAAACTCAAACCCTA-1 P-6774_S-10146
# multiome_P-6774_S-10146_GATTAGTGTTTGCTGT-1 P-6774_S-10146
# multiome_P-6774_S-10146_TCGGTTTGTGATGATT-1 P-6774_S-10146
# multiome_P-6774_S-10146_GTCCAGGGTCCGTAGG-1 P-6774_S-10146
# multiome_P-6774_S-10146_CCGCTTAGTTAACACG-1 P-6774_S-10146
# multiome_P-6774_S-10146_GAGTGTTTCTAGCGTG-1 P-6774_S-10146
# multiome_P-6774_S-10146_GCGGTTGGTGGATTAT-1 P-6774_S-10146
# multiome_P-6774_S-10146_TTGGATTCACGTAAGG-1 P-6774_S-10146
# multiome_P-6774_S-10146_GTGCGCAGTAAACAAG-1 P-6774_S-10146
# multiome_P-6774_S-10146_GGCTTCAAGTTATGGC-1 P-6774_S-10146
# multiome_P-6774_S-10146_TACCGCAAGCGCCTTT-1 P-6774_S-10146
# multiome_P-6774_S-10146_GAGTGATCAAGTGTTT-1 P-6774_S-10146
# multiome_P-6774_S-10146_GGTCAGGAGTGCTGTG-1 P-6774_S-10146
# multiome_P-6774_S-10146_TGGATTCAGACAAGTG-1 P-6774_S-10146
# multiome_P-6774_S-10146_TCCAGGTCAATTGAAG-1 P-6774_S-10146
# multiome_P-6774_S-10146_CTAGTAATCTAAGTGC-1 P-6774_S-10146
#                                            SampleID                ⋯ iCNV
# BT042_PD_TGCGATAAGCCATCCG-1                BT042_PD                ⋯ normal
# BT042_PD_GAATAGAGTTTATGCG-1                BT042_PD                ⋯ normal
# BT042_PD_CCTGCATAGGTCACAG-1                BT042_PD                ⋯ normal
# BT042_PD_CGGAGAACAACTGCTA-1                BT042_PD                ⋯ normal
# BT042_PD_AGGGCTCCAACTCGTA-1                BT042_PD                ⋯ normal
# BT042_PD_GAGGCCTCACAGACGA-1                BT042_PD                ⋯ normal
# BT042_PD_ACACTGACATAATCCG-1                BT042_PD                ⋯ normal
# BT042_PD_TTCACGCTCGAGTGAG-1                BT042_PD                ⋯ normal
# BT042_PD_ATGAGTCCAATCGCAT-1                BT042_PD                ⋯ normal
# BT042_PD_GGATGTTGTAGAGCTG-1                BT042_PD                ⋯ normal
# BT042_PD_TGTGGCGTCTATACTC-1                BT042_PD                ⋯ normal
# BT042_PD_AGCGCTGCATTGCAAC-1                BT042_PD                ⋯ normal
# BT042_PD_TGACGCGCAAAGGGCT-1                BT042_PD                ⋯ normal
# BT042_PD_AAGTCGTTCAATCGGT-1                BT042_PD                ⋯ normal
# BT042_PD_CGGGTCACACGTGAGA-1                BT042_PD                ⋯ normal
# BT042_PD_GTGTTCCTCATTGTTC-1                BT042_PD                ⋯ normal
# BT042_PD_GCGATCGAGGTATAGT-1                BT042_PD                ⋯ normal
# BT042_PD_CCTGTTGAGTGTTCAC-1                BT042_PD                ⋯ normal
# BT042_PD_TACTTACCAAGTACCT-1                BT042_PD                ⋯ normal
# BT042_PD_TTCAGGAGTAGTGTGG-1                BT042_PD                ⋯ normal
# BT042_PD_AGGTGTTGTCGTCGGT-1                BT042_PD                ⋯ normal
# BT042_PD_ACCTGTCGTCTGTGAT-1                BT042_PD                ⋯ normal
# BT042_PD_GAACTGTAGACCTCAT-1                BT042_PD                ⋯ normal
# BT042_PD_AAGTCGTAGAGATTCA-1                BT042_PD                ⋯ normal
# BT042_PD_TATCAGGAGCCTGACC-1                BT042_PD                ⋯ normal
# BT042_PD_CTGGCAGAGCTGTTCA-1                BT042_PD                ⋯ normal
# BT042_PD_TGCGACGCAGCTGTGC-1                BT042_PD                ⋯ normal
# BT042_PD_TTGACCCAGATGGCAC-1                BT042_PD                ⋯ normal
# BT042_PD_CTGCTCACATCCTGTC-1                BT042_PD                ⋯ normal
# BT042_PD_TAAGTCGGTCGCAGTC-1                BT042_PD                ⋯ normal
# ⋮                                          ⋮                       ⋱ ⋮
# multiome_P-6774_S-10146_TATTAGGTCGACCTGA-1 P-6774_S-10146_Multiome ⋯ normal
# multiome_P-6774_S-10146_TGCGCGAGTCGTAATG-1 P-6774_S-10146_Multiome ⋯ tumor
# multiome_P-6774_S-10146_GCTGTACCAAAGCGGC-1 P-6774_S-10146_Multiome ⋯ normal
# multiome_P-6774_S-10146_GGCAGGATCAGGGCCT-1 P-6774_S-10146_Multiome ⋯ normal
# multiome_P-6774_S-10146_GGTTGGTGTGCTAGAC-1 P-6774_S-10146_Multiome ⋯ normal
# multiome_P-6774_S-10146_GCATGAAAGGCAATAG-1 P-6774_S-10146_Multiome ⋯ normal
# multiome_P-6774_S-10146_GGTCAGGAGGGCTTTG-1 P-6774_S-10146_Multiome ⋯ normal
# multiome_P-6774_S-10146_CCTGAGTCACCCTCAC-1 P-6774_S-10146_Multiome ⋯ normal
# multiome_P-6774_S-10146_ATGAAGTAGTTATCCT-1 P-6774_S-10146_Multiome ⋯ normal
# multiome_P-6774_S-10146_CGGGACAAGATAGACG-1 P-6774_S-10146_Multiome ⋯ normal
# multiome_P-6774_S-10146_CATTCCTCACTGACTA-1 P-6774_S-10146_Multiome ⋯ normal
# multiome_P-6774_S-10146_CAAACGCGTTGCAGTA-1 P-6774_S-10146_Multiome ⋯ normal
# multiome_P-6774_S-10146_TTGGATATCGAGGAAC-1 P-6774_S-10146_Multiome ⋯ normal
# multiome_P-6774_S-10146_TCCTCTAAGGACCAGG-1 P-6774_S-10146_Multiome ⋯ normal
# multiome_P-6774_S-10146_GGAAACTCAAACCCTA-1 P-6774_S-10146_Multiome ⋯ normal
# multiome_P-6774_S-10146_GATTAGTGTTTGCTGT-1 P-6774_S-10146_Multiome ⋯ normal
# multiome_P-6774_S-10146_TCGGTTTGTGATGATT-1 P-6774_S-10146_Multiome ⋯ normal
# multiome_P-6774_S-10146_GTCCAGGGTCCGTAGG-1 P-6774_S-10146_Multiome ⋯ normal
# multiome_P-6774_S-10146_CCGCTTAGTTAACACG-1 P-6774_S-10146_Multiome ⋯ normal
# multiome_P-6774_S-10146_GAGTGTTTCTAGCGTG-1 P-6774_S-10146_Multiome ⋯ normal
# multiome_P-6774_S-10146_GCGGTTGGTGGATTAT-1 P-6774_S-10146_Multiome ⋯ normal
# multiome_P-6774_S-10146_TTGGATTCACGTAAGG-1 P-6774_S-10146_Multiome ⋯ normal
# multiome_P-6774_S-10146_GTGCGCAGTAAACAAG-1 P-6774_S-10146_Multiome ⋯ normal
# multiome_P-6774_S-10146_GGCTTCAAGTTATGGC-1 P-6774_S-10146_Multiome ⋯ normal
# multiome_P-6774_S-10146_TACCGCAAGCGCCTTT-1 P-6774_S-10146_Multiome ⋯ normal
# multiome_P-6774_S-10146_GAGTGATCAAGTGTTT-1 P-6774_S-10146_Multiome ⋯ normal
# multiome_P-6774_S-10146_GGTCAGGAGTGCTGTG-1 P-6774_S-10146_Multiome ⋯ normal
# multiome_P-6774_S-10146_TGGATTCAGACAAGTG-1 P-6774_S-10146_Multiome ⋯ normal
# multiome_P-6774_S-10146_TCCAGGTCAATTGAAG-1 P-6774_S-10146_Multiome ⋯ normal
# multiome_P-6774_S-10146_CTAGTAATCTAAGTGC-1 P-6774_S-10146_Multiome ⋯ normal
#                                            cell_id         MP_4_1
# BT042_PD_TGCGATAAGCCATCCG-1                TAM_BDM         -0.00236428
# BT042_PD_GAATAGAGTTTATGCG-1                TAM_BDM          0.03998572
# BT042_PD_CCTGCATAGGTCACAG-1                TAM_BDM         -0.14208201
# BT042_PD_CGGAGAACAACTGCTA-1                TAM_BDM          0.02837985
# BT042_PD_AGGGCTCCAACTCGTA-1                TAM_BDM          0.21526037
# BT042_PD_GAGGCCTCACAGACGA-1                TAM_BDM         -0.09419071
# BT042_PD_ACACTGACATAATCCG-1                TAM_BDM         -0.03831031
# BT042_PD_TTCACGCTCGAGTGAG-1                TAM_BDM         -0.00676619
# BT042_PD_ATGAGTCCAATCGCAT-1                TAM_BDM          0.15557673
# BT042_PD_GGATGTTGTAGAGCTG-1                TAM_BDM         -0.12840677
# BT042_PD_TGTGGCGTCTATACTC-1                TAM_BDM         -0.08617775
# BT042_PD_AGCGCTGCATTGCAAC-1                TAM_BDM         -0.01740077
# BT042_PD_TGACGCGCAAAGGGCT-1                TAM_BDM          0.20526791
# BT042_PD_AAGTCGTTCAATCGGT-1                TAM_BDM         -0.07380693
# BT042_PD_CGGGTCACACGTGAGA-1                TAM_BDM          0.24979926
# BT042_PD_GTGTTCCTCATTGTTC-1                TAM_BDM          0.04826365
# BT042_PD_GCGATCGAGGTATAGT-1                TAM_BDM          0.08209183
# BT042_PD_CCTGTTGAGTGTTCAC-1                TAM_BDM         -0.02846825
# BT042_PD_TACTTACCAAGTACCT-1                TAM_BDM          0.05977220
# BT042_PD_TTCAGGAGTAGTGTGG-1                TAM_BDM          0.04660388
# BT042_PD_AGGTGTTGTCGTCGGT-1                TAM_BDM         -0.01341793
# BT042_PD_ACCTGTCGTCTGTGAT-1                TAM_BDM         -0.05340072
# BT042_PD_GAACTGTAGACCTCAT-1                Mono             0.48839750
# BT042_PD_AAGTCGTAGAGATTCA-1                TAM_BDM          0.05148808
# BT042_PD_TATCAGGAGCCTGACC-1                TAM_BDM          0.03592798
# BT042_PD_CTGGCAGAGCTGTTCA-1                TAM_BDM         -0.10346980
# BT042_PD_TGCGACGCAGCTGTGC-1                TAM_BDM         -0.05956197
# BT042_PD_TTGACCCAGATGGCAC-1                TAM_BDM         -0.03522556
# BT042_PD_CTGCTCACATCCTGTC-1                TAM_BDM          0.01577020
# BT042_PD_TAAGTCGGTCGCAGTC-1                TAM_BDM          0.15298100
# ⋮                                          ⋮               ⋮
# multiome_P-6774_S-10146_TATTAGGTCGACCTGA-1 TAM_BDM          0.091106712
# multiome_P-6774_S-10146_TGCGCGAGTCGTAATG-1 Stem_like_tumor  0.057402504
# multiome_P-6774_S-10146_GCTGTACCAAAGCGGC-1 TAM_BDM          0.026685998
# multiome_P-6774_S-10146_GGCAGGATCAGGGCCT-1 TAM_BDM         -0.050912241
# multiome_P-6774_S-10146_GGTTGGTGTGCTAGAC-1 TAM_BDM         -0.070393474
# multiome_P-6774_S-10146_GCATGAAAGGCAATAG-1 TAM_BDM         -0.032200107
# multiome_P-6774_S-10146_GGTCAGGAGGGCTTTG-1 TAM_BDM         -0.075881518
# multiome_P-6774_S-10146_CCTGAGTCACCCTCAC-1 TAM_BDM          0.095921392
# multiome_P-6774_S-10146_ATGAAGTAGTTATCCT-1 TAM_BDM          0.027559788
# multiome_P-6774_S-10146_CGGGACAAGATAGACG-1 TAM_BDM         -0.044302976
# multiome_P-6774_S-10146_CATTCCTCACTGACTA-1 TAM_BDM         -0.077843421
# multiome_P-6774_S-10146_CAAACGCGTTGCAGTA-1 TAM_BDM         -0.072856709
# multiome_P-6774_S-10146_TTGGATATCGAGGAAC-1 TAM_BDM         -0.080644565
# multiome_P-6774_S-10146_TCCTCTAAGGACCAGG-1 TAM_BDM          0.068379916
# multiome_P-6774_S-10146_GGAAACTCAAACCCTA-1 TAM_BDM          0.029833814
# multiome_P-6774_S-10146_GATTAGTGTTTGCTGT-1 B_cell          -0.062768703
# multiome_P-6774_S-10146_TCGGTTTGTGATGATT-1 TAM_BDM         -0.020447770
# multiome_P-6774_S-10146_GTCCAGGGTCCGTAGG-1 TAM_BDM          0.175629647
# multiome_P-6774_S-10146_CCGCTTAGTTAACACG-1 TAM_BDM          0.032378111
# multiome_P-6774_S-10146_GAGTGTTTCTAGCGTG-1 TAM_BDM          0.149108742
# multiome_P-6774_S-10146_GCGGTTGGTGGATTAT-1 TAM_BDM         -0.073866644
# multiome_P-6774_S-10146_TTGGATTCACGTAAGG-1 TAM_BDM         -0.014496533
# multiome_P-6774_S-10146_GTGCGCAGTAAACAAG-1 B_cell           0.123324483
# multiome_P-6774_S-10146_GGCTTCAAGTTATGGC-1 B_cell           0.063217984
# multiome_P-6774_S-10146_TACCGCAAGCGCCTTT-1 TAM_MG           0.007139013
# multiome_P-6774_S-10146_GAGTGATCAAGTGTTT-1 TAM_MG          -0.061626376
# multiome_P-6774_S-10146_GGTCAGGAGTGCTGTG-1 B_cell          -0.053194240
# multiome_P-6774_S-10146_TGGATTCAGACAAGTG-1 TAM_MG          -0.057899688
# multiome_P-6774_S-10146_TCCAGGTCAATTGAAG-1 TAM_BDM          0.004574947
# multiome_P-6774_S-10146_CTAGTAATCTAAGTGC-1 B_cell           0.071661707
#                                            MP_10_1     MP_7_1       MP_2_1
# BT042_PD_TGCGATAAGCCATCCG-1                -0.13057575  0.064428696  0.03415157
# BT042_PD_GAATAGAGTTTATGCG-1                -0.17807608 -0.073085107  0.18685520
# BT042_PD_CCTGCATAGGTCACAG-1                -0.22154835  0.115023802 -0.45820713
# BT042_PD_CGGAGAACAACTGCTA-1                -0.06634642  0.010894763 -0.15444584
# BT042_PD_AGGGCTCCAACTCGTA-1                -0.06344517 -0.028994205 -0.26797151
# BT042_PD_GAGGCCTCACAGACGA-1                -0.15958002 -0.014367484 -0.28721043
# BT042_PD_ACACTGACATAATCCG-1                -0.09485660 -0.004028131  0.16793354
# BT042_PD_TTCACGCTCGAGTGAG-1                -0.20783224  0.117037765  0.08801238
# BT042_PD_ATGAGTCCAATCGCAT-1                 0.06482436  0.083166953  0.81102772
# BT042_PD_GGATGTTGTAGAGCTG-1                -0.05259325 -0.081168406  0.70172449
# BT042_PD_TGTGGCGTCTATACTC-1                -0.14254677  0.117435910 -0.53344863
# BT042_PD_AGCGCTGCATTGCAAC-1                -0.02108589 -0.108808614  0.17475748
# BT042_PD_TGACGCGCAAAGGGCT-1                 0.13015961  0.313252312 -0.30435418
# BT042_PD_AAGTCGTTCAATCGGT-1                -0.11980520  0.148147620  0.40984552
# BT042_PD_CGGGTCACACGTGAGA-1                -0.03995992  0.040613848 -0.06189214
# BT042_PD_GTGTTCCTCATTGTTC-1                 0.01593721  0.073448719  0.64499971
# BT042_PD_GCGATCGAGGTATAGT-1                -0.25336662 -0.039340116 -0.51339042
# BT042_PD_GAGGCCTCACAGACGA-1                MP8           nuclei
# BT042_PD_ACACTGACATAATCCG-1                MP8           nuclei
# BT042_PD_TTCACGCTCGAGTGAG-1                MP8           nuclei
# BT042_PD_ATGAGTCCAATCGCAT-1                MP2           nuclei
# BT042_PD_GGATGTTGTAGAGCTG-1                MP2           nuclei
# BT042_PD_TGTGGCGTCTATACTC-1                MP8           nuclei
# BT042_PD_AGCGCTGCATTGCAAC-1                MP8           nuclei
# BT042_PD_TGACGCGCAAAGGGCT-1                unresolved    nuclei
# BT042_PD_AAGTCGTTCAATCGGT-1                MP8           nuclei
# BT042_PD_CGGGTCACACGTGAGA-1                MP4           nuclei
# BT042_PD_GTGTTCCTCATTGTTC-1                MP2           nuclei
# BT042_PD_GCGATCGAGGTATAGT-1                MP8           nuclei
# BT042_PD_CCTGTTGAGTGTTCAC-1                MP8           nuclei
# BT042_PD_TACTTACCAAGTACCT-1                MP4           nuclei
# BT042_PD_TTCAGGAGTAGTGTGG-1                MP4           nuclei
# BT042_PD_AGGTGTTGTCGTCGGT-1                MP8           nuclei
# BT042_PD_ACCTGTCGTCTGTGAT-1                MP2           nuclei
# BT042_PD_GAACTGTAGACCTCAT-1                unresolved    nuclei
# BT042_PD_AAGTCGTAGAGATTCA-1                MP8           nuclei
# BT042_PD_TATCAGGAGCCTGACC-1                MP8           nuclei
# BT042_PD_CTGGCAGAGCTGTTCA-1                MP8           nuclei
# BT042_PD_TGCGACGCAGCTGTGC-1                MP8           nuclei
# BT042_PD_TTGACCCAGATGGCAC-1                MP8           nuclei
# BT042_PD_CTGCTCACATCCTGTC-1                MP8           nuclei
# BT042_PD_TAAGTCGGTCGCAGTC-1                MP8           nuclei
# ⋮                                          ⋮             ⋮
# multiome_P-6774_S-10146_TATTAGGTCGACCTGA-1 MP7           nuclei
# multiome_P-6774_S-10146_TGCGCGAGTCGTAATG-1 MP4           nuclei
# multiome_P-6774_S-10146_GCTGTACCAAAGCGGC-1 MP9           nuclei
# multiome_P-6774_S-10146_GGCAGGATCAGGGCCT-1 MP7           nuclei
# multiome_P-6774_S-10146_GGTTGGTGTGCTAGAC-1 MP9           nuclei
# multiome_P-6774_S-10146_GCATGAAAGGCAATAG-1 MP9           nuclei
# multiome_P-6774_S-10146_GGTCAGGAGGGCTTTG-1 MP9           nuclei
# multiome_P-6774_S-10146_CCTGAGTCACCCTCAC-1 MP4           nuclei
# multiome_P-6774_S-10146_ATGAAGTAGTTATCCT-1 MP4           nuclei
# multiome_P-6774_S-10146_CGGGACAAGATAGACG-1 MP7           nuclei
# multiome_P-6774_S-10146_CATTCCTCACTGACTA-1 MP9           nuclei
# multiome_P-6774_S-10146_CAAACGCGTTGCAGTA-1 MP8           nuclei
# multiome_P-6774_S-10146_TTGGATATCGAGGAAC-1 MP8           nuclei
# multiome_P-6774_S-10146_TCCTCTAAGGACCAGG-1 MP9           nuclei
# multiome_P-6774_S-10146_GGAAACTCAAACCCTA-1 MP8           nuclei
# multiome_P-6774_S-10146_GATTAGTGTTTGCTGT-1 MP8           nuclei
# multiome_P-6774_S-10146_TCGGTTTGTGATGATT-1 MP9           nuclei
# multiome_P-6774_S-10146_GTCCAGGGTCCGTAGG-1 MP8           nuclei
# multiome_P-6774_S-10146_CCGCTTAGTTAACACG-1 MP8           nuclei
# multiome_P-6774_S-10146_GAGTGTTTCTAGCGTG-1 MP9           nuclei
# multiome_P-6774_S-10146_GCGGTTGGTGGATTAT-1 MP9           nuclei
# multiome_P-6774_S-10146_TTGGATTCACGTAAGG-1 unresolved    nuclei
# multiome_P-6774_S-10146_GTGCGCAGTAAACAAG-1 MP8           nuclei
# multiome_P-6774_S-10146_GGCTTCAAGTTATGGC-1 MP9           nuclei
# multiome_P-6774_S-10146_TACCGCAAGCGCCTTT-1 MP8           nuclei
# multiome_P-6774_S-10146_GAGTGATCAAGTGTTT-1 MP9           nuclei
# multiome_P-6774_S-10146_GGTCAGGAGTGCTGTG-1 MP9           nuclei
# multiome_P-6774_S-10146_TGGATTCAGACAAGTG-1 MP9           nuclei
# multiome_P-6774_S-10146_TCCAGGTCAATTGAAG-1 MP8           nuclei
# multiome_P-6774_S-10146_CTAGTAATCTAAGTGC-1 MP9           nuclei

# %%
library("data.table")
library("tidyverse")
library("ggpubr")
library("magrittr")
library("lme4")
library("numDeriv")
library("scales")
library("stringr")
# Out:
# ── Attaching core tidyverse packages ───────────────────────────────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ forcats   1.0.0     ✔ purrr     1.0.2
# ✔ lubridate 1.9.3     ✔ readr     2.1.5
# ── Conflicts ─────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ data.table::between() masks dplyr::between()
# ✖ readr::col_factor()   masks scales::col_factor()
# ✖ purrr::discard()      masks scales::discard()
# ✖ Matrix::expand()      masks tidyr::expand()
# ✖ dplyr::filter()       masks stats::filter()
# ✖ data.table::first()   masks dplyr::first()
# ✖ lubridate::hour()     masks data.table::hour()
# ✖ lubridate::isoweek()  masks data.table::isoweek()
# ✖ dplyr::lag()          masks stats::lag()
# ✖ data.table::last()    masks dplyr::last()
# ✖ lubridate::mday()     masks data.table::mday()
# ✖ lubridate::minute()   masks data.table::minute()
# ✖ lubridate::month()    masks data.table::month()
# ✖ Matrix::pack()        masks tidyr::pack()
# ✖ lubridate::quarter()  masks data.table::quarter()
# ✖ lubridate::second()   masks data.table::second()
# ✖ purrr::transpose()    masks data.table::transpose()
# ✖ Matrix::unpack()      masks tidyr::unpack()
# ✖ lubridate::wday()     masks data.table::wday()
# ✖ lubridate::week()     masks data.table::week()
# ✖ lubridate::yday()     masks data.table::yday()
# ✖ lubridate::year()     masks data.table::year()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘magrittr’
#
#
# The following object is masked from ‘package:purrr’:
#
#     set_names
#
#
# The following object is masked from ‘package:tidyr’:
#
#     extract

# %%
# Method and initial implementation by Natsuhiko Kumasaka (natsuhiko@github)
# refactored and maintained by Ni Huang (nh3@github)

#' Make cell type by sample count matrix
#'
#' This function makes cell type by sample count matrix from a cell level annotation table
#'
#' @param obs_tbl Cell level annotation table, such as AnnData.obs (data.frame-like object)
#' @param colSample Column in "obs_tbl" specifying sample ID (str)
#' @param colCelltype Column in "obs_tbl" specifying cell type annotation (str)
#'
#' @return matrix containing cell type counts of dimension nSample x nCelltype
#'
#' @import magrittr
.make_count_matrix <- function(obs_tbl, colSample, colCelltype) {
  cnt_mat <- table(obs_tbl[[colSample]], obs_tbl[[colCelltype]]) %>% as.matrix()
  cnt_mat
}

#' Make sample level metadata table
#'
#' This function makes sample level metadata table from a cell level annotation table
#'
#' @param obs_tbl Cell level annotation table, such as AnnData.obs (data.frame-like object)
#' @param colSample Column in "obs_tbl" specifying sample ID (str)
#' @param colVarCats Columns in "obs_tbl" specifying categorical variables to control for (vector of str)
#' @param colVarNums Columns in "obs_tbl" specifying numerical variables to control for (vector of str)
#' @param extra_term Extra term(s) to be added to the model (str or vector of str)
#'
#' @return tibble containing metadata for each sample, one per row
#'
#' @import dplyr
.make_sample_metadata <- function(obs_tbl, colSample, colVarCats = c(), colVarNums = c(), extra_term = NULL) {
  if (!is.null(extra_term)) {
    extra_vars <- unique(unlist(strsplit(extra_term, ":", fixed = T)))
    extra_vars <- extra_vars[extra_vars %in% colnames(obs_tbl)]
  } else {
    extra_vars <- c()
  }
  metadata_tbl <- obs_tbl %>%
    select(one_of(unique(c(colSample, colVarCats, colVarNums, extra_vars)))) %>%
    unique()
  metadata_tbl
}

#' Make input data for model fitting
#'
#' This function makes input data for model fitting by assembling sample level
#' metadata and cell type by sample count matrix
#'
#' @param Y Cell type by sample count matrix (matrix of dimension nSample x nCelltype)
#' @param metadata_tbl Sample level metadata table (data.frame-like object)
#'
#' @return tibble containing counts and metadata for each cell type in each sample
#'
#' @import tibble
#' @import dplyr
.make_input_for_glmer <- function(Y, metadata_tbl, colSample) {
  samples <- rownames(Y)
  celltypes <- colnames(Y)
  nSample <- length(samples)
  nCelltype <- length(celltypes)

  metadata_tbl <- metadata_tbl[match(samples, metadata_tbl[[colSample]]), ]

  input_tbl <- bind_cols(
    metadata_tbl[rep(1:nSample, nCelltype), ],
    enframe(factor(rep(celltypes, rep(nSample, nCelltype))), name = NULL, value = "Celltype")
  )

  input_tbl$Y <- as.vector(Y)
  cat("input prepared\n")

  input_tbl
}

#' Make model formula
#'
#' This function makes a formula for a GLMM with random effects for each
#' specified categorical variables and interactions between each variable and
#' cell type
#'
#' @param colSample Column in "obs_tbl" specifying sample ID (str)
#' @param colVarCats Columns in "obs_tbl" specifying categorical variables to control for (vector of str)
#' @param colVarNums Columns in "obs_tbl" specifying numerical variables to control for (vector of str)
#' @param extra_term Extra term(s) to be added to the model (str or vector of str)
#'
#' @return formula specifying a GLMM model
.make_formula <- function(colSample, colCelltype, colVarCats, colVarNums, extra_term = NULL) {
  if (!is.null(extra_term)) {
    extra_vars <- unique(unlist(strsplit(extra_term, ":", fixed = T)))
    extra_vars[extra_vars == colCelltype] <- "Celltype"
    extra_term <- sprintf("(1|%s)", paste(extra_vars, collapse = ":"))
  }
  terms <- c(
    colVarNums,
    sprintf("(1|%s)", c(colSample, colVarCats)),
    sprintf("(%s-1|Celltype)", colVarNums),
    sprintf("(1|%s:Celltype)", c(colSample, colVarCats))
  )
  formula_str <- paste(c("I(Y) ~ (1|Celltype)", terms, extra_term), collapse = "+")
  cat(paste0(formula_str, "\n"))
  as.formula(formula_str)
}

#' Get mean estimate of random effects and LTSR values for all specified variables
#'
#' This function extracts random effect estimates (mean and sd) of specified
#' variables, calculates LTSR using a z-score test and prepare categories in
#' specified orders for plotting
#'
#' @param ranef_tbl Table of random effect estimates (mean and sd) extracted from fitted model
#'     (data.frame-like object)
#' @param vars A list specifying required categorical sample metadata variables and their order,
#'     e.g. list(size=c('small', 'medium', 'big'), price=c('cheap', 'expensive'))
#' @param celltypes If specified, only keep those cell types (vector of str)
#' @param references If specified, fold changes are calculated relative to the specified level
#'     instead of global mean. Must be a list, e.g. list(size='small', price='cheap')
#'
#' @return tibble containing mean random effects and respective LTSR
#'
#' @import dplyr
#' @import tidyr
#' @import stringr
.getCondValLtsr <- function(ranef_tbl, vars, celltypes = NULL, references = NULL) {
  if (!is.list(vars)) stop('"vars" must be a list of which names are co-variables to plot', call. = F)
  if (!is.null(references) && !is.list(references)) stop('"references" must be a list of which names match that of "vars"', call. = F)

  cat_ranef_tbl <- ranef_tbl %>%
    filter(
      grepl(":Celltype$", grpvar)
    ) %>%
    mutate(
      grpvar = factor(sub(":Celltype$", "", grpvar)),
      grp = factor(ifelse(
        grepl(":.*:", grp),
        sapply(str_split(grp, ":"), function(x) paste(paste(x[-length(x)], collapse = ","), x[length(x)], sep = ":")),
        as.character(grp)
      ))
    ) %>%
    separate(
      grp,
      into = c("grpval", "Celltype"), sep = ":"
    )

  num_ranef_tbl <- ranef_tbl %>%
    filter(
      grpvar == "Celltype" & term != "(Intercept)"
    ) %>%
    mutate(
      grpvar = factor(term),
      grpval= paste("Slope",term, sep = "-"),
      Celltype = grp
    ) %>%
    select (
      -grp
    )

  if (!is.null(references)) {
    cat_ranef_tbl <- bind_rows(
      lapply(names(vars), function(vname) {
        if (vname %in% names(references)) {
          ref <- references[[vname]]
          full_join(
            cat_ranef_tbl %>% filter(grpvar == vname, grpval != ref),
            cat_ranef_tbl %>% filter(grpvar == vname, grpval == ref) %>% select(grpvar, Celltype, condval, condsd),
            by = c("grpvar", "Celltype")
          ) %>%
            mutate(
              condval = condval.x - condval.y,
              condsd = sqrt(condsd.x^2 + condsd.y^2)
            ) %>%
            select(-condval.x, -condval.y, -condsd.x, -condsd.y)
        } else {
          return(cat_ranef_tbl %>% filter(grpvar == vname))
        }
      })
    )
  }

  ranef_tbl <- bind_rows(cat_ranef_tbl, num_ranef_tbl)

  ranef_tbl <- ranef_tbl %>%
    mutate(
      lfsr = pnorm(condval, 0, condsd)
    ) %>%
    mutate(
      lfsr = ifelse(lfsr > 0.5, 1 - lfsr, lfsr)
    ) %>%
    mutate(
      ltsr = 1 - lfsr
    ) %>%
    select(
      grpvar, grpval, Celltype, condval, ltsr
    )

  if (!is.null(celltypes)) ranef_tbl <- ranef_tbl %>% filter(Celltype %in% celltypes)

  ranef_tbl <- ranef_tbl %>%
    filter(
      grpvar %in% names(vars)
    ) %>%
    mutate(
      grpvar = factor(grpvar, levels = names(vars)),
      grpval = factor(grpval, levels = unlist(vars, use.names = F))
    )

  ranef_tbl
}

#' Cell type composition analysis
#'
#' This function performs cell type composition analysis across samples grouped by certain metadata
#' variable while controling for other variables, by fitting a Poisson Generalised Linear Mixed
#' Model
#'
#' @param obs_tbl Cell level annotation table, such as AnnData.obs (data.frame-like object)
#' @param colSample Column in "obs_tbl" specifying sample ID (str)
#' @param colCelltype Column in "obs_tbl" specifying cell type annotation (str)
#' @param colVarCats Columns in "obs_tbl" specifying categorical variables to control for (vector of str)
#' @param colVarNums Columns in "obs_tbl" specifying numerical variables to control for (vector of str)
#' @param extra_term Extra term(s) to be added to the model (str or vector of str)
#' @param save If specified, used as file name prefix to save returned values (str)
#'
#' @return list containing two tables, 1) estimated random effects, 2) estimated explained variance
#'     (in the form of standard deviation)
#'
#' @import tibble
#' @import dplyr
#' @import tidyr
#' @import lme4
#' @import numDeriv
#'
#' @export
CellTypeCompositionAnalysis <- function(obs_tbl, colSample, colCelltype, colVarCats, colVarNums = NULL, extra_term = NULL, save = NULL) {
  metadata_tbl <- .make_sample_metadata(obs_tbl, colSample, colVarCats, colVarNums, extra_term = extra_term)
  Y <- .make_count_matrix(obs_tbl, colSample, colCelltype)

  input_tbl <- .make_input_for_glmer(Y, metadata_tbl, colSample)

  f <- .make_formula(colSample, colCelltype, colVarCats, colVarNums, extra_term = extra_term)
  cat("model constructed\n")
  res.prop <- glmer(
    f,
    data = input_tbl, family = poisson,
    control = glmerControl(optimizer = "bobyqa", optCtrl = list(maxfun = 2e5))
  )
  cat("model fitted\n")

  # standard errors of standard deviations (squre root of the variance parameters)
  devfun <- update(res.prop, devFunOnly = T)
  pars <- getME(res.prop, c("theta", "fixef"))
  hess <- hessian(devfun, unlist(pars))
  sdse.prop <- data.frame(sd = unlist(pars), se = sqrt(diag(solve(hess))))
  sdse_tbl <- sdse.prop %>%
    rownames_to_column() %>%
    as_tibble()
  # posterior means and their standard deviations
  res.prop.ranef <- ranef(res.prop)
  ranef_tbl <- data.frame(res.prop.ranef) %>% as_tibble()

  if (is.character(save)) {
    output_dir <- ifelse(grepl("[/]$", save), save, dirname(save))
    if (!dir.exists(output_dir)) dir.create(output_dir, recursive = T)
    output_sep <- ifelse(grepl("[/.]$", save), "", ".")
    write_tsv(ranef_tbl, paste(save, "ranef.tsv", sep = output_sep))
    write_tsv(sdse_tbl, paste(save, "sdse.tsv", sep = output_sep))
  }

  list(ranef = ranef_tbl, sdse = sdse_tbl)
}

#' Plot variable explained variance
#'
#' This function plots (square root of) variance explained by variables as a forest plot
#'
#' @param sdse_tbl Table containing square-root of estimated explained variance and standard errors
#'     (data.frame-like object)
#' @param colSample Column in "obs_tbl" specifying sample ID (str)
#' @param ci Confidence interval level (numeric between 0 and 1, default 0.95)
#'
#' @return ggplot object of a forest plot
#'
#' @import dplyr
#' @import ggplot2
#'
#' @export
plot_sdse <- function(sdse_tbl, colSample, ci = 0.95, xlim = c(-0.5, 1.5)) {
  n_se <- qnorm(1 - (1 - ci) / 2)
  p_tbl <- sdse_tbl %>%
    filter(
      grepl(":Celltype.\\(Intercept\\)", rowname)
    ) %>%
    mutate(
      rowname = sub(paste0("^", colSample, "$"), "Residual", sub("theta.(.*):Celltype.*", "\\1", rowname))
    ) %>%
    arrange(sd) %>%
    mutate(
      rowname = factor(rowname, levels = c("Residual", rowname[rowname != "Residual"]))
    ) %>%
    mutate(ci_l = sd - se * n_se, ci_h = sd + se * n_se)
  p <- (
    ggplot(p_tbl, aes(x = sd, y = rowname)) +
      geom_point(shape = 18, size = 3) +
      geom_errorbarh(aes(xmin = ci_l, xmax = ci_h), height = 0) +
      geom_vline(xintercept = 0, lty = 2) +
      xlab("Square root of explained variance") +
      coord_cartesian(xlim = xlim) +
      theme_bw() +
      theme(axis.title.y = element_blank())
  )
}

#' Plot estimated random effects of variables
#'
#' This function plots random effects of variables on cell type composition as a dot plot
#'
#' @param ranef_tbl Table of random effect estimates (mean and sd) extracted from fitted model
#'     (data.frame-like object)
#' @param vars A list specifying required categorical sample metadata variables and their order,
#'     e.g. list(size=c('small', 'medium', 'big'), price=c('cheap', 'expensive'))
#' @param celltypes If specified, only keep those cell types (vector of str)
#' @param celltype_order Determine how cell types are ordered. Either "hclust" which orders by
#'     hierarchical clustering, or a vector of cell types. (str or vector of str)
#' @param references If specified, fold changes are calculated relative to the specified level
#'     instead of global mean. Must be a list, e.g. list(size='small', price='cheap')
#' @param maxFC Cap fold change by this value (numeric, default 3)
#' @param LTSR2p Whether to convert LTSR to p value (logical, default FALSE)
#' @param filterLtsr Only keeps cell types of which at least one LTSR is greater or equal to
#'     specified value. (numeric, default 0)
#' @param swap_axes Whether to swap axis when plotting (logical, default FALSE)
#'
#' @return ggplot object of a dot plot
#'
#' @import dplyr
#' @import ggplot2
#' @importFrom scales squish
#'
#' @export
plot_ranef <- function(ranef_tbl, vars, celltypes = NULL, celltype_order = "hclust", references = NULL,
                       maxFC = 3, LTSR2p = F, highlightLtsr = 0.0, filterLtsr = 0.0, swap_axes = F) {
  ranef_tbl <- .getCondValLtsr(ranef_tbl, vars, celltypes = celltypes, references = references)

  condval_mat <- ranef_tbl %>%
    select(
      Celltype, grpval, condval
    ) %>%
    spread(
      "grpval", "condval"
    ) %>%
    column_to_rownames(
      var = "Celltype"
    ) %>%
    as.matrix()
  if (length(celltype_order) == 1 && celltype_order == "hclust") {
    dendy <- hclust(dist(condval_mat))
    ordered_celltype <- rownames(condval_mat)[dendy$ord]
  } else if (!is.null(celltype_order) && length(celltype_order) == dim(condval_mat)[1]) {
    ordered_celltype <- celltype_order
  }

  ranef_tbl <- ranef_tbl %>% mutate(
    Celltype = factor(Celltype, levels = ordered_celltype),
    condval = condval %>% pmin(log(maxFC)) %>% pmax(log(1 / maxFC)),
    ltsr = ltsr %>% pmin(0.9999) %>% pmax(0.5)
  )

  if (swap_axes) {
    ranef_tbl$Celltype <- factor(ranef_tbl$Celltype, levels = rev(levels(ranef_tbl$Celltype)))
    ranef_tbl$grpval <- factor(ranef_tbl$grpval, levels = rev(levels(ranef_tbl$grpval)))
  }

  if (filterLtsr > 0) {
    filtered_celltypes <- ranef_tbl %>%
      group_by(Celltype) %>%
      summarise(maxLtsr = max(ltsr)) %>%
      dplyr::filter(maxLtsr >= filterLtsr) %>%
      select(Celltype) %>%
      unlist(use.names = F)
    ranef_tbl <- ranef_tbl %>% dplyr::filter(Celltype %in% filtered_celltypes)
  }

  geom_dots <- geom_point(
    aes(
      fill = log2(exp(condval)),
      size = -log10(1 - ltsr)
    ),
    color = "white",
    shape = 21
  )

  if (swap_axes) {
    p <- (
      ggplot(ranef_tbl, aes(y = grpval, x = Celltype)) +
        facet_grid(grpvar ~ ., scales = "free_y", space = "free_y", switch = "x") +
        geom_dots
    )
  } else {
    p <- (
      ggplot(ranef_tbl, aes(x = grpval, y = Celltype)) +
        facet_grid(. ~ grpvar, scales = "free_x", space = "free_x", switch = "x") +
        geom_dots
    )
  }

  p <- (
    p + scale_fill_distiller(
      palette = "RdBu",
      limits = log2(c(1 / maxFC, maxFC)),
      breaks = log2(c(1 / maxFC, maxFC)),
      labels = c(paste0("1/", maxFC), maxFC),
      oob = squish,
      guide = guide_colorbar(
        title = "Fold change", title.position = "top", direction = "horizontal",
        barwidth = 5, barheight = 0.75, raster = F, order = 1)
    )
    + scale_size(
      limits = -log10(1 - c(0.5, 0.9999)),
      breaks = -log10(1 - c(0.5, 0.9, 0.99, 0.999, 0.9999)),
      range = c(0.5, 9),
      labels = ifelse(
        rep(LTSR2p, 5),
        c("0.5", "0.1", "0.01", "0.001", "<0.0001"),
        c("0.5", "0.9", "0.99", "0.999", ">0.9999")
      ),
      guide = guide_legend(
        title = ifelse(LTSR2p, "p", "LTSR"), reverse = T, order = 2,
        override.aes = list(fill = "black", color = "white")
      )
    )
    + theme_bw()
    + theme(
      axis.title.x = element_blank(),
      axis.title.y = element_blank(),
      strip.placement = "outside",
      strip.background = element_blank(),
      legend.spacing.y = unit(0.5, "line")
    )
  )

  if (highlightLtsr > 0) {
    p <- (
      p + geom_point(
        aes(
          color = ltsr > highlightLtsr,
          alpha = ltsr > highlightLtsr
        ),
        shape = 21, size = 9
      )
      + scale_color_manual(
        label = c(
          "", ifelse(LTSR2p, paste0("p < ", 1 - highlightLtsr), paste0("LTSR > ", highlightLtsr))
        ),
        values = c("white", "red"),
        guide = guide_legend(title = NULL, override.aes = list(size = 9), reverse = T, order = 3)
      )
      + scale_alpha_manual(values = c(0, 1), guide = F)
    )
  }

  p
}

#' Theme that mimics dotplots generated by Natsuhiko's code
#'
#' This function sets a number of options in ggplot2::theme() to mimic the style
#' of dotplots generated by Natsuhiko's code
#'
#' @param ... options passed to ggplot2::theme()
#'
#' @importFrom ggplot2 theme
#'
#' @export
theme_ctca <- function(...) {
  theme(
    axis.text.x = element_text(angle = 45, hjust = 1),
    axis.ticks = element_blank(),
    strip.text = element_blank(),
    panel.grid = element_blank(),
    panel.border = element_blank(),
    ...
  )
}

# %% [markdown]
# #### Material

# %%
ltsr <- CellTypeCompositionAnalysis(obs_tbl=meta, 
                            colSample='ID', 
                            colCelltype='MP_Assignment', 
                            colVarCats=c('Material'))
# Out:
# input prepared
# I(Y) ~ (1|Celltype)+(1|ID)+(1|Material)+(1|ID:Celltype)+(1|Material:Celltype)
# model constructed
# boundary (singular) fit: see help('isSingular')
# model fitted

# %%
options(repr.plot.height = 5, repr.plot.width = 3)
p <- plot_sdse(ltsr$sdse, 'ID')
p
# Out:
# plot without title

# %%
options(repr.plot.height = 5, repr.plot.width = 3)
plt_gen = plot_ranef(ltsr$ranef, 
                     vars=list(Material=c('cell', 'nuclei')),
                    celltypes=c('MP4','MP10','MP7','MP2','MP8','MP9'
                                ),
                    celltype_order=rev(c('MP4','MP10','MP7','MP2','MP8','MP9'
                                )),
                     highlightLtsr = 0.9) + theme_pubr(legend = "right") +
   theme(panel.grid.major=element_blank(), panel.grid.minor=element_blank(),
         axis.text.x=element_text(angle=60, vjust=1, hjust=1))
plt_gen
# Out:
# Warning message:
# “The `raster` argument of `guide_colourbar()` is deprecated as of ggplot2 3.5.0.
# ℹ Please use the `display` argument instead.”
# Warning message:
# “The `guide` argument in `scale_*()` cannot be `FALSE`. This was deprecated in ggplot2 3.3.4.
# ℹ Please use "none" instead.”
# plot without title

# %% [markdown]
# ggsave('figures/LTSR_myeloid_material_FINAL.pdf', width = 3, height = 5)

# %% [markdown]
# #### Clinical_status

# %%
ltsr <- CellTypeCompositionAnalysis(obs_tbl=meta %>% filter(Clinical_status %in% c('Primary', 'Recurrence')), 
                            colSample='ID', 
                            colCelltype='MP_Assignment', 
                            colVarCats=c('Clinical_status'))
# Out:
# input prepared
# I(Y) ~ (1|Celltype)+(1|ID)+(1|Clinical_status)+(1|ID:Celltype)+(1|Clinical_status:Celltype)
# model constructed
# boundary (singular) fit: see help('isSingular')
# model fitted

# %%
p <- plot_sdse(ltsr$sdse, 'ID')
p
# Out:
# plot without title

# %%
options(repr.plot.height = 5, repr.plot.width = 3)
plt_gen = plot_ranef(ltsr$ranef, 
                     vars=list(Clinical_status=c('Primary', 'Recurrence')),
                    celltypes=c('MP4','MP10','MP7','MP2','MP8','MP9'
                                ),
                    celltype_order=rev(c('MP4','MP10','MP7','MP2','MP8','MP9'
                                )),
                     highlightLtsr = 0.9) + theme_pubr(legend = "right") +
   theme(panel.grid.major=element_blank(), panel.grid.minor=element_blank(),
         axis.text.x=element_text(angle=60, vjust=1, hjust=1))
plt_gen
# Out:
# plot without title

# %%
ggsave('figures/LTSR_myeloid_Clinical_status_subset_MP_FINAL.pdf', width = 3.2, height = 3.5)
