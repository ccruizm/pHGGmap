# %% [markdown]
# `conda activate r_env_standr`

# %% [markdown]
# Taken from https://doi.org/10.1038/s43587-024-00613-3

# %%
suppressPackageStartupMessages({
    library(reticulate)
    library(ggplot2)
    library(Seurat)
    library(dplyr)
    library(tidyr)
    library(tibble)
    library(stringr)
    library(lme4)
    library(numDeriv)
    library(dittoSeq)
    library(future)
    library(data.table)
    library(scales)
    plan("multicore", workers = 12)
    options(future.globals.maxSize = 1000 * 1024^5)
    options(stringsAsFactors = FALSE)
    set.seed(123)
})
# Out:
# Warning message:
# “package ‘ggplot2’ was built under R version 4.3.3”

# %%
malignant <- readRDS('/projects/0/einf2548/cruiz/dmg/data/malignant_rna.rds')
malignant
# Out:
# An object of class Seurat
# 19248 features across 291695 samples within 1 assay
# Active assay: RNA (19248 features, 2000 variable features)
#  3 layers present: counts, data, scale.data
#  2 dimensional reductions calculated: pca, umap

# %%
malignant <- AddMetaData(malignant , readRDS('data//nmf_assigment_malignant_no_core_programs.rds'))

# %%
malignant <- subset(malignant, iCNV == 'tumor')
malignant
# Out:
# An object of class Seurat
# 19248 features across 258867 samples within 1 assay
# Active assay: RNA (19248 features, 2000 variable features)
#  3 layers present: counts, data, scale.data
#  2 dimensional reductions calculated: pca, umap

# %%
malignant$Material <- recode(malignant$Batch_for_correction,
                          '10Xv1_nuclei_multiome' = 'nuclei',
                           '10Xv3_cell_rna'='cell',
                           '10Xv3_nuclei_rna'='nuclei',
                           '10Xv3.1_nuclei_rna'='nuclei')

# %%
options(repr.plot.height = 5, repr.plot.width = 3)

malignant$MP_Assignment <- sub("_1$", "", malignant$MP_Assignment)
malignant$MP_Assignment <- sub("_", "", malignant$MP_Assignment)

malignant$MP_Assignment <- factor(malignant$MP_Assignment,
                                 levels=c('MP4', 'MP11','MP2',
                            'MP5',
                            'MP3','MP13','MP8',
                            'MP12',
                            'MP9','MP7','unresolved'
                                ))

# %%
meta <- malignant@meta.data
meta
# Out:
#                                            nCount_RNA nFeature_RNA nCount_RAW
# BT042_pons_2_AGGCCACCATGGCCAC-1             1020       731          1179
# BT042_pons_2_CCCTCAAAGTAGCTCT-1              897       673          1044
# BT042_pons_2_CTCCGATTCGGCCTTT-1              847       613           994
# BT042_pons_2_TGATCAGTCCTACAAG-1              827       637          1006
# BT042_pons_2_ATCACTTAGACATGCG-1              627       504           828
# BT042_pons_2_GAAATGAGTACTAAGA-1              531       424           740
# BT042_pons_2_CATCCGTGTTAAGACA-1              541       424           740
# BT042_pons_2_TCTATCAGTGGAGGTT-1              527       432           737
# BT042_pons_2_TCTGGCTTCGAGAACG-1              278       230           505
# BT042_pons_2_CCGATGGTCTGTAACG-1              365       294           563
# BT042_pons_2_GTTCGCTAGATACCAA-1              278       241           486
# BT042_pons_2_GCAGCCAAGGACAAGA-1              336       285           504
# BT042_pons_2_TGGCGTGCATACTGAC-1              276       239           493
# BT042_pons_2_TTCTTGATCGCAAGAG-1              289       260           448
# BT072_region_1_TTTGGTTTCGACACTA-1          25978      5589         26011
# BT072_region_1_CTTCTAAGTTACCCTC-1          22102      5634         22192
# BT072_region_1_CCATCACCAGCAATTC-1          21269      4155         21281
# BT072_region_1_CCCTCTCTCGAGTCTA-1          19056      5039         19072
# BT072_region_1_ACTATTCTCCTACCGT-1          17509      4634         17544
# BT072_region_1_ACGTAACCAGGCTTGC-1          20182      5660         20217
# BT072_region_1_ATTCAGGCATGCCGCA-1          18317      4505         18332
# BT072_region_1_AATCACGGTCACAATC-1          19635      4531         19649
# BT072_region_1_GACACGCTCCACAAGT-1          18723      4505         18748
# BT072_region_1_GACTCAATCTAATTCC-1          17796      4401         17824
# BT072_region_1_ATATCCTAGCCTGACC-1          18227      3908         18247
# BT072_region_1_CTGCATCTCTAAGCGT-1          18507      4784         18543
# BT072_region_1_TGCAGGCCAGCTACAT-1          17696      4206         17717
# BT072_region_1_GATCAGTTCGCCTATC-1          18124      4330         18176
# BT072_region_1_CTACTATTCCGAACGC-1          16424      3790         16448
# BT072_region_1_GCGGAAACAATTCTCT-1          16083      4179         16096
# ⋮                                          ⋮          ⋮            ⋮
# multiome_P-6774_S-10146_TGCTAACAGGTCCTAG-1 284        240          714
# multiome_P-6774_S-10146_GAAACTGAGGCCGGAA-1 346        275          722
# multiome_P-6774_S-10146_GAAAGCCAGTTTCCTG-1 290        203          704
# multiome_P-6774_S-10146_CGTTAACAGGCGAAAC-1 337        262          698
# multiome_P-6774_S-10146_GGCGCTAGTGCATTTC-1 314        222          729
# multiome_P-6774_S-10146_AAGGTCAAGTTTGGTA-1 314        254          682
# multiome_P-6774_S-10146_CCAAACTAGCTATGAC-1 294        207          712
# multiome_P-6774_S-10146_GCAGGCTTCCTTGTTG-1 308        235          682
# multiome_P-6774_S-10146_GCCTGTGCACAAAGGT-1 257        203          698
# multiome_P-6774_S-10146_GATTACGGTAACGTGC-1 327        224          721
# multiome_P-6774_S-10146_CCTAATAAGATTGAGG-1 297        237          697
# multiome_P-6774_S-10146_GCGGATACACTGGCTG-1 294        232          671
# multiome_P-6774_S-10146_CTACCGGCACATAGCC-1 271        202          705
# multiome_P-6774_S-10146_GCATTAGGTGCTCCAC-1 286        216          666
# multiome_P-6774_S-10146_GTGCAAGCATAATGTC-1 296        238          662
# multiome_P-6774_S-10146_TGTATCGCATAGCGAG-1 281        228          684
# multiome_P-6774_S-10146_TACTAAGTCGTTAACA-1 303        248          662
# multiome_P-6774_S-10146_GCAATAGAGATAGACG-1 285        209          684
# multiome_P-6774_S-10146_TAGTAAGCAGGTTCAC-1 302        238          657
# multiome_P-6774_S-10146_TTGGATTCAGCATGGA-1 305        258          660
# multiome_P-6774_S-10146_TGGATTCAGTGAACAG-1 269        227          646
# multiome_P-6774_S-10146_AATGTCCAGGCCGGAA-1 271        220          632
# multiome_P-6774_S-10146_GGAGCGATCATAGCCG-1 307        246          661
# multiome_P-6774_S-10146_GACTAATGTGTTGCTT-1 262        221          630
# multiome_P-6774_S-10146_GGAGTGAGTAAACAAG-1 279        231          620
# multiome_P-6774_S-10146_CGAATCTAGTTTAACG-1 304        263          609
# multiome_P-6774_S-10146_GCCTCAAAGGATTGCT-1 260        204          609
# multiome_P-6774_S-10146_ACTTAGTCACTAGGTC-1 285        259          601
# multiome_P-6774_S-10146_TCAGCGATCCGTGACA-1 275        202          604
# multiome_P-6774_S-10146_CCTGTTGGTGACCTGG-1 237        209          543
#                                            nFeature_RAW DF.class DF.score
# BT042_pons_2_AGGCCACCATGGCCAC-1             836         Singlet  0.15217391
# BT042_pons_2_CCCTCAAAGTAGCTCT-1             781         Singlet  0.15217391
# BT042_pons_2_CTCCGATTCGGCCTTT-1             709         Singlet  0.11739130
# BT042_pons_2_TGATCAGTCCTACAAG-1             753         Singlet  0.12608696
# BT042_pons_2_ATCACTTAGACATGCG-1             655         Singlet  0.13043478
# BT042_pons_2_GAAATGAGTACTAAGA-1             585         Singlet  0.10869565
# BT042_pons_2_CATCCGTGTTAAGACA-1             593         Singlet  0.13478261
# BT042_pons_2_TCTATCAGTGGAGGTT-1             582         Singlet  0.13478261
# BT042_pons_2_TCTGGCTTCGAGAACG-1             422         Singlet  0.11304348
# BT042_pons_2_CCGATGGTCTGTAACG-1             462         Singlet  0.11304348
# BT042_pons_2_GTTCGCTAGATACCAA-1             399         Singlet  0.11304348
# BT042_pons_2_GCAGCCAAGGACAAGA-1             425         Singlet  0.10000000
# BT042_pons_2_TGGCGTGCATACTGAC-1             419         Singlet  0.13043478
# BT042_pons_2_TTCTTGATCGCAAGAG-1             397         Singlet  0.09565217
# BT072_region_1_TTTGGTTTCGACACTA-1          5599         Singlet  0.25000000
# BT072_region_1_CTTCTAAGTTACCCTC-1          5669         Singlet  0.13636364
# BT072_region_1_CCATCACCAGCAATTC-1          4159         Singlet  0.25000000
# BT072_region_1_CCCTCTCTCGAGTCTA-1          5048         Singlet  0.29545455
# BT072_region_1_ACTATTCTCCTACCGT-1          4636         Singlet  0.29545455
# BT072_region_1_ACGTAACCAGGCTTGC-1          5672         Singlet  0.27272727
# BT072_region_1_ATTCAGGCATGCCGCA-1          4514         Singlet  0.18181818
# BT072_region_1_AATCACGGTCACAATC-1          4538         Singlet  0.20454545
# BT072_region_1_GACACGCTCCACAAGT-1          4515         Singlet  0.18181818
# BT072_region_1_GACTCAATCTAATTCC-1          4409         Singlet  0.18181818
# BT072_region_1_ATATCCTAGCCTGACC-1          3918         Singlet  0.15909091
# BT072_region_1_CTGCATCTCTAAGCGT-1          4790         Singlet  0.31818182
# BT072_region_1_TGCAGGCCAGCTACAT-1          4214         Singlet  0.13636364
# BT072_region_1_GATCAGTTCGCCTATC-1          4355         Singlet  0.09090909
# BT072_region_1_CTACTATTCCGAACGC-1          3804         Singlet  0.25000000
# BT072_region_1_GCGGAAACAATTCTCT-1          4186         Singlet  0.25000000
# ⋮                                          ⋮            ⋮        ⋮
# multiome_P-6774_S-10146_TGCTAACAGGTCCTAG-1 597          Singlet  0.08716187
# multiome_P-6774_S-10146_GAAACTGAGGCCGGAA-1 587          Singlet  0.23958781
# multiome_P-6774_S-10146_GAAAGCCAGTTTCCTG-1 561          Singlet  0.13009875
# multiome_P-6774_S-10146_CGTTAACAGGCGAAAC-1 560          Singlet  0.24388149
# multiome_P-6774_S-10146_GGCGCTAGTGCATTTC-1 573          Singlet  0.03263203
# multiome_P-6774_S-10146_AAGGTCAAGTTTGGTA-1 564          Singlet  0.19708029
# multiome_P-6774_S-10146_CCAAACTAGCTATGAC-1 559          Singlet  0.08501503
# multiome_P-6774_S-10146_GCAGGCTTCCTTGTTG-1 543          Singlet  0.26620867
# multiome_P-6774_S-10146_GCCTGTGCACAAAGGT-1 584          Singlet  0.03091456
# multiome_P-6774_S-10146_GATTACGGTAACGTGC-1 565          Singlet  0.04723057
# multiome_P-6774_S-10146_CCTAATAAGATTGAGG-1 567          Singlet  0.04121941
# multiome_P-6774_S-10146_GCGGATACACTGGCTG-1 550          Singlet  0.21897810
# multiome_P-6774_S-10146_CTACCGGCACATAGCC-1 573          Singlet  0.07471018
# multiome_P-6774_S-10146_GCATTAGGTGCTCCAC-1 534          Singlet  0.23100043
# multiome_P-6774_S-10146_GTGCAAGCATAATGTC-1 548          Singlet  0.19278660
# multiome_P-6774_S-10146_TGTATCGCATAGCGAG-1 561          Singlet  0.03649635
# multiome_P-6774_S-10146_TACTAAGTCGTTAACA-1 557          Singlet  0.24431086
# multiome_P-6774_S-10146_GCAATAGAGATAGACG-1 524          Singlet  0.07213396
# multiome_P-6774_S-10146_TAGTAAGCAGGTTCAC-1 540          Singlet  0.24302276
# multiome_P-6774_S-10146_TTGGATTCAGCATGGA-1 544          Singlet  0.13782739
# multiome_P-6774_S-10146_TGGATTCAGTGAACAG-1 548          Singlet  0.11635895
# multiome_P-6774_S-10146_AATGTCCAGGCCGGAA-1 522          Singlet  0.14255045
# multiome_P-6774_S-10146_GGAGCGATCATAGCCG-1 545          Singlet  0.03778446
# multiome_P-6774_S-10146_GACTAATGTGTTGCTT-1 536          Singlet  0.13310434
# multiome_P-6774_S-10146_GGAGTGAGTAAACAAG-1 527          Singlet  0.21940747
# multiome_P-6774_S-10146_CGAATCTAGTTTAACG-1 525          Singlet  0.15242593
# multiome_P-6774_S-10146_GCCTCAAAGGATTGCT-1 495          Singlet  0.24602834
# multiome_P-6774_S-10146_ACTTAGTCACTAGGTC-1 526          Singlet  0.10004294
# multiome_P-6774_S-10146_TCAGCGATCCGTGACA-1 481          Singlet  0.03864319
# multiome_P-6774_S-10146_CCTGTTGGTGACCTGG-1 489          Singlet  0.11807643
#                                            scDblFinder.class scDblFinder.score
# BT042_pons_2_AGGCCACCATGGCCAC-1            Singlet           0.05966683
# BT042_pons_2_CCCTCAAAGTAGCTCT-1            Singlet           0.07683539
# BT042_pons_2_CTCCGATTCGGCCTTT-1            Singlet           0.02298219
# BT042_pons_2_TGATCAGTCCTACAAG-1            Singlet           0.01525696
# BT042_pons_2_ATCACTTAGACATGCG-1            Singlet           0.03680524
# BT042_pons_2_GAAATGAGTACTAAGA-1            Singlet           0.03842901
# BT042_pons_2_CATCCGTGTTAAGACA-1            Singlet           0.03842901
# BT042_pons_2_TCTATCAGTGGAGGTT-1            Singlet           0.01356047
# BT042_pons_2_TCTGGCTTCGAGAACG-1            Singlet           0.03209129
# BT042_pons_2_CCGATGGTCTGTAACG-1            Singlet           0.02325889
# BT042_pons_2_GTTCGCTAGATACCAA-1            Singlet           0.03680524
# BT042_pons_2_GCAGCCAAGGACAAGA-1            Singlet           0.03680524
# BT042_pons_2_TGGCGTGCATACTGAC-1            Singlet           0.02298219
# BT042_pons_2_TTCTTGATCGCAAGAG-1            Singlet           0.03209129
# BT072_region_1_TTTGGTTTCGACACTA-1          Singlet           0.37402776
# BT072_region_1_CTTCTAAGTTACCCTC-1          Singlet           0.26810941
# BT072_region_1_CCATCACCAGCAATTC-1          Singlet           0.68720722
# BT072_region_1_CCCTCTCTCGAGTCTA-1          Singlet           0.53357679
# BT072_region_1_ACTATTCTCCTACCGT-1          Singlet           0.22547771
# BT072_region_1_ACGTAACCAGGCTTGC-1          Singlet           0.11019740
# BT072_region_1_ATTCAGGCATGCCGCA-1          Singlet           0.20776209
# BT072_region_1_AATCACGGTCACAATC-1          Singlet           0.60341781
# BT072_region_1_GACACGCTCCACAAGT-1          Singlet           0.21692978
# BT072_region_1_GACTCAATCTAATTCC-1          Singlet           0.42852744
# BT072_region_1_ATATCCTAGCCTGACC-1          Singlet           0.55193424
# BT072_region_1_CTGCATCTCTAAGCGT-1          Singlet           0.86670399
# BT072_region_1_TGCAGGCCAGCTACAT-1          Singlet           0.11508778
# BT072_region_1_GATCAGTTCGCCTATC-1          Singlet           0.24014036
# BT072_region_1_CTACTATTCCGAACGC-1          Singlet           0.57708156
# BT072_region_1_GCGGAAACAATTCTCT-1          Singlet           0.40044403
# ⋮                                          ⋮                 ⋮
# multiome_P-6774_S-10146_TGCTAACAGGTCCTAG-1 Singlet           6.078985e-05
# multiome_P-6774_S-10146_GAAACTGAGGCCGGAA-1 Singlet           1.165431e-04
# multiome_P-6774_S-10146_GAAAGCCAGTTTCCTG-1 Singlet           5.937665e-05
# multiome_P-6774_S-10146_CGTTAACAGGCGAAAC-1 Singlet           6.360566e-05
# multiome_P-6774_S-10146_GGCGCTAGTGCATTTC-1 Singlet           3.635921e-04
# multiome_P-6774_S-10146_AAGGTCAAGTTTGGTA-1 Singlet           1.144285e-04
# multiome_P-6774_S-10146_CCAAACTAGCTATGAC-1 Singlet           3.973769e-04
# multiome_P-6774_S-10146_GCAGGCTTCCTTGTTG-1 Singlet           1.163947e-04
# multiome_P-6774_S-10146_GCCTGTGCACAAAGGT-1 Singlet           1.182709e-04
# multiome_P-6774_S-10146_GATTACGGTAACGTGC-1 Singlet           4.104942e-04
# multiome_P-6774_S-10146_CCTAATAAGATTGAGG-1 Singlet           6.585094e-04
# multiome_P-6774_S-10146_GCGGATACACTGGCTG-1 Singlet           2.731083e-04
# multiome_P-6774_S-10146_CTACCGGCACATAGCC-1 Singlet           1.761884e-04
# multiome_P-6774_S-10146_GCATTAGGTGCTCCAC-1 Singlet           1.675549e-04
# multiome_P-6774_S-10146_GTGCAAGCATAATGTC-1 Singlet           6.973551e-05
# multiome_P-6774_S-10146_TGTATCGCATAGCGAG-1 Singlet           3.578383e-04
# multiome_P-6774_S-10146_TACTAAGTCGTTAACA-1 Singlet           3.187806e-04
# multiome_P-6774_S-10146_GCAATAGAGATAGACG-1 Singlet           6.174150e-05
# multiome_P-6774_S-10146_TAGTAAGCAGGTTCAC-1 Singlet           7.626754e-05
# multiome_P-6774_S-10146_TTGGATTCAGCATGGA-1 Singlet           6.415898e-05
# multiome_P-6774_S-10146_TGGATTCAGTGAACAG-1 Singlet           1.194274e-04
# multiome_P-6774_S-10146_AATGTCCAGGCCGGAA-1 Singlet           1.229871e-04
# multiome_P-6774_S-10146_GGAGCGATCATAGCCG-1 Singlet           3.297045e-04
# multiome_P-6774_S-10146_GACTAATGTGTTGCTT-1 Singlet           7.825657e-05
# multiome_P-6774_S-10146_GGAGTGAGTAAACAAG-1 Singlet           1.396935e-04
# multiome_P-6774_S-10146_CGAATCTAGTTTAACG-1 Singlet           6.602362e-05
# multiome_P-6774_S-10146_GCCTCAAAGGATTGCT-1 Singlet           7.201255e-05
# multiome_P-6774_S-10146_ACTTAGTCACTAGGTC-1 Singlet           2.502547e-05
# multiome_P-6774_S-10146_TCAGCGATCCGTGACA-1 Singlet           3.583328e-04
# multiome_P-6774_S-10146_CCTGTTGGTGACCTGG-1 Singlet           7.255303e-05
#                                            ID
# BT042_pons_2_AGGCCACCATGGCCAC-1            T18-90532
# BT042_pons_2_CCCTCAAAGTAGCTCT-1            T18-90532
# BT042_pons_2_CTCCGATTCGGCCTTT-1            T18-90532
# BT042_pons_2_TGATCAGTCCTACAAG-1            T18-90532
# BT042_pons_2_ATCACTTAGACATGCG-1            T18-90532
# BT042_pons_2_GAAATGAGTACTAAGA-1            T18-90532
# BT042_pons_2_CATCCGTGTTAAGACA-1            T18-90532
# BT042_pons_2_TCTATCAGTGGAGGTT-1            T18-90532
# BT042_pons_2_TCTGGCTTCGAGAACG-1            T18-90532
# BT042_pons_2_CCGATGGTCTGTAACG-1            T18-90532
# BT042_pons_2_GTTCGCTAGATACCAA-1            T18-90532
# BT042_pons_2_GCAGCCAAGGACAAGA-1            T18-90532
# BT042_pons_2_TGGCGTGCATACTGAC-1            T18-90532
# BT042_pons_2_TTCTTGATCGCAAGAG-1            T18-90532
# BT072_region_1_TTTGGTTTCGACACTA-1          T19-90171
# BT072_region_1_CTTCTAAGTTACCCTC-1          T19-90171
# BT072_region_1_CCATCACCAGCAATTC-1          T19-90171
# BT072_region_1_CCCTCTCTCGAGTCTA-1          T19-90171
# BT072_region_1_ACTATTCTCCTACCGT-1          T19-90171
# BT072_region_1_ACGTAACCAGGCTTGC-1          T19-90171
# BT072_region_1_ATTCAGGCATGCCGCA-1          T19-90171
# BT072_region_1_AATCACGGTCACAATC-1          T19-90171
# BT072_region_1_GACACGCTCCACAAGT-1          T19-90171
# BT072_region_1_GACTCAATCTAATTCC-1          T19-90171
# BT072_region_1_ATATCCTAGCCTGACC-1          T19-90171
# BT072_region_1_CTGCATCTCTAAGCGT-1          T19-90171
# BT072_region_1_TGCAGGCCAGCTACAT-1          T19-90171
# BT072_region_1_GATCAGTTCGCCTATC-1          T19-90171
# BT072_region_1_CTACTATTCCGAACGC-1          T19-90171
# BT072_region_1_GCGGAAACAATTCTCT-1          T19-90171
# ⋮                                          ⋮
# multiome_P-6774_S-10146_TGCTAACAGGTCCTAG-1 P-6774_S-10146
# multiome_P-6774_S-10146_GAAACTGAGGCCGGAA-1 P-6774_S-10146
# multiome_P-6774_S-10146_GAAAGCCAGTTTCCTG-1 P-6774_S-10146
# multiome_P-6774_S-10146_CGTTAACAGGCGAAAC-1 P-6774_S-10146
# multiome_P-6774_S-10146_GGCGCTAGTGCATTTC-1 P-6774_S-10146
# multiome_P-6774_S-10146_AAGGTCAAGTTTGGTA-1 P-6774_S-10146
# multiome_P-6774_S-10146_CCAAACTAGCTATGAC-1 P-6774_S-10146
# multiome_P-6774_S-10146_GCAGGCTTCCTTGTTG-1 P-6774_S-10146
# multiome_P-6774_S-10146_GCCTGTGCACAAAGGT-1 P-6774_S-10146
# multiome_P-6774_S-10146_GATTACGGTAACGTGC-1 P-6774_S-10146
# multiome_P-6774_S-10146_CCTAATAAGATTGAGG-1 P-6774_S-10146
# multiome_P-6774_S-10146_GCGGATACACTGGCTG-1 P-6774_S-10146
# multiome_P-6774_S-10146_CTACCGGCACATAGCC-1 P-6774_S-10146
# multiome_P-6774_S-10146_GCATTAGGTGCTCCAC-1 P-6774_S-10146
# multiome_P-6774_S-10146_GTGCAAGCATAATGTC-1 P-6774_S-10146
# multiome_P-6774_S-10146_TGTATCGCATAGCGAG-1 P-6774_S-10146
# multiome_P-6774_S-10146_TACTAAGTCGTTAACA-1 P-6774_S-10146
# multiome_P-6774_S-10146_GCAATAGAGATAGACG-1 P-6774_S-10146
# multiome_P-6774_S-10146_TAGTAAGCAGGTTCAC-1 P-6774_S-10146
# multiome_P-6774_S-10146_TTGGATTCAGCATGGA-1 P-6774_S-10146
# multiome_P-6774_S-10146_TGGATTCAGTGAACAG-1 P-6774_S-10146
# multiome_P-6774_S-10146_AATGTCCAGGCCGGAA-1 P-6774_S-10146
# multiome_P-6774_S-10146_GGAGCGATCATAGCCG-1 P-6774_S-10146
# multiome_P-6774_S-10146_GACTAATGTGTTGCTT-1 P-6774_S-10146
# multiome_P-6774_S-10146_GGAGTGAGTAAACAAG-1 P-6774_S-10146
# multiome_P-6774_S-10146_CGAATCTAGTTTAACG-1 P-6774_S-10146
# multiome_P-6774_S-10146_GCCTCAAAGGATTGCT-1 P-6774_S-10146
# multiome_P-6774_S-10146_ACTTAGTCACTAGGTC-1 P-6774_S-10146
# multiome_P-6774_S-10146_TCAGCGATCCGTGACA-1 P-6774_S-10146
# multiome_P-6774_S-10146_CCTGTTGGTGACCTGG-1 P-6774_S-10146
#                                            SampleID                ⋯
# BT042_pons_2_AGGCCACCATGGCCAC-1            BT042_pons_2            ⋯
# BT042_pons_2_CCCTCAAAGTAGCTCT-1            BT042_pons_2            ⋯
# BT042_pons_2_CTCCGATTCGGCCTTT-1            BT042_pons_2            ⋯
# BT042_pons_2_TGATCAGTCCTACAAG-1            BT042_pons_2            ⋯
# BT042_pons_2_ATCACTTAGACATGCG-1            BT042_pons_2            ⋯
# BT042_pons_2_GAAATGAGTACTAAGA-1            BT042_pons_2            ⋯
# BT042_pons_2_CATCCGTGTTAAGACA-1            BT042_pons_2            ⋯
# BT042_pons_2_TCTATCAGTGGAGGTT-1            BT042_pons_2            ⋯
# BT042_pons_2_TCTGGCTTCGAGAACG-1            BT042_pons_2            ⋯
# BT042_pons_2_CCGATGGTCTGTAACG-1            BT042_pons_2            ⋯
# BT042_pons_2_GTTCGCTAGATACCAA-1            BT042_pons_2            ⋯
# BT042_pons_2_GCAGCCAAGGACAAGA-1            BT042_pons_2            ⋯
# BT042_pons_2_TGGCGTGCATACTGAC-1            BT042_pons_2            ⋯
# BT042_pons_2_TTCTTGATCGCAAGAG-1            BT042_pons_2            ⋯
# BT072_region_1_TTTGGTTTCGACACTA-1          BT072_region_1          ⋯
# BT072_region_1_CTTCTAAGTTACCCTC-1          BT072_region_1          ⋯
# BT072_region_1_CCATCACCAGCAATTC-1          BT072_region_1          ⋯
# BT072_region_1_CCCTCTCTCGAGTCTA-1          BT072_region_1          ⋯
# BT072_region_1_ACTATTCTCCTACCGT-1          BT072_region_1          ⋯
# BT072_region_1_ACGTAACCAGGCTTGC-1          BT072_region_1          ⋯
# BT072_region_1_ATTCAGGCATGCCGCA-1          BT072_region_1          ⋯
# BT072_region_1_AATCACGGTCACAATC-1          BT072_region_1          ⋯
# BT072_region_1_GACACGCTCCACAAGT-1          BT072_region_1          ⋯
# BT072_region_1_GACTCAATCTAATTCC-1          BT072_region_1          ⋯
# BT072_region_1_ATATCCTAGCCTGACC-1          BT072_region_1          ⋯
# BT072_region_1_CTGCATCTCTAAGCGT-1          BT072_region_1          ⋯
# BT072_region_1_TGCAGGCCAGCTACAT-1          BT072_region_1          ⋯
# BT072_region_1_GATCAGTTCGCCTATC-1          BT072_region_1          ⋯
# BT072_region_1_CTACTATTCCGAACGC-1          BT072_region_1          ⋯
# BT072_region_1_GCGGAAACAATTCTCT-1          BT072_region_1          ⋯
# ⋮                                          ⋮                       ⋱
# multiome_P-6774_S-10146_TGCTAACAGGTCCTAG-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_GAAACTGAGGCCGGAA-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_GAAAGCCAGTTTCCTG-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_CGTTAACAGGCGAAAC-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_GGCGCTAGTGCATTTC-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_AAGGTCAAGTTTGGTA-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_CCAAACTAGCTATGAC-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_GCAGGCTTCCTTGTTG-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_GCCTGTGCACAAAGGT-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_GATTACGGTAACGTGC-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_CCTAATAAGATTGAGG-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_GCGGATACACTGGCTG-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_CTACCGGCACATAGCC-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_GCATTAGGTGCTCCAC-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_GTGCAAGCATAATGTC-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_TGTATCGCATAGCGAG-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_TACTAAGTCGTTAACA-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_GCAATAGAGATAGACG-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_TAGTAAGCAGGTTCAC-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_TTGGATTCAGCATGGA-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_TGGATTCAGTGAACAG-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_AATGTCCAGGCCGGAA-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_GGAGCGATCATAGCCG-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_GACTAATGTGTTGCTT-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_GGAGTGAGTAAACAAG-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_CGAATCTAGTTTAACG-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_GCCTCAAAGGATTGCT-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_ACTTAGTCACTAGGTC-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_TCAGCGATCCGTGACA-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_CCTGTTGGTGACCTGG-1 P-6774_S-10146_Multiome ⋯
#                                            predicted.annotation_level_2.score
# BT042_pons_2_AGGCCACCATGGCCAC-1            0.5484847
# BT042_pons_2_CCCTCAAAGTAGCTCT-1            0.9791045
# BT042_pons_2_CTCCGATTCGGCCTTT-1            0.6321089
# BT042_pons_2_TGATCAGTCCTACAAG-1            0.8884661
# BT042_pons_2_ATCACTTAGACATGCG-1            0.9625962
# BT042_pons_2_GAAATGAGTACTAAGA-1            0.8881611
# BT042_pons_2_CATCCGTGTTAAGACA-1            0.7694054
# BT042_pons_2_TCTATCAGTGGAGGTT-1            0.9019691
# BT042_pons_2_TCTGGCTTCGAGAACG-1            0.8169074
# BT042_pons_2_CCGATGGTCTGTAACG-1            0.9200916
# BT042_pons_2_GTTCGCTAGATACCAA-1            0.9589029
# BT042_pons_2_GCAGCCAAGGACAAGA-1            0.7208627
# BT042_pons_2_TGGCGTGCATACTGAC-1            0.6160484
# BT042_pons_2_TTCTTGATCGCAAGAG-1            0.6293058
# BT072_region_1_TTTGGTTTCGACACTA-1          0.9640407
# BT072_region_1_CTTCTAAGTTACCCTC-1          0.7362723
# BT072_region_1_CCATCACCAGCAATTC-1          0.8785957
# BT072_region_1_CCCTCTCTCGAGTCTA-1          0.9657224
# BT072_region_1_ACTATTCTCCTACCGT-1          0.9361680
# BT072_region_1_ACGTAACCAGGCTTGC-1          0.6606320
# BT072_region_1_ATTCAGGCATGCCGCA-1          0.8787667
# BT072_region_1_AATCACGGTCACAATC-1          0.9144663
# BT072_region_1_GACACGCTCCACAAGT-1          0.9963077
# BT072_region_1_GACTCAATCTAATTCC-1          0.9130624
# BT072_region_1_ATATCCTAGCCTGACC-1          0.8239507
# BT072_region_1_CTGCATCTCTAAGCGT-1          0.9553812
# BT072_region_1_TGCAGGCCAGCTACAT-1          0.9379125
# BT072_region_1_GATCAGTTCGCCTATC-1          0.7870686
# BT072_region_1_CTACTATTCCGAACGC-1          0.9548097
# BT072_region_1_GCGGAAACAATTCTCT-1          0.8646880
# ⋮                                          ⋮
# multiome_P-6774_S-10146_TGCTAACAGGTCCTAG-1 0.5111257
# multiome_P-6774_S-10146_GAAACTGAGGCCGGAA-1 0.7881348
# multiome_P-6774_S-10146_GAAAGCCAGTTTCCTG-1 0.7686758
# multiome_P-6774_S-10146_CGTTAACAGGCGAAAC-1 0.8366107
# multiome_P-6774_S-10146_GGCGCTAGTGCATTTC-1 0.9082646
# multiome_P-6774_S-10146_AAGGTCAAGTTTGGTA-1 0.7008069
# multiome_P-6774_S-10146_CCAAACTAGCTATGAC-1 0.8526486
# multiome_P-6774_S-10146_GCAGGCTTCCTTGTTG-1 0.7525808
# multiome_P-6774_S-10146_GCCTGTGCACAAAGGT-1 0.8917864
# multiome_P-6774_S-10146_GATTACGGTAACGTGC-1 0.9242836
# multiome_P-6774_S-10146_CCTAATAAGATTGAGG-1 0.5984490
# multiome_P-6774_S-10146_GCGGATACACTGGCTG-1 0.7899239
# multiome_P-6774_S-10146_CTACCGGCACATAGCC-1 0.8996444
# multiome_P-6774_S-10146_GCATTAGGTGCTCCAC-1 0.7120488
# multiome_P-6774_S-10146_GTGCAAGCATAATGTC-1 0.8105766
# multiome_P-6774_S-10146_TGTATCGCATAGCGAG-1 0.8747856
# multiome_P-6774_S-10146_TACTAAGTCGTTAACA-1 0.8437931
# multiome_P-6774_S-10146_GCAATAGAGATAGACG-1 0.7774899
# multiome_P-6774_S-10146_TAGTAAGCAGGTTCAC-1 0.6321156
# multiome_P-6774_S-10146_TTGGATTCAGCATGGA-1 0.7016165
# multiome_P-6774_S-10146_TGGATTCAGTGAACAG-1 0.5034779
# multiome_P-6774_S-10146_AATGTCCAGGCCGGAA-1 0.6818266
# multiome_P-6774_S-10146_GGAGCGATCATAGCCG-1 0.8650870
# multiome_P-6774_S-10146_GACTAATGTGTTGCTT-1 0.5634287
# multiome_P-6774_S-10146_GGAGTGAGTAAACAAG-1 0.5110399
# multiome_P-6774_S-10146_CGAATCTAGTTTAACG-1 0.5093233
# multiome_P-6774_S-10146_GCCTCAAAGGATTGCT-1 0.7516055
# multiome_P-6774_S-10146_ACTTAGTCACTAGGTC-1 0.7987004
# multiome_P-6774_S-10146_TCAGCGATCCGTGACA-1 0.8632624
# multiome_P-6774_S-10146_CCTGTTGGTGACCTGG-1 0.8842554
#                                            predicted.annotation_level_2
# BT042_pons_2_AGGCCACCATGGCCAC-1            Differentiated-like
# BT042_pons_2_CCCTCAAAGTAGCTCT-1            Differentiated-like
# BT042_pons_2_CTCCGATTCGGCCTTT-1            Differentiated-like
# BT042_pons_2_TGATCAGTCCTACAAG-1            Stem-like
# BT042_pons_2_ATCACTTAGACATGCG-1            Differentiated-like
# BT042_pons_2_GAAATGAGTACTAAGA-1            Differentiated-like
# BT042_pons_2_CATCCGTGTTAAGACA-1            Differentiated-like
# BT042_pons_2_TCTATCAGTGGAGGTT-1            Stem-like
# BT042_pons_2_TCTGGCTTCGAGAACG-1            Differentiated-like
# BT042_pons_2_CCGATGGTCTGTAACG-1            Stem-like
# BT042_pons_2_GTTCGCTAGATACCAA-1            Stem-like
# BT042_pons_2_GCAGCCAAGGACAAGA-1            Stem-like
# BT042_pons_2_TGGCGTGCATACTGAC-1            Stem-like
# BT042_pons_2_TTCTTGATCGCAAGAG-1            Differentiated-like
# BT072_region_1_TTTGGTTTCGACACTA-1          Differentiated-like
# BT072_region_1_CTTCTAAGTTACCCTC-1          Stem-like
# BT072_region_1_CCATCACCAGCAATTC-1          Differentiated-like
# BT072_region_1_CCCTCTCTCGAGTCTA-1          Differentiated-like
# BT072_region_1_ACTATTCTCCTACCGT-1          Differentiated-like
# BT072_region_1_ACGTAACCAGGCTTGC-1          Stem-like
# BT072_region_1_ATTCAGGCATGCCGCA-1          Differentiated-like
# BT072_region_1_AATCACGGTCACAATC-1          Differentiated-like
# BT072_region_1_GACACGCTCCACAAGT-1          Differentiated-like
# BT072_region_1_GACTCAATCTAATTCC-1          Differentiated-like
# BT072_region_1_ATATCCTAGCCTGACC-1          Differentiated-like
# BT072_region_1_CTGCATCTCTAAGCGT-1          Differentiated-like
# BT072_region_1_TGCAGGCCAGCTACAT-1          Differentiated-like
# BT072_region_1_GATCAGTTCGCCTATC-1          Glial-Neuronal
# BT072_region_1_CTACTATTCCGAACGC-1          Differentiated-like
# BT072_region_1_GCGGAAACAATTCTCT-1          Differentiated-like
# ⋮                                          ⋮
# multiome_P-6774_S-10146_TGCTAACAGGTCCTAG-1 Stem-like
# multiome_P-6774_S-10146_GAAACTGAGGCCGGAA-1 Differentiated-like
# multiome_P-6774_S-10146_GAAAGCCAGTTTCCTG-1 Stem-like
# multiome_P-6774_S-10146_CGTTAACAGGCGAAAC-1 Differentiated-like
# multiome_P-6774_S-10146_GGCGCTAGTGCATTTC-1 Stem-like
# multiome_P-6774_S-10146_AAGGTCAAGTTTGGTA-1 Stem-like
# multiome_P-6774_S-10146_CCAAACTAGCTATGAC-1 Stem-like
# multiome_P-6774_S-10146_GCAGGCTTCCTTGTTG-1 Differentiated-like
# multiome_P-6774_S-10146_GCCTGTGCACAAAGGT-1 Stem-like
# multiome_P-6774_S-10146_GATTACGGTAACGTGC-1 Stem-like
# multiome_P-6774_S-10146_CCTAATAAGATTGAGG-1 Stem-like
# multiome_P-6774_S-10146_GCGGATACACTGGCTG-1 Differentiated-like
# multiome_P-6774_S-10146_CTACCGGCACATAGCC-1 Stem-like
# multiome_P-6774_S-10146_GCATTAGGTGCTCCAC-1 Stem-like
# multiome_P-6774_S-10146_GTGCAAGCATAATGTC-1 Stem-like
# multiome_P-6774_S-10146_TGTATCGCATAGCGAG-1 Stem-like
# multiome_P-6774_S-10146_TACTAAGTCGTTAACA-1 Differentiated-like
# multiome_P-6774_S-10146_GCAATAGAGATAGACG-1 Stem-like
# multiome_P-6774_S-10146_TAGTAAGCAGGTTCAC-1 Stem-like
# multiome_P-6774_S-10146_TTGGATTCAGCATGGA-1 Stem-like
# multiome_P-6774_S-10146_TGGATTCAGTGAACAG-1 Differentiated-like
# multiome_P-6774_S-10146_AATGTCCAGGCCGGAA-1 Stem-like
# multiome_P-6774_S-10146_GGAGCGATCATAGCCG-1 Stem-like
# multiome_P-6774_S-10146_GACTAATGTGTTGCTT-1 Differentiated-like
# multiome_P-6774_S-10146_GGAGTGAGTAAACAAG-1 Differentiated-like
# multiome_P-6774_S-10146_CGAATCTAGTTTAACG-1 Differentiated-like
# multiome_P-6774_S-10146_GCCTCAAAGGATTGCT-1 Stem-like
# multiome_P-6774_S-10146_ACTTAGTCACTAGGTC-1 Stem-like
# multiome_P-6774_S-10146_TCAGCGATCCGTGACA-1 Stem-like
# multiome_P-6774_S-10146_CCTGTTGGTGACCTGG-1 Stem-like
#                                            predicted.annotation_level_3.score
# BT042_pons_2_AGGCCACCATGGCCAC-1            0.5173874
# BT042_pons_2_CCCTCAAAGTAGCTCT-1            0.8238877
# BT042_pons_2_CTCCGATTCGGCCTTT-1            0.3563641
# BT042_pons_2_TGATCAGTCCTACAAG-1            0.5281412
# BT042_pons_2_ATCACTTAGACATGCG-1            0.8562781
# BT042_pons_2_GAAATGAGTACTAAGA-1            0.5864758
# BT042_pons_2_CATCCGTGTTAAGACA-1            0.4961172
# BT042_pons_2_TCTATCAGTGGAGGTT-1            0.5241815
# BT042_pons_2_TCTGGCTTCGAGAACG-1            0.5081449
# BT042_pons_2_CCGATGGTCTGTAACG-1            0.5626511
# BT042_pons_2_GTTCGCTAGATACCAA-1            0.9479460
# BT042_pons_2_GCAGCCAAGGACAAGA-1            0.6617900
# BT042_pons_2_TGGCGTGCATACTGAC-1            0.6129590
# BT042_pons_2_TTCTTGATCGCAAGAG-1            0.3782245
# BT072_region_1_TTTGGTTTCGACACTA-1          0.9299083
# BT072_region_1_CTTCTAAGTTACCCTC-1          0.7362723
# BT072_region_1_CCATCACCAGCAATTC-1          0.7828893
# BT072_region_1_CCCTCTCTCGAGTCTA-1          0.9070130
# BT072_region_1_ACTATTCTCCTACCGT-1          0.9274902
# BT072_region_1_ACGTAACCAGGCTTGC-1          0.4709681
# BT072_region_1_ATTCAGGCATGCCGCA-1          0.6598650
# BT072_region_1_AATCACGGTCACAATC-1          0.7230614
# BT072_region_1_GACACGCTCCACAAGT-1          0.9509822
# BT072_region_1_GACTCAATCTAATTCC-1          0.7966812
# BT072_region_1_ATATCCTAGCCTGACC-1          0.6848783
# BT072_region_1_CTGCATCTCTAAGCGT-1          0.9213997
# BT072_region_1_TGCAGGCCAGCTACAT-1          0.7978769
# BT072_region_1_GATCAGTTCGCCTATC-1          0.7870686
# BT072_region_1_CTACTATTCCGAACGC-1          0.8841882
# BT072_region_1_GCGGAAACAATTCTCT-1          0.7418773
# ⋮                                          ⋮
# multiome_P-6774_S-10146_TGCTAACAGGTCCTAG-1 0.4450958
# multiome_P-6774_S-10146_GAAACTGAGGCCGGAA-1 0.4525496
# multiome_P-6774_S-10146_GAAAGCCAGTTTCCTG-1 0.3888396
# multiome_P-6774_S-10146_CGTTAACAGGCGAAAC-1 0.5930704
# multiome_P-6774_S-10146_GGCGCTAGTGCATTTC-1 0.4815865
# multiome_P-6774_S-10146_AAGGTCAAGTTTGGTA-1 0.6834498
# multiome_P-6774_S-10146_CCAAACTAGCTATGAC-1 0.4978888
# multiome_P-6774_S-10146_GCAGGCTTCCTTGTTG-1 0.4036009
# multiome_P-6774_S-10146_GCCTGTGCACAAAGGT-1 0.6824721
# multiome_P-6774_S-10146_GATTACGGTAACGTGC-1 0.5000384
# multiome_P-6774_S-10146_CCTAATAAGATTGAGG-1 0.4731489
# multiome_P-6774_S-10146_GCGGATACACTGGCTG-1 0.6153987
# multiome_P-6774_S-10146_CTACCGGCACATAGCC-1 0.5180780
# multiome_P-6774_S-10146_GCATTAGGTGCTCCAC-1 0.5769073
# multiome_P-6774_S-10146_GTGCAAGCATAATGTC-1 0.7681734
# multiome_P-6774_S-10146_TGTATCGCATAGCGAG-1 0.5832430
# multiome_P-6774_S-10146_TACTAAGTCGTTAACA-1 0.4792728
# multiome_P-6774_S-10146_GCAATAGAGATAGACG-1 0.7124170
# multiome_P-6774_S-10146_TAGTAAGCAGGTTCAC-1 0.6110221
# multiome_P-6774_S-10146_TTGGATTCAGCATGGA-1 0.6790693
# multiome_P-6774_S-10146_TGGATTCAGTGAACAG-1 0.4289018
# multiome_P-6774_S-10146_AATGTCCAGGCCGGAA-1 0.6803897
# multiome_P-6774_S-10146_GGAGCGATCATAGCCG-1 0.5349488
# multiome_P-6774_S-10146_GACTAATGTGTTGCTT-1 0.4544009
# multiome_P-6774_S-10146_GGAGTGAGTAAACAAG-1 0.4721482
# multiome_P-6774_S-10146_CGAATCTAGTTTAACG-1 0.4736304
# multiome_P-6774_S-10146_GCCTCAAAGGATTGCT-1 0.7386161
# multiome_P-6774_S-10146_ACTTAGTCACTAGGTC-1 0.7884128
# multiome_P-6774_S-10146_TCAGCGATCCGTGACA-1 0.7979862
# multiome_P-6774_S-10146_CCTGTTGGTGACCTGG-1 0.8192006
#                                            predicted.annotation_level_3
# BT042_pons_2_AGGCCACCATGGCCAC-1            MES-like
# BT042_pons_2_CCCTCAAAGTAGCTCT-1            MES-like
# BT042_pons_2_CTCCGATTCGGCCTTT-1            MES-like
# BT042_pons_2_TGATCAGTCCTACAAG-1            OPC-like
# BT042_pons_2_ATCACTTAGACATGCG-1            MES-like
# BT042_pons_2_GAAATGAGTACTAAGA-1            MES-like
# BT042_pons_2_CATCCGTGTTAAGACA-1            AC-like
# BT042_pons_2_TCTATCAGTGGAGGTT-1            NPC-like
# BT042_pons_2_TCTGGCTTCGAGAACG-1            MES-like
# BT042_pons_2_CCGATGGTCTGTAACG-1            OPC-like
# BT042_pons_2_GTTCGCTAGATACCAA-1            NPC-like
# BT042_pons_2_GCAGCCAAGGACAAGA-1            OPC-like
# BT042_pons_2_TGGCGTGCATACTGAC-1            NPC-like
# BT042_pons_2_TTCTTGATCGCAAGAG-1            MES-like
# BT072_region_1_TTTGGTTTCGACACTA-1          MES-like
# BT072_region_1_CTTCTAAGTTACCCTC-1          OPC-like
# BT072_region_1_CCATCACCAGCAATTC-1          MES-like
# BT072_region_1_CCCTCTCTCGAGTCTA-1          MES-like
# BT072_region_1_ACTATTCTCCTACCGT-1          MES-like
# BT072_region_1_ACGTAACCAGGCTTGC-1          NPC-like
# BT072_region_1_ATTCAGGCATGCCGCA-1          MES-like
# BT072_region_1_AATCACGGTCACAATC-1          MES-like
# BT072_region_1_GACACGCTCCACAAGT-1          MES-like
# BT072_region_1_GACTCAATCTAATTCC-1          MES-like
# BT072_region_1_ATATCCTAGCCTGACC-1          MES-like
# BT072_region_1_CTGCATCTCTAAGCGT-1          MES-like
# BT072_region_1_TGCAGGCCAGCTACAT-1          MES-like
# BT072_region_1_GATCAGTTCGCCTATC-1          OPC
# BT072_region_1_CTACTATTCCGAACGC-1          MES-like
# BT072_region_1_GCGGAAACAATTCTCT-1          MES-like
# ⋮                                          ⋮
# multiome_P-6774_S-10146_TGCTAACAGGTCCTAG-1 NPC-like
# multiome_P-6774_S-10146_GAAACTGAGGCCGGAA-1 MES-like
# multiome_P-6774_S-10146_GAAAGCCAGTTTCCTG-1 NPC-like
# multiome_P-6774_S-10146_CGTTAACAGGCGAAAC-1 MES-like
# multiome_P-6774_S-10146_GGCGCTAGTGCATTTC-1 NPC-like
# multiome_P-6774_S-10146_AAGGTCAAGTTTGGTA-1 NPC-like
# multiome_P-6774_S-10146_CCAAACTAGCTATGAC-1 NPC-like
# multiome_P-6774_S-10146_GCAGGCTTCCTTGTTG-1 MES-like
# multiome_P-6774_S-10146_GCCTGTGCACAAAGGT-1 NPC-like
# multiome_P-6774_S-10146_GATTACGGTAACGTGC-1 OPC-like
# multiome_P-6774_S-10146_CCTAATAAGATTGAGG-1 NPC-like
# multiome_P-6774_S-10146_GCGGATACACTGGCTG-1 AC-like
# multiome_P-6774_S-10146_CTACCGGCACATAGCC-1 NPC-like
# multiome_P-6774_S-10146_GCATTAGGTGCTCCAC-1 NPC-like
# multiome_P-6774_S-10146_GTGCAAGCATAATGTC-1 NPC-like
# multiome_P-6774_S-10146_TGTATCGCATAGCGAG-1 NPC-like
# multiome_P-6774_S-10146_TACTAAGTCGTTAACA-1 MES-like
# multiome_P-6774_S-10146_GCAATAGAGATAGACG-1 NPC-like
# multiome_P-6774_S-10146_TAGTAAGCAGGTTCAC-1 NPC-like
# multiome_P-6774_S-10146_TTGGATTCAGCATGGA-1 NPC-like
# multiome_P-6774_S-10146_TGGATTCAGTGAACAG-1 NPC-like
# multiome_P-6774_S-10146_AATGTCCAGGCCGGAA-1 NPC-like
# multiome_P-6774_S-10146_GGAGCGATCATAGCCG-1 NPC-like
# multiome_P-6774_S-10146_GACTAATGTGTTGCTT-1 MES-like
# multiome_P-6774_S-10146_GGAGTGAGTAAACAAG-1 NPC-like
# multiome_P-6774_S-10146_CGAATCTAGTTTAACG-1 NPC-like
# multiome_P-6774_S-10146_GCCTCAAAGGATTGCT-1 NPC-like
# multiome_P-6774_S-10146_ACTTAGTCACTAGGTC-1 NPC-like
# multiome_P-6774_S-10146_TCAGCGATCCGTGACA-1 NPC-like
# multiome_P-6774_S-10146_CCTGTTGGTGACCTGG-1 NPC-like
#                                            predicted.annotation_level_4.score
# BT042_pons_2_AGGCCACCATGGCCAC-1            0.4575269
# BT042_pons_2_CCCTCAAAGTAGCTCT-1            0.6477115
# BT042_pons_2_CTCCGATTCGGCCTTT-1            0.2757447
# BT042_pons_2_TGATCAGTCCTACAAG-1            0.3874710
# BT042_pons_2_ATCACTTAGACATGCG-1            0.4341138
# BT042_pons_2_GAAATGAGTACTAAGA-1            0.4750826
# BT042_pons_2_CATCCGTGTTAAGACA-1            0.4961172
# BT042_pons_2_TCTATCAGTGGAGGTT-1            0.4594949
# BT042_pons_2_TCTGGCTTCGAGAACG-1            0.3498062
# BT042_pons_2_CCGATGGTCTGTAACG-1            0.5220578
# BT042_pons_2_GTTCGCTAGATACCAA-1            0.9479460
# BT042_pons_2_GCAGCCAAGGACAAGA-1            0.6617900
# BT042_pons_2_TGGCGTGCATACTGAC-1            0.6072312
# BT042_pons_2_TTCTTGATCGCAAGAG-1            0.3198836
# BT072_region_1_TTTGGTTTCGACACTA-1          0.7670195
# BT072_region_1_CTTCTAAGTTACCCTC-1          0.7256694
# BT072_region_1_CCATCACCAGCAATTC-1          0.5770742
# BT072_region_1_CCCTCTCTCGAGTCTA-1          0.6791035
# BT072_region_1_ACTATTCTCCTACCGT-1          0.5050211
# BT072_region_1_ACGTAACCAGGCTTGC-1          0.4316649
# BT072_region_1_ATTCAGGCATGCCGCA-1          0.6554791
# BT072_region_1_AATCACGGTCACAATC-1          0.6153088
# BT072_region_1_GACACGCTCCACAAGT-1          0.8388669
# BT072_region_1_GACTCAATCTAATTCC-1          0.7276469
# BT072_region_1_ATATCCTAGCCTGACC-1          0.6719126
# BT072_region_1_CTGCATCTCTAAGCGT-1          0.6277148
# BT072_region_1_TGCAGGCCAGCTACAT-1          0.7222025
# BT072_region_1_GATCAGTTCGCCTATC-1          0.7870686
# BT072_region_1_CTACTATTCCGAACGC-1          0.7010074
# BT072_region_1_GCGGAAACAATTCTCT-1          0.7038901
# ⋮                                          ⋮
# multiome_P-6774_S-10146_TGCTAACAGGTCCTAG-1 0.3958715
# multiome_P-6774_S-10146_GAAACTGAGGCCGGAA-1 0.3494150
# multiome_P-6774_S-10146_GAAAGCCAGTTTCCTG-1 0.3423874
# multiome_P-6774_S-10146_CGTTAACAGGCGAAAC-1 0.3579886
# multiome_P-6774_S-10146_GGCGCTAGTGCATTTC-1 0.3972492
# multiome_P-6774_S-10146_AAGGTCAAGTTTGGTA-1 0.6487307
# multiome_P-6774_S-10146_CCAAACTAGCTATGAC-1 0.4063369
# multiome_P-6774_S-10146_GCAGGCTTCCTTGTTG-1 0.3489799
# multiome_P-6774_S-10146_GCCTGTGCACAAAGGT-1 0.5672693
# multiome_P-6774_S-10146_GATTACGGTAACGTGC-1 0.4121936
# multiome_P-6774_S-10146_CCTAATAAGATTGAGG-1 0.3404392
# multiome_P-6774_S-10146_GCGGATACACTGGCTG-1 0.6153987
# multiome_P-6774_S-10146_CTACCGGCACATAGCC-1 0.4560981
# multiome_P-6774_S-10146_GCATTAGGTGCTCCAC-1 0.5264450
# multiome_P-6774_S-10146_GTGCAAGCATAATGTC-1 0.7607353
# multiome_P-6774_S-10146_TGTATCGCATAGCGAG-1 0.4432159
# multiome_P-6774_S-10146_TACTAAGTCGTTAACA-1 0.3645203
# multiome_P-6774_S-10146_GCAATAGAGATAGACG-1 0.7124170
# multiome_P-6774_S-10146_TAGTAAGCAGGTTCAC-1 0.6049324
# multiome_P-6774_S-10146_TTGGATTCAGCATGGA-1 0.6591933
# multiome_P-6774_S-10146_TGGATTCAGTGAACAG-1 0.3959222
# multiome_P-6774_S-10146_AATGTCCAGGCCGGAA-1 0.6803897
# multiome_P-6774_S-10146_GGAGCGATCATAGCCG-1 0.3640371
# multiome_P-6774_S-10146_GACTAATGTGTTGCTT-1 0.3853766
# multiome_P-6774_S-10146_GGAGTGAGTAAACAAG-1 0.4663545
# multiome_P-6774_S-10146_CGAATCTAGTTTAACG-1 0.4441619
# multiome_P-6774_S-10146_GCCTCAAAGGATTGCT-1 0.7234301
# multiome_P-6774_S-10146_ACTTAGTCACTAGGTC-1 0.7754187
# multiome_P-6774_S-10146_TCAGCGATCCGTGACA-1 0.7475065
# multiome_P-6774_S-10146_CCTGTTGGTGACCTGG-1 0.7863769
#                                            predicted.annotation_level_4 iCNV
# BT042_pons_2_AGGCCACCATGGCCAC-1            MES-like hypoxia/MHC         tumor
# BT042_pons_2_CCCTCAAAGTAGCTCT-1            MES-like hypoxia/MHC         tumor
# BT042_pons_2_CTCCGATTCGGCCTTT-1            AC-like                      tumor
# BT042_pons_2_TGATCAGTCCTACAAG-1            OPC-like                     tumor
# BT042_pons_2_ATCACTTAGACATGCG-1            MES-like hypoxia/MHC         tumor
# BT042_pons_2_GAAATGAGTACTAAGA-1            MES-like hypoxia independent tumor
# BT042_pons_2_CATCCGTGTTAAGACA-1            AC-like                      tumor
# BT042_pons_2_TCTATCAGTGGAGGTT-1            NPC-like OPC                 tumor
# BT042_pons_2_TCTGGCTTCGAGAACG-1            MES-like hypoxia independent tumor
# BT042_pons_2_CCGATGGTCTGTAACG-1            OPC-like                     tumor
# BT042_pons_2_GTTCGCTAGATACCAA-1            NPC-like OPC                 tumor
# BT042_pons_2_GCAGCCAAGGACAAGA-1            OPC-like                     tumor
# BT042_pons_2_TGGCGTGCATACTGAC-1            NPC-like OPC                 tumor
# BT042_pons_2_TTCTTGATCGCAAGAG-1            MES-like hypoxia independent tumor
# BT072_region_1_TTTGGTTTCGACACTA-1          MES-like hypoxia/MHC         tumor
# BT072_region_1_CTTCTAAGTTACCCTC-1          OPC-like                     tumor
# BT072_region_1_CCATCACCAGCAATTC-1          MES-like hypoxia/MHC         tumor
# BT072_region_1_CCCTCTCTCGAGTCTA-1          MES-like hypoxia/MHC         tumor
# BT072_region_1_ACTATTCTCCTACCGT-1          MES-like hypoxia independent tumor
# BT072_region_1_ACGTAACCAGGCTTGC-1          NPC-like Prolif              tumor
# BT072_region_1_ATTCAGGCATGCCGCA-1          MES-like hypoxia/MHC         tumor
# BT072_region_1_AATCACGGTCACAATC-1          MES-like hypoxia/MHC         tumor
# BT072_region_1_GACACGCTCCACAAGT-1          MES-like hypoxia/MHC         tumor
# BT072_region_1_GACTCAATCTAATTCC-1          MES-like hypoxia/MHC         tumor
# BT072_region_1_ATATCCTAGCCTGACC-1          MES-like hypoxia/MHC         tumor
# BT072_region_1_CTGCATCTCTAAGCGT-1          MES-like hypoxia/MHC         tumor
# BT072_region_1_TGCAGGCCAGCTACAT-1          MES-like hypoxia/MHC         tumor
# BT072_region_1_GATCAGTTCGCCTATC-1          OPC                          tumor
# BT072_region_1_CTACTATTCCGAACGC-1          MES-like hypoxia/MHC         tumor
# BT072_region_1_GCGGAAACAATTCTCT-1          MES-like hypoxia/MHC         tumor
# ⋮                                          ⋮                            ⋮
# multiome_P-6774_S-10146_TGCTAACAGGTCCTAG-1 NPC-like OPC                 tumor
# multiome_P-6774_S-10146_GAAACTGAGGCCGGAA-1 MES-like hypoxia independent tumor
# multiome_P-6774_S-10146_GAAAGCCAGTTTCCTG-1 NPC-like OPC                 tumor
# multiome_P-6774_S-10146_CGTTAACAGGCGAAAC-1 MES-like hypoxia independent tumor
# multiome_P-6774_S-10146_GGCGCTAGTGCATTTC-1 OPC-like                     tumor
# multiome_P-6774_S-10146_AAGGTCAAGTTTGGTA-1 NPC-like OPC                 tumor
# multiome_P-6774_S-10146_CCAAACTAGCTATGAC-1 NPC-like OPC                 tumor
# multiome_P-6774_S-10146_GCAGGCTTCCTTGTTG-1 AC-like                      tumor
# multiome_P-6774_S-10146_GCCTGTGCACAAAGGT-1 NPC-like OPC                 tumor
# multiome_P-6774_S-10146_GATTACGGTAACGTGC-1 OPC-like                     tumor
# multiome_P-6774_S-10146_CCTAATAAGATTGAGG-1 NPC-like OPC                 tumor
# multiome_P-6774_S-10146_GCGGATACACTGGCTG-1 AC-like                      tumor
# multiome_P-6774_S-10146_CTACCGGCACATAGCC-1 NPC-like OPC                 tumor
# multiome_P-6774_S-10146_GCATTAGGTGCTCCAC-1 NPC-like OPC                 tumor
# multiome_P-6774_S-10146_GTGCAAGCATAATGTC-1 NPC-like OPC                 tumor
# multiome_P-6774_S-10146_TGTATCGCATAGCGAG-1 NPC-like OPC                 tumor
# multiome_P-6774_S-10146_TACTAAGTCGTTAACA-1 AC-like                      tumor
# multiome_P-6774_S-10146_GCAATAGAGATAGACG-1 NPC-like OPC                 tumor
# multiome_P-6774_S-10146_TAGTAAGCAGGTTCAC-1 NPC-like OPC                 tumor
# multiome_P-6774_S-10146_TTGGATTCAGCATGGA-1 NPC-like OPC                 tumor
# multiome_P-6774_S-10146_TGGATTCAGTGAACAG-1 NPC-like OPC                 tumor
# multiome_P-6774_S-10146_AATGTCCAGGCCGGAA-1 NPC-like OPC                 tumor
# multiome_P-6774_S-10146_GGAGCGATCATAGCCG-1 NPC-like OPC                 tumor
# multiome_P-6774_S-10146_GACTAATGTGTTGCTT-1 MES-like hypoxia/MHC         tumor
# multiome_P-6774_S-10146_GGAGTGAGTAAACAAG-1 NPC-like OPC                 tumor
# multiome_P-6774_S-10146_CGAATCTAGTTTAACG-1 NPC-like OPC                 tumor
# multiome_P-6774_S-10146_GCCTCAAAGGATTGCT-1 NPC-like OPC                 tumor
# multiome_P-6774_S-10146_ACTTAGTCACTAGGTC-1 NPC-like OPC                 tumor
# multiome_P-6774_S-10146_TCAGCGATCCGTGACA-1 NPC-like OPC                 tumor
# multiome_P-6774_S-10146_CCTGTTGGTGACCTGG-1 NPC-like OPC                 tumor
#                                            cell_id
# BT042_pons_2_AGGCCACCATGGCCAC-1            Differentiated_like_tumor
# BT042_pons_2_CCCTCAAAGTAGCTCT-1            Differentiated_like_tumor
# BT042_pons_2_CTCCGATTCGGCCTTT-1            Differentiated_like_tumor
# BT042_pons_2_TGATCAGTCCTACAAG-1            Stem_like_tumor
# BT042_pons_2_ATCACTTAGACATGCG-1            Differentiated_like_tumor
# BT042_pons_2_GAAATGAGTACTAAGA-1            Differentiated_like_tumor
# BT042_pons_2_CATCCGTGTTAAGACA-1            Differentiated_like_tumor
# BT042_pons_2_TCTATCAGTGGAGGTT-1            Stem_like_tumor
# BT042_pons_2_TCTGGCTTCGAGAACG-1            Differentiated_like_tumor
# BT042_pons_2_CCGATGGTCTGTAACG-1            Stem_like_tumor
# BT042_pons_2_GTTCGCTAGATACCAA-1            Stem_like_tumor
# BT042_pons_2_GCAGCCAAGGACAAGA-1            Stem_like_tumor
# BT042_pons_2_TGGCGTGCATACTGAC-1            Stem_like_tumor
# BT042_pons_2_TTCTTGATCGCAAGAG-1            Differentiated_like_tumor
# BT072_region_1_TTTGGTTTCGACACTA-1          Differentiated_like_tumor
# BT072_region_1_CTTCTAAGTTACCCTC-1          Stem_like_tumor
# BT072_region_1_CCATCACCAGCAATTC-1          Differentiated_like_tumor
# BT072_region_1_CCCTCTCTCGAGTCTA-1          Differentiated_like_tumor
# BT072_region_1_ACTATTCTCCTACCGT-1          Differentiated_like_tumor
# BT072_region_1_ACGTAACCAGGCTTGC-1          Stem_like_tumor
# BT072_region_1_ATTCAGGCATGCCGCA-1          Differentiated_like_tumor
# BT072_region_1_AATCACGGTCACAATC-1          Differentiated_like_tumor
# BT072_region_1_GACACGCTCCACAAGT-1          Differentiated_like_tumor
# BT072_region_1_GACTCAATCTAATTCC-1          Differentiated_like_tumor
# BT072_region_1_ATATCCTAGCCTGACC-1          Differentiated_like_tumor
# BT072_region_1_CTGCATCTCTAAGCGT-1          Differentiated_like_tumor
# BT072_region_1_TGCAGGCCAGCTACAT-1          Differentiated_like_tumor
# BT072_region_1_GATCAGTTCGCCTATC-1          Stem_like_tumor
# BT072_region_1_CTACTATTCCGAACGC-1          Differentiated_like_tumor
# BT072_region_1_GCGGAAACAATTCTCT-1          Differentiated_like_tumor
# ⋮                                          ⋮
# multiome_P-6774_S-10146_TGCTAACAGGTCCTAG-1 Stem_like_tumor
# multiome_P-6774_S-10146_GAAACTGAGGCCGGAA-1 Differentiated_like_tumor
# multiome_P-6774_S-10146_GAAAGCCAGTTTCCTG-1 Stem_like_tumor
# multiome_P-6774_S-10146_CGTTAACAGGCGAAAC-1 Differentiated_like_tumor
# multiome_P-6774_S-10146_GGCGCTAGTGCATTTC-1 Stem_like_tumor
# multiome_P-6774_S-10146_AAGGTCAAGTTTGGTA-1 Stem_like_tumor
# multiome_P-6774_S-10146_CCAAACTAGCTATGAC-1 Stem_like_tumor
# multiome_P-6774_S-10146_GCAGGCTTCCTTGTTG-1 Differentiated_like_tumor
# multiome_P-6774_S-10146_GCCTGTGCACAAAGGT-1 Stem_like_tumor
# multiome_P-6774_S-10146_GATTACGGTAACGTGC-1 Stem_like_tumor
# multiome_P-6774_S-10146_CCTAATAAGATTGAGG-1 Stem_like_tumor
# multiome_P-6774_S-10146_GCGGATACACTGGCTG-1 Differentiated_like_tumor
# multiome_P-6774_S-10146_CTACCGGCACATAGCC-1 Stem_like_tumor
# multiome_P-6774_S-10146_GCATTAGGTGCTCCAC-1 Stem_like_tumor
# multiome_P-6774_S-10146_GTGCAAGCATAATGTC-1 Stem_like_tumor
# multiome_P-6774_S-10146_TGTATCGCATAGCGAG-1 Stem_like_tumor
# multiome_P-6774_S-10146_TACTAAGTCGTTAACA-1 Differentiated_like_tumor
# multiome_P-6774_S-10146_GCAATAGAGATAGACG-1 Stem_like_tumor
# multiome_P-6774_S-10146_TAGTAAGCAGGTTCAC-1 Stem_like_tumor
# multiome_P-6774_S-10146_TTGGATTCAGCATGGA-1 Stem_like_tumor
# multiome_P-6774_S-10146_TGGATTCAGTGAACAG-1 Stem_like_tumor
# multiome_P-6774_S-10146_AATGTCCAGGCCGGAA-1 Stem_like_tumor
# multiome_P-6774_S-10146_GGAGCGATCATAGCCG-1 Stem_like_tumor
# multiome_P-6774_S-10146_GACTAATGTGTTGCTT-1 Differentiated_like_tumor
# multiome_P-6774_S-10146_GGAGTGAGTAAACAAG-1 Stem_like_tumor
# multiome_P-6774_S-10146_CGAATCTAGTTTAACG-1 Stem_like_tumor
# multiome_P-6774_S-10146_GCCTCAAAGGATTGCT-1 Stem_like_tumor
# multiome_P-6774_S-10146_ACTTAGTCACTAGGTC-1 Stem_like_tumor
# multiome_P-6774_S-10146_TCAGCGATCCGTGACA-1 Stem_like_tumor
# multiome_P-6774_S-10146_CCTGTTGGTGACCTGG-1 Stem_like_tumor
#                                            MP_Assignment Material
# BT042_pons_2_AGGCCACCATGGCCAC-1            MP9           nuclei
# BT042_pons_2_CCCTCAAAGTAGCTCT-1            MP9           nuclei
# BT042_pons_2_CTCCGATTCGGCCTTT-1            unresolved    nuclei
# BT042_pons_2_TGATCAGTCCTACAAG-1            MP11          nuclei
# BT042_pons_2_ATCACTTAGACATGCG-1            unresolved    nuclei
# BT042_pons_2_GAAATGAGTACTAAGA-1            unresolved    nuclei
# BT042_pons_2_CATCCGTGTTAAGACA-1            MP3           nuclei
# BT042_pons_2_TCTATCAGTGGAGGTT-1            unresolved    nuclei
# BT042_pons_2_TCTGGCTTCGAGAACG-1            MP9           nuclei
# BT042_pons_2_CCGATGGTCTGTAACG-1            MP2           nuclei
# BT042_pons_2_GTTCGCTAGATACCAA-1            MP13          nuclei
# BT042_pons_2_GCAGCCAAGGACAAGA-1            MP8           nuclei
# BT042_pons_2_TGGCGTGCATACTGAC-1            unresolved    nuclei
# BT042_pons_2_TTCTTGATCGCAAGAG-1            unresolved    nuclei
# BT072_region_1_TTTGGTTTCGACACTA-1          MP7           nuclei
# BT072_region_1_CTTCTAAGTTACCCTC-1          MP8           nuclei
# BT072_region_1_CCATCACCAGCAATTC-1          MP9           nuclei
# BT072_region_1_CCCTCTCTCGAGTCTA-1          unresolved    nuclei
# BT072_region_1_ACTATTCTCCTACCGT-1          MP9           nuclei
# BT072_region_1_ACGTAACCAGGCTTGC-1          MP7           nuclei
# BT072_region_1_ATTCAGGCATGCCGCA-1          MP9           nuclei
# BT072_region_1_AATCACGGTCACAATC-1          MP9           nuclei
# BT072_region_1_GACACGCTCCACAAGT-1          MP7           nuclei
# BT072_region_1_GACTCAATCTAATTCC-1          MP9           nuclei
# BT072_region_1_ATATCCTAGCCTGACC-1          MP9           nuclei
# BT072_region_1_CTGCATCTCTAAGCGT-1          unresolved    nuclei
# BT072_region_1_TGCAGGCCAGCTACAT-1          MP9           nuclei
# BT072_region_1_GATCAGTTCGCCTATC-1          MP2           nuclei
# BT072_region_1_CTACTATTCCGAACGC-1          MP9           nuclei
# BT072_region_1_GCGGAAACAATTCTCT-1          MP9           nuclei
# ⋮                                          ⋮             ⋮
# multiome_P-6774_S-10146_TGCTAACAGGTCCTAG-1 MP11          nuclei
# multiome_P-6774_S-10146_GAAACTGAGGCCGGAA-1 unresolved    nuclei
# multiome_P-6774_S-10146_GAAAGCCAGTTTCCTG-1 MP2           nuclei
# multiome_P-6774_S-10146_CGTTAACAGGCGAAAC-1 MP3           nuclei
# multiome_P-6774_S-10146_GGCGCTAGTGCATTTC-1 MP5           nuclei
# multiome_P-6774_S-10146_AAGGTCAAGTTTGGTA-1 MP8           nuclei
# multiome_P-6774_S-10146_CCAAACTAGCTATGAC-1 MP2           nuclei
# multiome_P-6774_S-10146_GCAGGCTTCCTTGTTG-1 MP3           nuclei
# multiome_P-6774_S-10146_GCCTGTGCACAAAGGT-1 MP5           nuclei
# multiome_P-6774_S-10146_GATTACGGTAACGTGC-1 MP5           nuclei
# multiome_P-6774_S-10146_CCTAATAAGATTGAGG-1 MP2           nuclei
# multiome_P-6774_S-10146_GCGGATACACTGGCTG-1 MP3           nuclei
# multiome_P-6774_S-10146_CTACCGGCACATAGCC-1 MP2           nuclei
# multiome_P-6774_S-10146_GCATTAGGTGCTCCAC-1 MP3           nuclei
# multiome_P-6774_S-10146_GTGCAAGCATAATGTC-1 MP9           nuclei
# multiome_P-6774_S-10146_TGTATCGCATAGCGAG-1 MP5           nuclei
# multiome_P-6774_S-10146_TACTAAGTCGTTAACA-1 unresolved    nuclei
# multiome_P-6774_S-10146_GCAATAGAGATAGACG-1 MP9           nuclei
# multiome_P-6774_S-10146_TAGTAAGCAGGTTCAC-1 MP3           nuclei
# multiome_P-6774_S-10146_TTGGATTCAGCATGGA-1 MP3           nuclei
# multiome_P-6774_S-10146_TGGATTCAGTGAACAG-1 unresolved    nuclei
# multiome_P-6774_S-10146_AATGTCCAGGCCGGAA-1 unresolved    nuclei
# multiome_P-6774_S-10146_GGAGCGATCATAGCCG-1 MP5           nuclei
# multiome_P-6774_S-10146_GACTAATGTGTTGCTT-1 MP3           nuclei
# multiome_P-6774_S-10146_GGAGTGAGTAAACAAG-1 MP3           nuclei
# multiome_P-6774_S-10146_CGAATCTAGTTTAACG-1 MP3           nuclei
# multiome_P-6774_S-10146_GCCTCAAAGGATTGCT-1 MP3           nuclei
# multiome_P-6774_S-10146_ACTTAGTCACTAGGTC-1 MP5           nuclei
# multiome_P-6774_S-10146_TCAGCGATCCGTGACA-1 MP5           nuclei
# multiome_P-6774_S-10146_CCTGTTGGTGACCTGG-1 MP3           nuclei

# %% [markdown]
# ### Final

# %%
library("data.table")
library("tidyverse")
library("ggpubr")
library("magrittr")
library("lme4")
library("numDeriv")
library("scales")
library("stringr")
# Out:
# ── Attaching core tidyverse packages ─────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ forcats   1.0.0     ✔ purrr     1.0.2
# ✔ lubridate 1.9.3     ✔ readr     2.1.5
# ── Conflicts ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ data.table::between() masks dplyr::between()
# ✖ readr::col_factor()   masks scales::col_factor()
# ✖ purrr::discard()      masks scales::discard()
# ✖ Matrix::expand()      masks tidyr::expand()
# ✖ dplyr::filter()       masks stats::filter()
# ✖ data.table::first()   masks dplyr::first()
# ✖ lubridate::hour()     masks data.table::hour()
# ✖ lubridate::isoweek()  masks data.table::isoweek()
# ✖ dplyr::lag()          masks stats::lag()
# ✖ data.table::last()    masks dplyr::last()
# ✖ lubridate::mday()     masks data.table::mday()
# ✖ lubridate::minute()   masks data.table::minute()
# ✖ lubridate::month()    masks data.table::month()
# ✖ Matrix::pack()        masks tidyr::pack()
# ✖ lubridate::quarter()  masks data.table::quarter()
# ✖ lubridate::second()   masks data.table::second()
# ✖ purrr::transpose()    masks data.table::transpose()
# ✖ Matrix::unpack()      masks tidyr::unpack()
# ✖ lubridate::wday()     masks data.table::wday()
# ✖ lubridate::week()     masks data.table::week()
# ✖ lubridate::yday()     masks data.table::yday()
# ✖ lubridate::year()     masks data.table::year()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘magrittr’
#
#
# The following object is masked from ‘package:purrr’:
#
#     set_names
#
#
# The following object is masked from ‘package:tidyr’:
#
#     extract

# %%
# Method and initial implementation by Natsuhiko Kumasaka (natsuhiko@github)
# refactored and maintained by Ni Huang (nh3@github)

#' Make cell type by sample count matrix
#'
#' This function makes cell type by sample count matrix from a cell level annotation table
#'
#' @param obs_tbl Cell level annotation table, such as AnnData.obs (data.frame-like object)
#' @param colSample Column in "obs_tbl" specifying sample ID (str)
#' @param colCelltype Column in "obs_tbl" specifying cell type annotation (str)
#'
#' @return matrix containing cell type counts of dimension nSample x nCelltype
#'
#' @import magrittr
.make_count_matrix <- function(obs_tbl, colSample, colCelltype) {
  cnt_mat <- table(obs_tbl[[colSample]], obs_tbl[[colCelltype]]) %>% as.matrix()
  cnt_mat
}

#' Make sample level metadata table
#'
#' This function makes sample level metadata table from a cell level annotation table
#'
#' @param obs_tbl Cell level annotation table, such as AnnData.obs (data.frame-like object)
#' @param colSample Column in "obs_tbl" specifying sample ID (str)
#' @param colVarCats Columns in "obs_tbl" specifying categorical variables to control for (vector of str)
#' @param colVarNums Columns in "obs_tbl" specifying numerical variables to control for (vector of str)
#' @param extra_term Extra term(s) to be added to the model (str or vector of str)
#'
#' @return tibble containing metadata for each sample, one per row
#'
#' @import dplyr
.make_sample_metadata <- function(obs_tbl, colSample, colVarCats = c(), colVarNums = c(), extra_term = NULL) {
  if (!is.null(extra_term)) {
    extra_vars <- unique(unlist(strsplit(extra_term, ":", fixed = T)))
    extra_vars <- extra_vars[extra_vars %in% colnames(obs_tbl)]
  } else {
    extra_vars <- c()
  }
  metadata_tbl <- obs_tbl %>%
    select(one_of(unique(c(colSample, colVarCats, colVarNums, extra_vars)))) %>%
    unique()
  metadata_tbl
}

#' Make input data for model fitting
#'
#' This function makes input data for model fitting by assembling sample level
#' metadata and cell type by sample count matrix
#'
#' @param Y Cell type by sample count matrix (matrix of dimension nSample x nCelltype)
#' @param metadata_tbl Sample level metadata table (data.frame-like object)
#'
#' @return tibble containing counts and metadata for each cell type in each sample
#'
#' @import tibble
#' @import dplyr
.make_input_for_glmer <- function(Y, metadata_tbl, colSample) {
  samples <- rownames(Y)
  celltypes <- colnames(Y)
  nSample <- length(samples)
  nCelltype <- length(celltypes)

  metadata_tbl <- metadata_tbl[match(samples, metadata_tbl[[colSample]]), ]

  input_tbl <- bind_cols(
    metadata_tbl[rep(1:nSample, nCelltype), ],
    enframe(factor(rep(celltypes, rep(nSample, nCelltype))), name = NULL, value = "Celltype")
  )

  input_tbl$Y <- as.vector(Y)
  cat("input prepared\n")

  input_tbl
}

#' Make model formula
#'
#' This function makes a formula for a GLMM with random effects for each
#' specified categorical variables and interactions between each variable and
#' cell type
#'
#' @param colSample Column in "obs_tbl" specifying sample ID (str)
#' @param colVarCats Columns in "obs_tbl" specifying categorical variables to control for (vector of str)
#' @param colVarNums Columns in "obs_tbl" specifying numerical variables to control for (vector of str)
#' @param extra_term Extra term(s) to be added to the model (str or vector of str)
#'
#' @return formula specifying a GLMM model
.make_formula <- function(colSample, colCelltype, colVarCats, colVarNums, extra_term = NULL) {
  if (!is.null(extra_term)) {
    extra_vars <- unique(unlist(strsplit(extra_term, ":", fixed = T)))
    extra_vars[extra_vars == colCelltype] <- "Celltype"
    extra_term <- sprintf("(1|%s)", paste(extra_vars, collapse = ":"))
  }
  terms <- c(
    colVarNums,
    sprintf("(1|%s)", c(colSample, colVarCats)),
    sprintf("(%s-1|Celltype)", colVarNums),
    sprintf("(1|%s:Celltype)", c(colSample, colVarCats))
  )
  formula_str <- paste(c("I(Y) ~ (1|Celltype)", terms, extra_term), collapse = "+")
  cat(paste0(formula_str, "\n"))
  as.formula(formula_str)
}

#' Get mean estimate of random effects and LTSR values for all specified variables
#'
#' This function extracts random effect estimates (mean and sd) of specified
#' variables, calculates LTSR using a z-score test and prepare categories in
#' specified orders for plotting
#'
#' @param ranef_tbl Table of random effect estimates (mean and sd) extracted from fitted model
#'     (data.frame-like object)
#' @param vars A list specifying required categorical sample metadata variables and their order,
#'     e.g. list(size=c('small', 'medium', 'big'), price=c('cheap', 'expensive'))
#' @param celltypes If specified, only keep those cell types (vector of str)
#' @param references If specified, fold changes are calculated relative to the specified level
#'     instead of global mean. Must be a list, e.g. list(size='small', price='cheap')
#'
#' @return tibble containing mean random effects and respective LTSR
#'
#' @import dplyr
#' @import tidyr
#' @import stringr
.getCondValLtsr <- function(ranef_tbl, vars, celltypes = NULL, references = NULL) {
  if (!is.list(vars)) stop('"vars" must be a list of which names are co-variables to plot', call. = F)
  if (!is.null(references) && !is.list(references)) stop('"references" must be a list of which names match that of "vars"', call. = F)

  cat_ranef_tbl <- ranef_tbl %>%
    filter(
      grepl(":Celltype$", grpvar)
    ) %>%
    mutate(
      grpvar = factor(sub(":Celltype$", "", grpvar)),
      grp = factor(ifelse(
        grepl(":.*:", grp),
        sapply(str_split(grp, ":"), function(x) paste(paste(x[-length(x)], collapse = ","), x[length(x)], sep = ":")),
        as.character(grp)
      ))
    ) %>%
    separate(
      grp,
      into = c("grpval", "Celltype"), sep = ":"
    )

  num_ranef_tbl <- ranef_tbl %>%
    filter(
      grpvar == "Celltype" & term != "(Intercept)"
    ) %>%
    mutate(
      grpvar = factor(term),
      grpval= paste("Slope",term, sep = "-"),
      Celltype = grp
    ) %>%
    select (
      -grp
    )

  if (!is.null(references)) {
    cat_ranef_tbl <- bind_rows(
      lapply(names(vars), function(vname) {
        if (vname %in% names(references)) {
          ref <- references[[vname]]
          full_join(
            cat_ranef_tbl %>% filter(grpvar == vname, grpval != ref),
            cat_ranef_tbl %>% filter(grpvar == vname, grpval == ref) %>% select(grpvar, Celltype, condval, condsd),
            by = c("grpvar", "Celltype")
          ) %>%
            mutate(
              condval = condval.x - condval.y,
              condsd = sqrt(condsd.x^2 + condsd.y^2)
            ) %>%
            select(-condval.x, -condval.y, -condsd.x, -condsd.y)
        } else {
          return(cat_ranef_tbl %>% filter(grpvar == vname))
        }
      })
    )
  }

  ranef_tbl <- bind_rows(cat_ranef_tbl, num_ranef_tbl)

  ranef_tbl <- ranef_tbl %>%
    mutate(
      lfsr = pnorm(condval, 0, condsd)
    ) %>%
    mutate(
      lfsr = ifelse(lfsr > 0.5, 1 - lfsr, lfsr)
    ) %>%
    mutate(
      ltsr = 1 - lfsr
    ) %>%
    select(
      grpvar, grpval, Celltype, condval, ltsr
    )

  if (!is.null(celltypes)) ranef_tbl <- ranef_tbl %>% filter(Celltype %in% celltypes)

  ranef_tbl <- ranef_tbl %>%
    filter(
      grpvar %in% names(vars)
    ) %>%
    mutate(
      grpvar = factor(grpvar, levels = names(vars)),
      grpval = factor(grpval, levels = unlist(vars, use.names = F))
    )

  ranef_tbl
}

#' Cell type composition analysis
#'
#' This function performs cell type composition analysis across samples grouped by certain metadata
#' variable while controling for other variables, by fitting a Poisson Generalised Linear Mixed
#' Model
#'
#' @param obs_tbl Cell level annotation table, such as AnnData.obs (data.frame-like object)
#' @param colSample Column in "obs_tbl" specifying sample ID (str)
#' @param colCelltype Column in "obs_tbl" specifying cell type annotation (str)
#' @param colVarCats Columns in "obs_tbl" specifying categorical variables to control for (vector of str)
#' @param colVarNums Columns in "obs_tbl" specifying numerical variables to control for (vector of str)
#' @param extra_term Extra term(s) to be added to the model (str or vector of str)
#' @param save If specified, used as file name prefix to save returned values (str)
#'
#' @return list containing two tables, 1) estimated random effects, 2) estimated explained variance
#'     (in the form of standard deviation)
#'
#' @import tibble
#' @import dplyr
#' @import tidyr
#' @import lme4
#' @import numDeriv
#'
#' @export
CellTypeCompositionAnalysis <- function(obs_tbl, colSample, colCelltype, colVarCats, colVarNums = NULL, extra_term = NULL, save = NULL) {
  metadata_tbl <- .make_sample_metadata(obs_tbl, colSample, colVarCats, colVarNums, extra_term = extra_term)
  Y <- .make_count_matrix(obs_tbl, colSample, colCelltype)

  input_tbl <- .make_input_for_glmer(Y, metadata_tbl, colSample)

  f <- .make_formula(colSample, colCelltype, colVarCats, colVarNums, extra_term = extra_term)
  cat("model constructed\n")
  res.prop <- glmer(
    f,
    data = input_tbl, family = poisson,
    control = glmerControl(optimizer = "bobyqa", optCtrl = list(maxfun = 2e5))
  )
  cat("model fitted\n")

  # standard errors of standard deviations (squre root of the variance parameters)
  devfun <- update(res.prop, devFunOnly = T)
  pars <- getME(res.prop, c("theta", "fixef"))
  hess <- hessian(devfun, unlist(pars))
  sdse.prop <- data.frame(sd = unlist(pars), se = sqrt(diag(solve(hess))))
  sdse_tbl <- sdse.prop %>%
    rownames_to_column() %>%
    as_tibble()
  # posterior means and their standard deviations
  res.prop.ranef <- ranef(res.prop)
  ranef_tbl <- data.frame(res.prop.ranef) %>% as_tibble()

  if (is.character(save)) {
    output_dir <- ifelse(grepl("[/]$", save), save, dirname(save))
    if (!dir.exists(output_dir)) dir.create(output_dir, recursive = T)
    output_sep <- ifelse(grepl("[/.]$", save), "", ".")
    write_tsv(ranef_tbl, paste(save, "ranef.tsv", sep = output_sep))
    write_tsv(sdse_tbl, paste(save, "sdse.tsv", sep = output_sep))
  }

  list(ranef = ranef_tbl, sdse = sdse_tbl)
}

#' Plot variable explained variance
#'
#' This function plots (square root of) variance explained by variables as a forest plot
#'
#' @param sdse_tbl Table containing square-root of estimated explained variance and standard errors
#'     (data.frame-like object)
#' @param colSample Column in "obs_tbl" specifying sample ID (str)
#' @param ci Confidence interval level (numeric between 0 and 1, default 0.95)
#'
#' @return ggplot object of a forest plot
#'
#' @import dplyr
#' @import ggplot2
#'
#' @export
plot_sdse <- function(sdse_tbl, colSample, ci = 0.95, xlim = c(-0.5, 1.5)) {
  n_se <- qnorm(1 - (1 - ci) / 2)
  p_tbl <- sdse_tbl %>%
    filter(
      grepl(":Celltype.\\(Intercept\\)", rowname)
    ) %>%
    mutate(
      rowname = sub(paste0("^", colSample, "$"), "Residual", sub("theta.(.*):Celltype.*", "\\1", rowname))
    ) %>%
    arrange(sd) %>%
    mutate(
      rowname = factor(rowname, levels = c("Residual", rowname[rowname != "Residual"]))
    ) %>%
    mutate(ci_l = sd - se * n_se, ci_h = sd + se * n_se)
  p <- (
    ggplot(p_tbl, aes(x = sd, y = rowname)) +
      geom_point(shape = 18, size = 3) +
      geom_errorbarh(aes(xmin = ci_l, xmax = ci_h), height = 0) +
      geom_vline(xintercept = 0, lty = 2) +
      xlab("Square root of explained variance") +
      coord_cartesian(xlim = xlim) +
      theme_bw() +
      theme(axis.title.y = element_blank())
  )
}

#' Plot estimated random effects of variables
#'
#' This function plots random effects of variables on cell type composition as a dot plot
#'
#' @param ranef_tbl Table of random effect estimates (mean and sd) extracted from fitted model
#'     (data.frame-like object)
#' @param vars A list specifying required categorical sample metadata variables and their order,
#'     e.g. list(size=c('small', 'medium', 'big'), price=c('cheap', 'expensive'))
#' @param celltypes If specified, only keep those cell types (vector of str)
#' @param celltype_order Determine how cell types are ordered. Either "hclust" which orders by
#'     hierarchical clustering, or a vector of cell types. (str or vector of str)
#' @param references If specified, fold changes are calculated relative to the specified level
#'     instead of global mean. Must be a list, e.g. list(size='small', price='cheap')
#' @param maxFC Cap fold change by this value (numeric, default 3)
#' @param LTSR2p Whether to convert LTSR to p value (logical, default FALSE)
#' @param filterLtsr Only keeps cell types of which at least one LTSR is greater or equal to
#'     specified value. (numeric, default 0)
#' @param swap_axes Whether to swap axis when plotting (logical, default FALSE)
#'
#' @return ggplot object of a dot plot
#'
#' @import dplyr
#' @import ggplot2
#' @importFrom scales squish
#'
#' @export
plot_ranef <- function(ranef_tbl, vars, celltypes = NULL, celltype_order = "hclust", references = NULL,
                       maxFC = 3, LTSR2p = F, highlightLtsr = 0.0, filterLtsr = 0.0, swap_axes = F) {
  ranef_tbl <- .getCondValLtsr(ranef_tbl, vars, celltypes = celltypes, references = references)

  condval_mat <- ranef_tbl %>%
    select(
      Celltype, grpval, condval
    ) %>%
    spread(
      "grpval", "condval"
    ) %>%
    column_to_rownames(
      var = "Celltype"
    ) %>%
    as.matrix()
  if (length(celltype_order) == 1 && celltype_order == "hclust") {
    dendy <- hclust(dist(condval_mat))
    ordered_celltype <- rownames(condval_mat)[dendy$ord]
  } else if (!is.null(celltype_order) && length(celltype_order) == dim(condval_mat)[1]) {
    ordered_celltype <- celltype_order
  }

  ranef_tbl <- ranef_tbl %>% mutate(
    Celltype = factor(Celltype, levels = ordered_celltype),
    condval = condval %>% pmin(log(maxFC)) %>% pmax(log(1 / maxFC)),
    ltsr = ltsr %>% pmin(0.9999) %>% pmax(0.5)
  )

  if (swap_axes) {
    ranef_tbl$Celltype <- factor(ranef_tbl$Celltype, levels = rev(levels(ranef_tbl$Celltype)))
    ranef_tbl$grpval <- factor(ranef_tbl$grpval, levels = rev(levels(ranef_tbl$grpval)))
  }

  if (filterLtsr > 0) {
    filtered_celltypes <- ranef_tbl %>%
      group_by(Celltype) %>%
      summarise(maxLtsr = max(ltsr)) %>%
      dplyr::filter(maxLtsr >= filterLtsr) %>%
      select(Celltype) %>%
      unlist(use.names = F)
    ranef_tbl <- ranef_tbl %>% dplyr::filter(Celltype %in% filtered_celltypes)
  }

  geom_dots <- geom_point(
    aes(
      fill = log2(exp(condval)),
      size = -log10(1 - ltsr)
    ),
    color = "white",
    shape = 21
  )

  if (swap_axes) {
    p <- (
      ggplot(ranef_tbl, aes(y = grpval, x = Celltype)) +
        facet_grid(grpvar ~ ., scales = "free_y", space = "free_y", switch = "x") +
        geom_dots
    )
  } else {
    p <- (
      ggplot(ranef_tbl, aes(x = grpval, y = Celltype)) +
        facet_grid(. ~ grpvar, scales = "free_x", space = "free_x", switch = "x") +
        geom_dots
    )
  }

  p <- (
    p + scale_fill_distiller(
      palette = "RdBu",
      limits = log2(c(1 / maxFC, maxFC)),
      breaks = log2(c(1 / maxFC, maxFC)),
      labels = c(paste0("1/", maxFC), maxFC),
      oob = squish,
      guide = guide_colorbar(
        title = "Fold change", title.position = "top", direction = "horizontal",
        barwidth = 5, barheight = 0.75, raster = F, order = 1)
    )
    + scale_size(
      limits = -log10(1 - c(0.5, 0.9999)),
      breaks = -log10(1 - c(0.5, 0.9, 0.99, 0.999, 0.9999)),
      range = c(0.5, 9),
      labels = ifelse(
        rep(LTSR2p, 5),
        c("0.5", "0.1", "0.01", "0.001", "<0.0001"),
        c("0.5", "0.9", "0.99", "0.999", ">0.9999")
      ),
      guide = guide_legend(
        title = ifelse(LTSR2p, "p", "LTSR"), reverse = T, order = 2,
        override.aes = list(fill = "black", color = "white")
      )
    )
    + theme_bw()
    + theme(
      axis.title.x = element_blank(),
      axis.title.y = element_blank(),
      strip.placement = "outside",
      strip.background = element_blank(),
      legend.spacing.y = unit(0.5, "line")
    )
  )

  if (highlightLtsr > 0) {
    p <- (
      p + geom_point(
        aes(
          color = ltsr > highlightLtsr,
          alpha = ltsr > highlightLtsr
        ),
        shape = 21, size = 9
      )
      + scale_color_manual(
        label = c(
          "", ifelse(LTSR2p, paste0("p < ", 1 - highlightLtsr), paste0("LTSR > ", highlightLtsr))
        ),
        values = c("white", "red"),
        guide = guide_legend(title = NULL, override.aes = list(size = 9), reverse = T, order = 3)
      )
      + scale_alpha_manual(values = c(0, 1), guide = F)
    )
  }

  p
}

#' Theme that mimics dotplots generated by Natsuhiko's code
#'
#' This function sets a number of options in ggplot2::theme() to mimic the style
#' of dotplots generated by Natsuhiko's code
#'
#' @param ... options passed to ggplot2::theme()
#'
#' @importFrom ggplot2 theme
#'
#' @export
theme_ctca <- function(...) {
  theme(
    axis.text.x = element_text(angle = 45, hjust = 1),
    axis.ticks = element_blank(),
    strip.text = element_blank(),
    panel.grid = element_blank(),
    panel.border = element_blank(),
    ...
  )
}

# %% [markdown]
# #### Material

# %%
ltsr <- CellTypeCompositionAnalysis(obs_tbl=meta, 
                            colSample='ID', 
                            colCelltype='MP_Assignment', 
                            colVarCats=c('Material'))
# Out:
# input prepared
# I(Y) ~ (1|Celltype)+(1|ID)+(1|Material)+(1|ID:Celltype)+(1|Material:Celltype)
# model constructed
# boundary (singular) fit: see help('isSingular')
# model fitted

# %%
options(repr.plot.height = 5, repr.plot.width = 3)
p <- plot_sdse(ltsr$sdse, 'ID')
p
# Out:
# plot without title

# %%
options(repr.plot.height = 6, repr.plot.width = 4)
plt_gen = plot_ranef(ltsr$ranef, 
                     vars=list(Material=c('cell', 'nuclei')),
                      celltypes=c('MP4', 'MP11','MP2',
                            'MP5',
                            'MP3','MP13','MP8',
                            'MP12',
                            'MP9','MP7',
                            'unresolved'
                                ),
                celltype_order=rev(c('MP4', 'MP11','MP2',
                            'MP5',
                            'MP3','MP13','MP8',
                            'MP12',
                            'MP9','MP7',
                                     'unresolved'
                                )),
                     highlightLtsr = 0.85) + theme_pubr(legend = "right") +
   theme(panel.grid.major=element_blank(), panel.grid.minor=element_blank(),
         axis.text.x=element_text(angle=60, vjust=1, hjust=1))
plt_gen
# Out:
# plot without title

# %%
ggsave('figures/LTSR_malignant_material_FINAL.pdf', width = 3.5, height = 5.5)

# %% [markdown]
# #### Clinical_status

# %%
ltsr <- CellTypeCompositionAnalysis(obs_tbl=meta %>% filter(Clinical_status %in% c('Primary', 'Recurrence')), 
                            colSample='ID', 
                            colCelltype='MP_Assignment', 
                            colVarCats=c('Clinical_status'))
# Out:
# input prepared
# I(Y) ~ (1|Celltype)+(1|ID)+(1|Clinical_status)+(1|ID:Celltype)+(1|Clinical_status:Celltype)
# model constructed
# boundary (singular) fit: see help('isSingular')
# model fitted

# %%
p <- plot_sdse(ltsr$sdse, 'ID')
p
# Out:
# plot without title

# %%
options(repr.plot.height = 6, repr.plot.width = 4)
plt_gen = plot_ranef(ltsr$ranef, 
                     vars=list(Clinical_status=c('Primary', 'Recurrence')),
                     celltypes=c('MP4', 'MP13','MP11','MP2',
                                 'MP12',
                            'MP5',
                            'MP3','MP8',
                            'MP9','MP7'
                                ),
                celltype_order=rev(c('MP4', 'MP13','MP11','MP2',
                                     'MP12',
                            'MP5',
                            'MP3','MP8',
                            'MP9','MP7'
                                )),
                     highlightLtsr = 0.85) + theme_pubr(legend = "right") +
   theme(panel.grid.major=element_blank(), panel.grid.minor=element_blank(),
         axis.text.x=element_text(angle=60, vjust=1, hjust=1))
plt_gen
# Out:
# plot without title

# %%
ggsave('figures/LTSR_malignant_Clinical_status_FINAL.pdf', width = 3.5, height = 5)
