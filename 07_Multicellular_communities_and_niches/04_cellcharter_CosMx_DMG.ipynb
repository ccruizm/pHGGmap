# %%
import anndata as ad
import squidpy as sq
import cellcharter as cc
import pandas as pd
import scanpy as sc
import scvi
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import sc_toolbox as sct
# Out:
# [rank: 0] Global seed set to 0

# %%
mpl.rcParams["figure.figsize"] = (5, 5)

# %%
adata_list = []
for sample in ['R5779_TMA2-S6', 'R5779_TMA3-S4']:
    adata = sq.read.nanostring(
        path=f'/projects/0/einf2548/cruiz/dmg/ST/SMI-0262_Broek.Vuurden_PrinsesMaxima-selected/5 Raw data/{sample}', 
        counts_file=f'{sample}_exprMat_file.csv',
        meta_file=f'{sample}_metadata_file.csv',
        fov_file=f'{sample}_fov_positions_file.csv'
    )

    # Flip y axis
    adata.obsm['spatial_fov'][:, 1] = np.max(adata.obsm['spatial_fov'][:, 1]) - adata.obsm['spatial_fov'][:, 1]

    # Remove negative probes
    adata = adata[:, [c for c in adata.var_names if 'NegPrb' not in c]].copy()
    
    adata.obs['sample'] = sample
    adata_list.append(adata)
# Out:
# WARNING: FOV `11` does not exist, skipping it.

# %%
adata = ad.concat(adata_list, axis=0, merge='same', pairwise=True, index_unique='_')

# 'spatial_fov' refers to global coordinates of the cells.
# Thus, we are going to use 'spatial_fov' and not 'spatial' as spatial coordinates.
adata.uns['spatial_fov'] = {s: {} for s in adata.obs['sample'].unique()}
adata.obs['sample'] = pd.Categorical(adata.obs['sample'])
adata
# Out:
# AnnData object with n_obs × n_vars = 67280 × 990
#     obs: 'fov', 'Area', 'AspectRatio', 'CenterX_global_px', 'CenterY_global_px', 'Width', 'Height', 'Mean.Histone', 'Max.Histone', 'Mean.G', 'Max.G', 'Mean.rRNA_MembraneStain_B2M', 'Max.rRNA_MembraneStain_B2M', 'Mean.GFAP', 'Max.GFAP', 'Mean.DAPI', 'Max.DAPI', 'cell_ID', 'sample'
#     uns: 'spatial_fov'
#     obsm: 'spatial', 'spatial_fov'

# %%
adata.obs['sample2'] = adata.obs['sample'].str.replace('_', '.')

# Create a new index by combining 'sample' column and the current index
adata.obs.index = adata.obs['sample2'] + '_' + adata.obs.index

# Strip the part after the last underscore in the new index
adata.obs.index = adata.obs.index.str.rsplit('_', n=1).str[0]

# %%
matching_indexes = adata.obs.index.intersection(metadata_df.index)

# %%
adata = adata[matching_indexes].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 26552 × 990
#     obs: 'fov', 'Area', 'AspectRatio', 'CenterX_global_px', 'CenterY_global_px', 'Width', 'Height', 'Mean.Histone', 'Max.Histone', 'Mean.G', 'Max.G', 'Mean.rRNA_MembraneStain_B2M', 'Max.rRNA_MembraneStain_B2M', 'Mean.GFAP', 'Max.GFAP', 'Mean.DAPI', 'Max.DAPI', 'cell_ID', 'sample', 'sample2'
#     uns: 'spatial_fov'
#     obsm: 'spatial', 'spatial_fov'

# %%
for column in metadata_df.columns:
    if column not in adata.obs.columns:
        adata.obs[column] = metadata_df[column]
adata.obs
# Out:
#                      fov   Area  AspectRatio  CenterX_global_px  \
# R5779.TMA2-S6_1_6      6  13541         2.06      -91818.593928
# R5779.TMA2-S6_2_6      6   9866         1.49      -90783.593928
# R5779.TMA2-S6_3_6      6  11085         1.44      -91065.593928
# R5779.TMA2-S6_4_6      6   6931         0.98      -94113.593928
# R5779.TMA2-S6_5_6      6  10243         1.22      -91193.593928
# ...                   ..    ...          ...                ...
# R5779.TMA3-S4_778_25  25  19899         1.47      204602.133870
# R5779.TMA3-S4_779_25  25   7369         1.75      204048.133870
# R5779.TMA3-S4_780_25  25  18654         1.90      204800.133870
# R5779.TMA3-S4_781_25  25   2768         2.58      205791.133870
# R5779.TMA3-S4_782_25  25   4364         3.64      203227.133870
#
#                       CenterY_global_px  Width  Height  Mean.Histone  \
# R5779.TMA2-S6_1_6          24598.076074    196      95          1574
# R5779.TMA2-S6_2_6          24597.076074    145      97          2271
# R5779.TMA2-S6_3_6          24595.076074    147     102           705
# R5779.TMA2-S6_4_6          24577.076074    107     109          2350
# R5779.TMA2-S6_5_6          24552.076074    151     124          3616
# ...                                 ...    ...     ...           ...
# R5779.TMA3-S4_778_25       53655.446082    187     127           870
# R5779.TMA3-S4_779_25       53630.446082    135      77           547
# R5779.TMA3-S4_780_25       53649.446082    219     115           285
# R5779.TMA3-S4_781_25       53611.446082     98      38           954
# R5779.TMA3-S4_782_25       53611.446082    142      39           591
#
#                       Max.Histone  Mean.G  ...  Run_Tissue_name  \
# R5779.TMA2-S6_1_6           14424      24  ...    R5779_TMA2-S6
# R5779.TMA2-S6_2_6           22200      24  ...    R5779_TMA2-S6
# R5779.TMA2-S6_3_6            4696      10  ...    R5779_TMA2-S6
# R5779.TMA2-S6_4_6            8616       4  ...    R5779_TMA2-S6
# R5779.TMA2-S6_5_6           14776      20  ...    R5779_TMA2-S6
# ...                           ...     ...  ...              ...
# R5779.TMA3-S4_778_25        11064      69  ...    R5779_TMA3-S4
# R5779.TMA3-S4_779_25         3332      74  ...    R5779_TMA3-S4
# R5779.TMA3-S4_780_25        13832      50  ...    R5779_TMA3-S4
# R5779.TMA3-S4_781_25         8520      12  ...    R5779_TMA3-S4
# R5779.TMA3-S4_782_25         5936      87  ...    R5779_TMA3-S4
#
#                       log10totalcounts    IFcolor  nb_clus  leiden_clus  \
# R5779.TMA2-S6_1_6             2.394452  #8E463CFF        j            8
# R5779.TMA2-S6_2_6             2.608526  #816562FF        j            8
# R5779.TMA2-S6_3_6             2.820858  #BA1F5EFF        j            8
# R5779.TMA2-S6_4_6             2.382017  #366959FF        j            8
# R5779.TMA2-S6_5_6             2.764176  #27A153FF        j            8
# ...                                ...        ...      ...          ...
# R5779.TMA3-S4_778_25          2.267172  #FF2721FF        c            2
# R5779.TMA3-S4_779_25          2.184691  #FF182CFF        d            3
# R5779.TMA3-S4_780_25          2.350248  #FF0D07FF        d            3
# R5779.TMA3-S4_781_25          1.397940  #FF2B05FF        c            1
# R5779.TMA3-S4_782_25          1.792392  #FF1A08FF        e            1
#
#                                         id               FOV        PMCID  \
# R5779.TMA2-S6_1_6        R5779.TMA2-S6_1_6   Run5779_S2_FOV6  PMCID448AAQ
# R5779.TMA2-S6_2_6        R5779.TMA2-S6_2_6   Run5779_S2_FOV6  PMCID448AAQ
# R5779.TMA2-S6_3_6        R5779.TMA2-S6_3_6   Run5779_S2_FOV6  PMCID448AAQ
# R5779.TMA2-S6_4_6        R5779.TMA2-S6_4_6   Run5779_S2_FOV6  PMCID448AAQ
# R5779.TMA2-S6_5_6        R5779.TMA2-S6_5_6   Run5779_S2_FOV6  PMCID448AAQ
# ...                                    ...               ...          ...
# R5779.TMA3-S4_778_25  R5779.TMA3-S4_778_25  Run5779_S3_FOV25  PMCID577AAL
# R5779.TMA3-S4_779_25  R5779.TMA3-S4_779_25  Run5779_S3_FOV25  PMCID577AAL
# R5779.TMA3-S4_780_25  R5779.TMA3-S4_780_25  Run5779_S3_FOV25  PMCID577AAL
# R5779.TMA3-S4_781_25  R5779.TMA3-S4_781_25  Run5779_S3_FOV25  PMCID577AAL
# R5779.TMA3-S4_782_25  R5779.TMA3-S4_782_25  Run5779_S3_FOV25  PMCID577AAL
#
#                      Replicate            ID_R
# R5779.TMA2-S6_1_6           R4  PMCID448AAQ_R4
# R5779.TMA2-S6_2_6           R4  PMCID448AAQ_R4
# R5779.TMA2-S6_3_6           R4  PMCID448AAQ_R4
# R5779.TMA2-S6_4_6           R4  PMCID448AAQ_R4
# R5779.TMA2-S6_5_6           R4  PMCID448AAQ_R4
# ...                        ...             ...
# R5779.TMA3-S4_778_25        R3  PMCID577AAL_R3
# R5779.TMA3-S4_779_25        R3  PMCID577AAL_R3
# R5779.TMA3-S4_780_25        R3  PMCID577AAL_R3
# R5779.TMA3-S4_781_25        R3  PMCID577AAL_R3
# R5779.TMA3-S4_782_25        R3  PMCID577AAL_R3
#
# [26552 rows x 42 columns]

# %%
sc.pp.filter_genes(adata, min_counts=3)
sc.pp.filter_cells(adata, min_counts=3)

# %%
adata.layers["counts"] = adata.X.copy()

sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)

# %%
scvi.settings.seed = 12345
scvi.model.SCVI.setup_anndata(
    adata, 
    layer="counts", 
    batch_key='PMCID'
)

model = scvi.model.SCVI(adata)
# Out:
# [rank: 0] Global seed set to 12345
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/abc.py:119: FutureWarning: SparseDataset is deprecated and will be removed in late 2024. It has been replaced by the public classes CSRDataset and CSCDataset.
#
# For instance checks, use `isinstance(X, (anndata.experimental.CSRDataset, anndata.experimental.CSCDataset))` instead.
#
# For creation, use `anndata.experimental.sparse_dataset(X)` instead.
#
#   return _abc_instancecheck(cls, instance)

# %%
model.train(early_stopping=True, enable_progress_bar=True)
# Out:
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# Epoch 1/301:   0%|                                                                                           | 0/301 [00:00<?, ?it/s]
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/abc.py:119: FutureWarning: SparseDataset is deprecated and will be removed in late 2024. It has been replaced by the public classes CSRDataset and CSCDataset.
#
# For instance checks, use `isinstance(X, (anndata.experimental.CSRDataset, anndata.experimental.CSCDataset))` instead.
#
# For creation, use `anndata.experimental.sparse_dataset(X)` instead.
#
#   return _abc_instancecheck(cls, instance)
# Epoch 301/301: 100%|████████████████████████████████████████████████████████████| 301/301 [08:20<00:00,  1.66s/it, loss=495, v_num=1]

# %%
adata.obsm['X_scVI'] = model.get_latent_representation(adata).astype(np.float32)

# %%
adata.obs['sample'] = pd.Categorical(adata.obs['sample'])
sq.gr.spatial_neighbors(adata, library_key='sample', coord_type='generic', delaunay=True, spatial_key='spatial_fov')
cc.gr.remove_long_links(adata)

# %%
cc.gr.aggregate_neighbors(adata, n_layers=3, use_rep='X_scVI', out_key='X_cellcharter', sample_key='fov')
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]

# %%
autok = cc.tl.ClusterAutoK(
    n_clusters=(2,20), 
    max_runs=10, 
    model_params=dict(
        random_state=12345,
        # If running on GPU
        trainer_params=dict(accelerator='gpu', devices=1)
    )
)

# %%
autok.fit(adata, use_rep='X_cellcharter')
# Out:
# Iteration 1/10
#   0%|          | 0/21 [00:00<?, ?it/s]
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# Iteration 2/10
#   0%|          | 0/21 [00:00<?, ?it/s]
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# Iteration 3/10
#   0%|          | 0/21 [00:00<?, ?it/s]
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# Iteration 4/10
#   0%|          | 0/21 [00:00<?, ?it/s]
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# Iteration 5/10
#   0%|          | 0/21 [00:00<?, ?it/s]
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# Iteration 6/10
#   0%|          | 0/21 [00:00<?, ?it/s]
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# Iteration 9/10
#   0%|          | 0/21 [00:00<?, ?it/s]
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(
# Convergence with a change in stability of 0.008810354033482832 reached after 9 iterations

# %%
cc.pl.autok_stability(autok)

# %%
adata.obs['cluster_cellcharter'] = autok.predict(adata, use_rep='X_cellcharter')
# Out:
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(

# %%
slide1 = sc.read('../data/tangram_R5779_TMA2-S6_FINAL.h5ad')
slide2 = sc.read('../data/tangram_R5779_TMA3-S4_FINAL.h5ad')

# %%
slide1.obs
# Out:
#                      fov   Area  AspectRatio  CenterX_global_px  \
# R5779.TMA2-S6_1_6      6  13541         2.06      -91818.593928
# R5779.TMA2-S6_2_6      6   9866         1.49      -90783.593928
# R5779.TMA2-S6_3_6      6  11085         1.44      -91065.593928
# R5779.TMA2-S6_4_6      6   6931         0.98      -94113.593928
# R5779.TMA2-S6_5_6      6  10243         1.22      -91193.593928
# ...                   ..    ...          ...                ...
# R5779.TMA2-S6_883_23  23   2322         1.33      -97051.218656
# R5779.TMA2-S6_884_23  23   3080         2.91      -96963.218656
# R5779.TMA2-S6_885_23  23   4482         2.29      -96829.218656
# R5779.TMA2-S6_886_23  23   9419         1.44      -95569.218656
# R5779.TMA2-S6_887_23  23   5486         1.51      -95154.218656
#
#                       CenterY_global_px  Width  Height  Mean.Histone  \
# R5779.TMA2-S6_1_6          24598.076074    196      95          1574
# R5779.TMA2-S6_2_6          24597.076074    145      97          2271
# R5779.TMA2-S6_3_6          24595.076074    147     102           705
# R5779.TMA2-S6_4_6          24577.076074    107     109          2350
# R5779.TMA2-S6_5_6          24552.076074    151     124          3616
# ...                                 ...    ...     ...           ...
# R5779.TMA2-S6_883_23      -33094.869861     61      46           236
# R5779.TMA2-S6_884_23      -33096.869861    125      43           913
# R5779.TMA2-S6_885_23      -33089.869861    128      56           930
# R5779.TMA2-S6_886_23      -33067.869861    144     100           556
# R5779.TMA2-S6_887_23      -33078.869861    118      78          1024
#
#                       Max.Histone  Mean.G  ...        PMCID  Replicate  \
# R5779.TMA2-S6_1_6           14424      24  ...  PMCID448AAQ         R4
# R5779.TMA2-S6_2_6           22200      24  ...  PMCID448AAQ         R4
# R5779.TMA2-S6_3_6            4696      10  ...  PMCID448AAQ         R4
# R5779.TMA2-S6_4_6            8616       4  ...  PMCID448AAQ         R4
# R5779.TMA2-S6_5_6           14776      20  ...  PMCID448AAQ         R4
# ...                           ...     ...  ...          ...        ...
# R5779.TMA2-S6_883_23         1416      19  ...  PMCID448AAQ         R3
# R5779.TMA2-S6_884_23         4500       9  ...  PMCID448AAQ         R3
# R5779.TMA2-S6_885_23         5620      25  ...  PMCID448AAQ         R3
# R5779.TMA2-S6_886_23         7928      20  ...  PMCID448AAQ         R3
# R5779.TMA2-S6_887_23         9736      13  ...  PMCID448AAQ         R3
#
#                                 ID_R  uniform_density  \
# R5779.TMA2-S6_1_6     PMCID448AAQ_R4         0.000243
# R5779.TMA2-S6_2_6     PMCID448AAQ_R4         0.000243
# R5779.TMA2-S6_3_6     PMCID448AAQ_R4         0.000243
# R5779.TMA2-S6_4_6     PMCID448AAQ_R4         0.000243
# R5779.TMA2-S6_5_6     PMCID448AAQ_R4         0.000243
# ...                              ...              ...
# R5779.TMA2-S6_883_23  PMCID448AAQ_R3         0.000243
# R5779.TMA2-S6_884_23  PMCID448AAQ_R3         0.000243
# R5779.TMA2-S6_885_23  PMCID448AAQ_R3         0.000243
# R5779.TMA2-S6_886_23  PMCID448AAQ_R3         0.000243
# R5779.TMA2-S6_887_23  PMCID448AAQ_R3         0.000243
#
#                       rna_count_based_density     x     y  tangram_prediction  \
# R5779.TMA2-S6_1_6                    0.000218  3095    42             TD_like
# R5779.TMA2-S6_2_6                    0.000274  4130    43            OPC_like
# R5779.TMA2-S6_3_6                    0.000315  3848    45          Cilia_like
# R5779.TMA2-S6_4_6                    0.000196   800    63             RG_like
# R5779.TMA2-S6_5_6                    0.000265  3720    88          Cilia_like
# ...                                       ...   ...   ...                 ...
# R5779.TMA2-S6_883_23                 0.000098  1805  4227            COP_like
# R5779.TMA2-S6_884_23                 0.000117  1893  4229           nIPC_like
# R5779.TMA2-S6_885_23                 0.000078  2027  4222            COP_like
# R5779.TMA2-S6_886_23                 0.000191  3287  4200             RG_like
# R5779.TMA2-S6_887_23                 0.000167  3702  4211          Cilia_like
#
#                      tangram_score leiden
# R5779.TMA2-S6_1_6         0.417731      2
# R5779.TMA2-S6_2_6         0.469717      3
# R5779.TMA2-S6_3_6         0.847367      2
# R5779.TMA2-S6_4_6         0.612234      1
# R5779.TMA2-S6_5_6         0.560510      2
# ...                            ...    ...
# R5779.TMA2-S6_883_23      0.781322      1
# R5779.TMA2-S6_884_23      0.698451      1
# R5779.TMA2-S6_885_23      0.629807      1
# R5779.TMA2-S6_886_23      0.659478      1
# R5779.TMA2-S6_887_23      0.418189      1
#
# [4121 rows x 48 columns]

# %%
# add tangram cell type assigments

obs_slide1 = slide1.obs[['tangram_prediction']].copy()
obs_slide2 = slide2.obs[['tangram_prediction']].copy()

merged_obs = pd.concat([obs_slide1, obs_slide2])

if not all(index in merged_obs.index for index in adata.obs.index):
    raise ValueError("Indexes of merged slides do not match indexes of adata.")

merged_obs = merged_obs.reindex(adata.obs.index)

adata.obs['tangram_prediction'] = merged_obs['tangram_prediction']

adata.obs
# Out:
#                      fov   Area  AspectRatio  CenterX_global_px  \
# R5779.TMA2-S6_1_6      6  13541         2.06      -91818.593928
# R5779.TMA2-S6_2_6      6   9866         1.49      -90783.593928
# R5779.TMA2-S6_3_6      6  11085         1.44      -91065.593928
# R5779.TMA2-S6_4_6      6   6931         0.98      -94113.593928
# R5779.TMA2-S6_5_6      6  10243         1.22      -91193.593928
# ...                   ..    ...          ...                ...
# R5779.TMA3-S4_778_25  25  19899         1.47      204602.133870
# R5779.TMA3-S4_779_25  25   7369         1.75      204048.133870
# R5779.TMA3-S4_780_25  25  18654         1.90      204800.133870
# R5779.TMA3-S4_781_25  25   2768         2.58      205791.133870
# R5779.TMA3-S4_782_25  25   4364         3.64      203227.133870
#
#                       CenterY_global_px  Width  Height  Mean.Histone  \
# R5779.TMA2-S6_1_6          24598.076074    196      95          1574
# R5779.TMA2-S6_2_6          24597.076074    145      97          2271
# R5779.TMA2-S6_3_6          24595.076074    147     102           705
# R5779.TMA2-S6_4_6          24577.076074    107     109          2350
# R5779.TMA2-S6_5_6          24552.076074    151     124          3616
# ...                                 ...    ...     ...           ...
# R5779.TMA3-S4_778_25       53655.446082    187     127           870
# R5779.TMA3-S4_779_25       53630.446082    135      77           547
# R5779.TMA3-S4_780_25       53649.446082    219     115           285
# R5779.TMA3-S4_781_25       53611.446082     98      38           954
# R5779.TMA3-S4_782_25       53611.446082    142      39           591
#
#                       Max.Histone  Mean.G  ...                    id  \
# R5779.TMA2-S6_1_6           14424      24  ...     R5779.TMA2-S6_1_6
# R5779.TMA2-S6_2_6           22200      24  ...     R5779.TMA2-S6_2_6
# R5779.TMA2-S6_3_6            4696      10  ...     R5779.TMA2-S6_3_6
# R5779.TMA2-S6_4_6            8616       4  ...     R5779.TMA2-S6_4_6
# R5779.TMA2-S6_5_6           14776      20  ...     R5779.TMA2-S6_5_6
# ...                           ...     ...  ...                   ...
# R5779.TMA3-S4_778_25        11064      69  ...  R5779.TMA3-S4_778_25
# R5779.TMA3-S4_779_25         3332      74  ...  R5779.TMA3-S4_779_25
# R5779.TMA3-S4_780_25        13832      50  ...  R5779.TMA3-S4_780_25
# R5779.TMA3-S4_781_25         8520      12  ...  R5779.TMA3-S4_781_25
# R5779.TMA3-S4_782_25         5936      87  ...  R5779.TMA3-S4_782_25
#
#                                    FOV        PMCID  Replicate  \
# R5779.TMA2-S6_1_6      Run5779_S2_FOV6  PMCID448AAQ         R4
# R5779.TMA2-S6_2_6      Run5779_S2_FOV6  PMCID448AAQ         R4
# R5779.TMA2-S6_3_6      Run5779_S2_FOV6  PMCID448AAQ         R4
# R5779.TMA2-S6_4_6      Run5779_S2_FOV6  PMCID448AAQ         R4
# R5779.TMA2-S6_5_6      Run5779_S2_FOV6  PMCID448AAQ         R4
# ...                                ...          ...        ...
# R5779.TMA3-S4_778_25  Run5779_S3_FOV25  PMCID577AAL         R3
# R5779.TMA3-S4_779_25  Run5779_S3_FOV25  PMCID577AAL         R3
# R5779.TMA3-S4_780_25  Run5779_S3_FOV25  PMCID577AAL         R3
# R5779.TMA3-S4_781_25  Run5779_S3_FOV25  PMCID577AAL         R3
# R5779.TMA3-S4_782_25  Run5779_S3_FOV25  PMCID577AAL         R3
#
#                                 ID_R  n_counts  _scvi_batch  _scvi_labels  \
# R5779.TMA2-S6_1_6     PMCID448AAQ_R4       248            6             0
# R5779.TMA2-S6_2_6     PMCID448AAQ_R4       406            6             0
# R5779.TMA2-S6_3_6     PMCID448AAQ_R4       662            6             0
# R5779.TMA2-S6_4_6     PMCID448AAQ_R4       241            6             0
# R5779.TMA2-S6_5_6     PMCID448AAQ_R4       581            6             0
# ...                              ...       ...          ...           ...
# R5779.TMA3-S4_778_25  PMCID577AAL_R3       185            7             0
# R5779.TMA3-S4_779_25  PMCID577AAL_R3       153            7             0
# R5779.TMA3-S4_780_25  PMCID577AAL_R3       224            7             0
# R5779.TMA3-S4_781_25  PMCID577AAL_R3        25            7             0
# R5779.TMA3-S4_782_25  PMCID577AAL_R3        62            7             0
#
#                      cluster_cellcharter tangram_prediction
# R5779.TMA2-S6_1_6                      6            TD_like
# R5779.TMA2-S6_2_6                      6           OPC_like
# R5779.TMA2-S6_3_6                      6         Cilia_like
# R5779.TMA2-S6_4_6                      6            RG_like
# R5779.TMA2-S6_5_6                      6         Cilia_like
# ...                                  ...                ...
# R5779.TMA3-S4_778_25                   9    TAM_homeostatic
# R5779.TMA3-S4_779_25                   9          nIPC_like
# R5779.TMA3-S4_780_25                   9            TD_like
# R5779.TMA3-S4_781_25                   9       Tri_IPC_like
# R5779.TMA3-S4_782_25                   9            AC_like
#
# [26552 rows x 47 columns]

# %%
cc.gr.enrichment(
    adata,
    group_key='tangram_prediction',
    label_key='cluster_cellcharter'
)
# Out:
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/pandas/core/internals/blocks.py:393: RuntimeWarning: divide by zero encountered in log2
#   result = func(self.values, **kwargs)

# %%
cc.pl.enrichment(
    adata,
    group_key='tangram_prediction',
    label_key='cluster_cellcharter',
    cluster_labels=False,
    # labels = [16, 1, 17, 2, 14, 9, 5, 6, 10, 7, 8, 11, 13, 19, 18, 0, 12, 4, 3, 15],
    figsize=(8, 4),
    size_threshold=1,
    color_threshold=0.5
)
# Out:
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/anndata/_core/anndata.py:430: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/anndata/_core/aligned_df.py:67: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/scanpy/plotting/_dotplot.py:757: RuntimeWarning: invalid value encountered in power
#   size = frac**size_exponent

# %%
gmm = cc.tl.Cluster(
    n_clusters=9, 
    random_state=12345,
    # If running on GPU
    trainer_params=dict(accelerator='gpu', devices=1)
)

# %%
gmm.fit(adata, use_rep='X_cellcharter')
adata.obs['cellcharter_9'] = gmm.predict(adata, use_rep='X_cellcharter')
# Out:
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/cruiz2/miniconda3/envs/cellcharter/lib/pyt ...
#   rank_zero_warn(

# %%
adata.obs['PMCID_FOV'] = adata.obs.PMCID.astype(str) + '_' + adata.obs.FOV.astype(str)
adata.obs['PMCID_FOV'] = adata.obs['PMCID_FOV'].astype('category')

# %%
cc.gr.enrichment(adata, group_key='tangram_prediction', label_key='cellcharter_9', observed_expected=True)
cc.pl.enrichment(
    adata,
    group_key='tangram_prediction',
    label_key='cellcharter_9',
    cluster_labels=True,
    figsize=(8, 3),
    size_threshold=1,
    color_threshold=0.5
)
# Out:
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/anndata/_core/anndata.py:430: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/anndata/_core/aligned_df.py:67: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/cruiz2/miniconda3/envs/cellcharter/lib/python3.10/site-packages/scanpy/plotting/_dotplot.py:757: RuntimeWarning: invalid value encountered in power
#   size = frac**size_exponent

# %%
cc.pl.proportion(
    adata,
    group_key='FOV',
    label_key='cellcharter_9',
    figsize=(10, 4),
    rotation_xlabel=90
)

# %%
cc.pl.proportion(
    adata,
    group_key='PMCID',
    label_key='cellcharter_9',
    figsize=(6, 4),
    rotation_xlabel=90
)
