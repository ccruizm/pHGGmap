# %%
library(ArchR)
library(BSgenome.Hsapiens.UCSC.hg38)
set.seed(1)
# Out:
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
#
#
# ArchR : Version 1.0.2
# For more information see our website : www.ArchRProject.com
# If you encounter a bug please report : https://github.com/GreenleafLab/ArchR/issues
#
# Loading Required Packages...
#
# 	Loading Package : grid v4.1.2
#
# 	Loading Package : gridExtra v2.3
#
# 	Loading Package : gtools v3.9.3
#
# 	Loading Package : gtable v0.3.1
#
# 	Loading Package : ggplot2 v3.3.6
#
# 	Loading Package : magrittr v2.0.3
#
# Warning message:
# “package ‘magrittr’ was built under R version 4.1.3”
# 	Loading Package : plyr v1.8.7
#
# 	Loading Package : stringr v1.4.1
#
# 	Loading Package : data.table v1.14.2
#
# 	Loading Package : matrixStats v0.62.0
#
# 	Loading Package : S4Vectors v0.32.4
#
# 	Loading Package : GenomicRanges v1.46.1
#
# 	Loading Package : BiocGenerics v0.40.0
#
# 	Loading Package : Matrix v1.5.4.1
#
# Warning message:
# “package ‘Matrix’ was built under R version 4.1.3”
# 	Loading Package : Rcpp v1.0.8.3
#
# 	Loading Package : SummarizedExperiment v1.24.0
#
# 	Loading Package : rhdf5 v2.38.1
#
# Loading required package: BSgenome
#
# Loading required package: Biostrings
#
# Loading required package: XVector
#
#
# Attaching package: ‘XVector’
#
#
# The following object is masked from ‘package:plyr’:
#
#     compact
#
#
#
# Attaching package: ‘Biostrings’
#
#
# The following object is masked from ‘package:grid’:
#
#     pattern
#
#
# The following object is masked from ‘package:base’:
#
#     strsplit
#
#
# Loading required package: rtracklayer

# %%
suppressPackageStartupMessages({
    library(Seurat)
    library(ggplot2)
    library(dplyr)
    library(tibble)
    library(stringr)
    library(dittoSeq)
    library(future)
    library(tidyr)
    library(purrr)
    library(data.table)
    library(reticulate)
    # plan("multicore", workers = 12)
    # options(future.globals.maxSize = 1000 * 1024^5)
    options(stringsAsFactors = FALSE)
    set.seed(123)
})

# %%
addArchRThreads(threads = 32) 
addArchRGenome("hg38")
# Out:
# Setting default number of Parallel threads to 32.
#
# Setting default genome to Hg38.

# %% [markdown]
# ### Load DMG atlas ATAC (matching Signac filtered cells)

# %%
dmg_atlas <- loadArchRProject('./ArchRSubset/')
# Out:
# Successfully loaded ArchRProject!
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|

# %%
use_condaenv('multi_integration')

# %%
sc <- import("scanpy")
adata <- sc$read_h5ad("../mosaic_integration_scglue/dmg_atlas_atac_full_PEAKS.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 124594 × 378298
#     obs: 'total', 'duplicate', 'chimeric', 'unmapped', 'lowmapq', 'mitochondrial', 'nonprimary', 'passed_filters', 'is__cell_barcode', 'excluded_reason', 'TSS_fragments', 'DNase_sensitive_region_fragments', 'enhancer_region_fragments', 'promoter_region_fragments', 'on_target_fragments', 'blacklist_region_fragments', 'peak_region_fragments', 'peak_region_cutsites', 'nCount_ATAC', 'nFeature_ATAC', 'SampleID', 'nucleosome_signal', 'nucleosome_percentile', 'TSS.enrichment', 'TSS.percentile', 'pct_reads_in_peaks', 'blacklist_ratio', 'high.tss', 'nucleosome_group', 'scDblFinder.score', 'scDblFinder.class', 'amulet_pvalue', 'amulet_qvalue', 'scDblFinder.p', 'dbl_combined_score', 'ID', 'Study', 'Institute', 'Preservation_method', 'Diagnosis', 'Tumor_type', 'Tumor_subtype', 'Location', 'Source', 'Clinical_status', 'Isolation_method', 'Sc_platform_RNA', 'Sc_platform_ATAC', 'Sc_multiome', 'Raw_data_available', 'Counts', 'Genome_version', 'Paired_sample', 'Multisector', 'Gender', 'Age_years', 'Dexamethasone_prior_surgery', 'Survival', 'Survival_months', 'Mitosis', 'Ki67', 'Methylation_array', 'H3F3A', 'H3C3', 'HIST1H3B', 'HIST2H3C', 'TP53', 'EGFR', 'PDGFRA', 'SUFU', 'NF1', 'pTERT', 'PIK3CA', 'PIK3R1', 'ATRX', 'PTEN', 'ASXL1', 'BCOR', 'BCORL1', 'SMC1A', 'WT1', 'PPM1D', 'ACVR1', 'TSHR', 'BRAF', 'GNAQ', 'LMNA', 'KIT', 'ARID1A', 'KRAS', 'Other', 'predicted.id.filtered', 'Batch_for_correction', 'cell_id', 'modality', 'domain', 'gex_barcode', 'atac_barcode', 'is_cell', 'gex_raw_reads', 'gex_mapped_reads', 'gex_conf_intergenic_reads', 'gex_conf_exonic_reads', 'gex_conf_intronic_reads', 'gex_conf_exonic_unique_reads', 'gex_conf_exonic_antisense_reads', 'gex_conf_exonic_dup_reads', 'gex_exonic_umis', 'gex_conf_intronic_unique_reads', 'gex_conf_intronic_antisense_reads', 'gex_conf_intronic_dup_reads', 'gex_intronic_umis', 'gex_conf_txomic_unique_reads', 'gex_umis_count', 'gex_genes_count', 'atac_raw_reads', 'atac_unmapped_reads', 'atac_lowmapq', 'atac_dup_reads', 'atac_chimeric_reads', 'atac_mitochondrial_reads', 'atac_TSS_fragments', 'atac_peak_region_fragments', 'atac_peak_region_cutsites', 'batch', 'n_counts', 'MP'
#     var: 'count-0', 'percentile-0', 'count-1', 'percentile-1', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'chrom', 'chromStart', 'chromEnd'
#     uns: 'Batch_for_correction_colors', 'MP_colors', 'Study_colors', 'cell_id_colors', 'hvg', 'log1p', 'neighbors', 'umap'
#     obsm: 'X_lsi', 'X_umap'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
meta <- adata$obs

# Access the cellnames
cell_names <- rownames(meta)

# Define the pattern and replacement
pattern <- "(.*)_(.*)$"
replacement <- "\\1#\\2"

# Apply the pattern and replacement using sub
rownames(meta) <- sub(pattern, replacement, cell_names)

meta$cell_names <- rownames(meta)
# Subset the DataFrame to include only rows with cell names in dmg_atlas$cellNames
meta <- meta[meta$cell_names %in% dmg_atlas$cellNames, ]
meta
# Out:
#                                            total  duplicate chimeric unmapped
# atac_T19-91014#AAACGAAAGACCCTAT-1           37892 15065      1        438
# atac_T19-91014#AAACGAAAGCGTTGCC-1           22601  6146      0        246
# atac_T19-91014#AAACGAAAGTGAATAC-1           21580  5723      1        213
# atac_T19-91014#AAACGAAAGTGCCCTG-1           28527  7851      0        319
# atac_T19-91014#AAACGAAAGTGTAATG-1           27213  9888      2        323
# atac_T19-91014#AAACGAACAAATGCTC-1           32533  8763      0        352
# atac_T19-91014#AAACGAACACGCCGAT-1           17835  5161      3        213
# atac_T19-91014#AAACGAACAGGTGTCC-1           23349  5489      2        242
# atac_T19-91014#AAACGAAGTACGGAGT-1           66244 12557      6        786
# atac_T19-91014#AAACGAAGTATCCCTC-1           20966  4675      1        164
# atac_T19-91014#AAACGAAGTATCTCAG-1           40695 10281      2        501
# atac_T19-91014#AAACGAAGTCAGACGA-1           10269  1979      1        139
# atac_T19-91014#AAACGAAGTGAAACAT-1           24766 10011      1        283
# atac_T19-91014#AAACGAATCGATGTAC-1           47801 14673      3        458
# atac_T19-91014#AAACTCGCAACGTAGG-1          atac_T19-91014#AAACTCGCAACGTAGG-1
# atac_T19-91014#AAACTCGCACGCTGTG-1          atac_T19-91014#AAACTCGCACGCTGTG-1
# atac_T19-91014#AAACTCGCAGAACAGC-1          atac_T19-91014#AAACTCGCAGAACAGC-1
# atac_T19-91014#AAACTCGGTAAACGTA-1          atac_T19-91014#AAACTCGGTAAACGTA-1
# atac_T19-91014#AAACTCGGTACTTCGA-1          atac_T19-91014#AAACTCGGTACTTCGA-1
# atac_T19-91014#AAACTCGGTAGCATGG-1          atac_T19-91014#AAACTCGGTAGCATGG-1
# atac_T19-91014#AAACTCGGTATTGTGC-1          atac_T19-91014#AAACTCGGTATTGTGC-1
# atac_T19-91014#AAACTCGGTTCACGTA-1          atac_T19-91014#AAACTCGGTTCACGTA-1
# atac_T19-91014#AAACTCGTCCATGACA-1          atac_T19-91014#AAACTCGTCCATGACA-1
# atac_T19-91014#AAACTCGTCTGCGTCT-1          atac_T19-91014#AAACTCGTCTGCGTCT-1
# atac_T19-91014#AAACTGCAGGAGTACC-1          atac_T19-91014#AAACTGCAGGAGTACC-1
# atac_T19-91014#AAACTGCAGGCGCTTC-1          atac_T19-91014#AAACTGCAGGCGCTTC-1
# atac_T19-91014#AAACTGCAGTAGTGTA-1          atac_T19-91014#AAACTGCAGTAGTGTA-1
# ⋮                                          ⋮
# multiome_P-6774_S-10146#TTTGGTAAGGGTGGAT-1 multiome_P-6774_S-10146#TTTGGTAAGGGTGGAT-1
# multiome_P-6774_S-10146#TTTGGTAAGTTGTCCC-1 multiome_P-6774_S-10146#TTTGGTAAGTTGTCCC-1
# multiome_P-6774_S-10146#TTTGGTGCAACTGGCT-1 multiome_P-6774_S-10146#TTTGGTGCAACTGGCT-1
# multiome_P-6774_S-10146#TTTGGTGCACATACTG-1 multiome_P-6774_S-10146#TTTGGTGCACATACTG-1
# multiome_P-6774_S-10146#TTTGGTGCACTTCATC-1 multiome_P-6774_S-10146#TTTGGTGCACTTCATC-1
# multiome_P-6774_S-10146#TTTGGTGCAGCAATAA-1 multiome_P-6774_S-10146#TTTGGTGCAGCAATAA-1
# multiome_P-6774_S-10146#TTTGTCCCAACCCTCC-1 multiome_P-6774_S-10146#TTTGTCCCAACCCTCC-1
# multiome_P-6774_S-10146#TTTGTCCCACTAAATC-1 multiome_P-6774_S-10146#TTTGTCCCACTAAATC-1
# multiome_P-6774_S-10146#TTTGTCCCATGGCCCA-1 multiome_P-6774_S-10146#TTTGTCCCATGGCCCA-1
# multiome_P-6774_S-10146#TTTGTCTAGGAGTCTT-1 multiome_P-6774_S-10146#TTTGTCTAGGAGTCTT-1
# multiome_P-6774_S-10146#TTTGTCTAGGCAACAA-1 multiome_P-6774_S-10146#TTTGTCTAGGCAACAA-1
# multiome_P-6774_S-10146#TTTGTGAAGATGGAGC-1 multiome_P-6774_S-10146#TTTGTGAAGATGGAGC-1
# multiome_P-6774_S-10146#TTTGTGAAGCAGCTCA-1 multiome_P-6774_S-10146#TTTGTGAAGCAGCTCA-1
# multiome_P-6774_S-10146#TTTGTGAAGCCGCAGT-1 multiome_P-6774_S-10146#TTTGTGAAGCCGCAGT-1
# multiome_P-6774_S-10146#TTTGTGAAGTTAGCTA-1 multiome_P-6774_S-10146#TTTGTGAAGTTAGCTA-1
# multiome_P-6774_S-10146#TTTGTGGCAAGGAATC-1 multiome_P-6774_S-10146#TTTGTGGCAAGGAATC-1
# multiome_P-6774_S-10146#TTTGTGGCAAGGTACG-1 multiome_P-6774_S-10146#TTTGTGGCAAGGTACG-1
# multiome_P-6774_S-10146#TTTGTGGCACCTCGCT-1 multiome_P-6774_S-10146#TTTGTGGCACCTCGCT-1
# multiome_P-6774_S-10146#TTTGTGGCACGTAATT-1 multiome_P-6774_S-10146#TTTGTGGCACGTAATT-1
# multiome_P-6774_S-10146#TTTGTGGCACTTGTTC-1 multiome_P-6774_S-10146#TTTGTGGCACTTGTTC-1
# multiome_P-6774_S-10146#TTTGTGGCAGCAAATA-1 multiome_P-6774_S-10146#TTTGTGGCAGCAAATA-1
# multiome_P-6774_S-10146#TTTGTGGCAGCAACAG-1 multiome_P-6774_S-10146#TTTGTGGCAGCAACAG-1
# multiome_P-6774_S-10146#TTTGTGGCATGCTATG-1 multiome_P-6774_S-10146#TTTGTGGCATGCTATG-1
# multiome_P-6774_S-10146#TTTGTGGCATTATGAC-1 multiome_P-6774_S-10146#TTTGTGGCATTATGAC-1
# multiome_P-6774_S-10146#TTTGTGTTCAAGTGAG-1 multiome_P-6774_S-10146#TTTGTGTTCAAGTGAG-1
# multiome_P-6774_S-10146#TTTGTGTTCCTAGTAA-1 multiome_P-6774_S-10146#TTTGTGTTCCTAGTAA-1
# multiome_P-6774_S-10146#TTTGTTGGTAGGATTT-1 multiome_P-6774_S-10146#TTTGTTGGTAGGATTT-1
# multiome_P-6774_S-10146#TTTGTTGGTTGGATAT-1 multiome_P-6774_S-10146#TTTGTTGGTTGGATAT-1
# multiome_P-6774_S-10146#TTTGTTGGTTGTAACG-1 multiome_P-6774_S-10146#TTTGTTGGTTGTAACG-1
# multiome_P-6774_S-10146#TTTGTTGGTTTATCGC-1 multiome_P-6774_S-10146#TTTGTTGGTTTATCGC-1

# %%
table(meta$MP)
# Out:
#          ACLike       Astrocyte             C1Q         COPLike       CiliaLike
#            6957            2894            4252            6074            1927
#     Endothelial          GBlike          GWLike     Homeostatic            IL1B
#             684            3205            3947            1139            1073
#         IPCLike      LipidLaden        Lymphoid  MonoNeutrophil           Mural
#            3887            1611             856            2785             898
#          Neuron             OPC         OPCLike Oligodendrocyte          RGLike
#            2632            2548           18892           15321            8967
#       Scavenger          TDLike      TriIPCLike
#            3346           28077            1988

# %%
meta$MP <- recode(meta$MP, 
                  'RGLike' = 'C1_RGLike', 
                  'TriIPCLike' = 'C2_TriIPCLike',
                  'IPCLike' = 'C3_IPCLike',
                  'OPCLike' = 'C4_OPCLike',
                  'COPLike' = 'C5_COPLike',
                  'ACLike' = 'C6_ACLike',
                  'CiliaLike' = 'C7_CiliaLike',
                  'GBlike' = 'C10_GBLike',
                  'TDLike' = 'C8_TDLike',
                  'GWLike' = 'C9_GWLike',
                  'Oligodendrocyte' = 'C11_Oligodendrocyte',
                  'OPC' = 'C12_OPC',
                  'Astrocyte' = 'C13_Astrocyte',
                  'Neuron' = 'C14_Neuron',
                  'MonoNeutrophil' = 'C15_MonoNeutrophil',
                  'C1Q' = 'C16_C1Q',
                  'LipidLaden' = 'C17_LipidLaden',
                  'Scavenger' = 'C18_Scavenger',
                  'IL1B' = 'C19_IL1B',
                  'Homeostatic' = 'C20_Homeostatic',
                  'Lymphoid' = 'C21_Lymphoid',
                  'Endothelial' = 'C22_Endothelial',
                  'Mural' = 'C23_Mural')

# %%
dmg_atlas <- addCellColData(ArchRProj = dmg_atlas, data = as.character(meta$MP),
    cells = rownames(meta), name = "MP", force = TRUE)
dmg_atlas
# Out:
# Overriding previous entry for MP
#
#
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
# class: ArchRProject
# outputDirectory: /gpfs/work2/0/einf2548/cruiz/dmg/notebooks/scATAC/archr/ArchRSubset
# samples(21): atac_T20-90296 atac_T19-91014 ... atac_P-2687_S-2688
#   atac_P-6255_S-8500
# sampleColData names(1): ArrowFiles
# cellColData names(21): Sample TSSEnrichment ... FRIP MPv2
# numberOfCells(1): 123960
# medianTSS(1): 8.384
# medianFrags(1): 11181

# %%
p1 <- plotEmbedding(
    dmg_atlas, 
    colorBy = "cellColData", 
    name = "MP", 
     embedding = "UMAPGlue"
)
p1
# Out:
# ArchR logging to : ArchRLogs/ArchR-plotEmbedding-3aed7a7162d504-Date-2024-09-09_Time-21-11-33.log
# If there is an issue, please report to github with logFile!
#
# Getting UMAP Embedding
#
# ColorBy = cellColData
#
# Plotting Embedding
#
# 1
# Length of unique values greater than palette, interpolating..
#
#
#
# ArchR logging successful to : ArchRLogs/ArchR-plotEmbedding-3aed7a7162d504-Date-2024-09-09_Time-21-11-33.log
# plot without title

# %%
library(BSgenome.Hsapiens.UCSC.hg38)
dmg_atlas <- addGroupCoverages(ArchRProj = dmg_atlas, groupBy = "MP", force=TRUE)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addGroupCoverages-3aed7a5eaac303-Date-2024-09-09_Time-21-11-48.log
# If there is an issue, please report to github with logFile!
#
# C1_RGLike (1 of 23) : CellGroups N = 5
#
# C2_TriIPCLike (2 of 23) : CellGroups N = 5
#
# C3_IPCLike (3 of 23) : CellGroups N = 5
#
# C4_OPCLike (4 of 23) : CellGroups N = 5
#
# C5_COPLike (5 of 23) : CellGroups N = 3
#
# C6_ACLike (6 of 23) : CellGroups N = 5
#
# C7_CiliaLike (7 of 23) : CellGroups N = 4
#
# C8_TDLike (8 of 23) : CellGroups N = 5
#
# C9_GWLike (9 of 23) : CellGroups N = 5
#
# C10_GBLike (10 of 23) : CellGroups N = 5
#
# C11_Oligodendrocyte (11 of 23) : CellGroups N = 5
#
# C12_OPC (12 of 23) : CellGroups N = 5
#
# C13_Astrocyte (13 of 23) : CellGroups N = 5
#
# C14_Neuron (14 of 23) : CellGroups N = 5
#
# C15_MonoNeutrophil (15 of 23) : CellGroups N = 5
#
# C16_C1Q (16 of 23) : CellGroups N = 5
#
# C17_LipidLaden (17 of 23) : CellGroups N = 5
#
# C18_Scavenger (18 of 23) : CellGroups N = 5
#
# C19_IL1B (19 of 23) : CellGroups N = 5
#
# C20_Homeostatic (20 of 23) : CellGroups N = 5
#
# C21_Lymphoid (21 of 23) : CellGroups N = 5
#
# C22_Endothelial (22 of 23) : CellGroups N = 4
#
# C23_Mural (23 of 23) : CellGroups N = 4
#
# 2024-09-09 21:12:07 : Creating Coverage Files!, 0.311 mins elapsed.
#
# 2024-09-09 21:12:07 : Batch Execution w/ safelapply!, 0.311 mins elapsed.
#
# 2024-09-09 21:45:29 : Adding Kmer Bias to Coverage Files!, 33.684 mins elapsed.
#
# Completed Kmer Bias Calculation
#
# Adding Kmer Bias (1 of 110)
#
# Adding Kmer Bias (2 of 110)
#
# Adding Kmer Bias (3 of 110)
#
# Adding Kmer Bias (4 of 110)
#
# Adding Kmer Bias (5 of 110)
#
# Adding Kmer Bias (6 of 110)
#
# Adding Kmer Bias (7 of 110)
#
# Adding Kmer Bias (8 of 110)
#
# Adding Kmer Bias (9 of 110)
#
# Adding Kmer Bias (10 of 110)
#
# Adding Kmer Bias (11 of 110)
#
# Adding Kmer Bias (12 of 110)
#
# Adding Kmer Bias (13 of 110)
#
# Adding Kmer Bias (14 of 110)
#
# Adding Kmer Bias (15 of 110)
#
# Adding Kmer Bias (16 of 110)
#
# Adding Kmer Bias (17 of 110)
#
# Adding Kmer Bias (18 of 110)
#
# Adding Kmer Bias (19 of 110)
#
# Adding Kmer Bias (20 of 110)
#
# Adding Kmer Bias (21 of 110)
#
# Adding Kmer Bias (22 of 110)
#
# Adding Kmer Bias (23 of 110)
#
# Adding Kmer Bias (24 of 110)
#
# Adding Kmer Bias (25 of 110)
#
# Adding Kmer Bias (26 of 110)
#
# Adding Kmer Bias (27 of 110)
#
# Adding Kmer Bias (28 of 110)
#
# Adding Kmer Bias (29 of 110)
#
# Adding Kmer Bias (30 of 110)
#
# Adding Kmer Bias (31 of 110)
#
# Adding Kmer Bias (32 of 110)
#
# Adding Kmer Bias (33 of 110)
#
# Adding Kmer Bias (34 of 110)
#
# Adding Kmer Bias (35 of 110)
#
# Adding Kmer Bias (36 of 110)
#
# Adding Kmer Bias (37 of 110)
#
# Adding Kmer Bias (38 of 110)
#
# Adding Kmer Bias (39 of 110)
#
# Adding Kmer Bias (40 of 110)
#
# Adding Kmer Bias (41 of 110)
#
# Adding Kmer Bias (42 of 110)
#
# Adding Kmer Bias (43 of 110)
#
# Adding Kmer Bias (44 of 110)
#
# Adding Kmer Bias (45 of 110)
#
# Adding Kmer Bias (46 of 110)
#
# Adding Kmer Bias (47 of 110)
#
# Adding Kmer Bias (48 of 110)
#
# Adding Kmer Bias (49 of 110)
#
# Adding Kmer Bias (50 of 110)
#
# Adding Kmer Bias (51 of 110)
#
# Adding Kmer Bias (52 of 110)
#
# Adding Kmer Bias (53 of 110)
#
# Adding Kmer Bias (54 of 110)
#
# Adding Kmer Bias (55 of 110)
#
# Adding Kmer Bias (56 of 110)
#
# Adding Kmer Bias (57 of 110)
#
# Adding Kmer Bias (58 of 110)
#
# Adding Kmer Bias (59 of 110)
#
# Adding Kmer Bias (60 of 110)
#
# Adding Kmer Bias (61 of 110)
#
# Adding Kmer Bias (62 of 110)
#
# Adding Kmer Bias (63 of 110)
#
# Adding Kmer Bias (64 of 110)
#
# Adding Kmer Bias (65 of 110)
#
# Adding Kmer Bias (66 of 110)
#
# Adding Kmer Bias (67 of 110)
#
# Adding Kmer Bias (68 of 110)
#
# Adding Kmer Bias (69 of 110)
#
# Adding Kmer Bias (70 of 110)
#
# Adding Kmer Bias (71 of 110)
#
# Adding Kmer Bias (72 of 110)
#
# Adding Kmer Bias (73 of 110)
#
# Adding Kmer Bias (74 of 110)
#
# Adding Kmer Bias (75 of 110)
#
# Adding Kmer Bias (76 of 110)
#
# Adding Kmer Bias (77 of 110)
#
# Adding Kmer Bias (78 of 110)
#
# Adding Kmer Bias (79 of 110)
#
# Adding Kmer Bias (80 of 110)
#
# Adding Kmer Bias (81 of 110)
#
# Adding Kmer Bias (82 of 110)
#
# Adding Kmer Bias (83 of 110)
#
# Adding Kmer Bias (84 of 110)
#
# Adding Kmer Bias (85 of 110)
#
# Adding Kmer Bias (86 of 110)
#
# Adding Kmer Bias (87 of 110)
#
# Adding Kmer Bias (88 of 110)
#
# Adding Kmer Bias (89 of 110)
#
# Adding Kmer Bias (90 of 110)
#
# Adding Kmer Bias (91 of 110)
#
# Adding Kmer Bias (92 of 110)
#
# Adding Kmer Bias (93 of 110)
#
# Adding Kmer Bias (94 of 110)
#
# Adding Kmer Bias (95 of 110)
#
# Adding Kmer Bias (96 of 110)
#
# Adding Kmer Bias (97 of 110)
#
# Adding Kmer Bias (98 of 110)
#
# Adding Kmer Bias (99 of 110)
#
# Adding Kmer Bias (100 of 110)
#
# Adding Kmer Bias (101 of 110)
#
# Adding Kmer Bias (102 of 110)
#
# Adding Kmer Bias (103 of 110)
#
# Adding Kmer Bias (104 of 110)
#
# Adding Kmer Bias (105 of 110)
#
# Adding Kmer Bias (106 of 110)
#
# Adding Kmer Bias (107 of 110)
#
# Adding Kmer Bias (108 of 110)
#
# Adding Kmer Bias (109 of 110)
#
# Adding Kmer Bias (110 of 110)
#
# 2024-09-09 21:49:05 : Finished Creation of Coverage Files!, 37.269 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addGroupCoverages-3aed7a5eaac303-Date-2024-09-09_Time-21-11-48.log

# %%
pathToMacs2 <- '/home/cruiz2/miniconda3/envs/python2/bin/macs2'

# %%
dmg_atlas <- addReproduciblePeakSet(
    ArchRProj = dmg_atlas, 
    groupBy = "MP", 
    pathToMacs2 = pathToMacs2,
    force=TRUE
)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addReproduciblePeakSet-3aed7a69029433-Date-2024-09-09_Time-21-49-05.log
# If there is an issue, please report to github with logFile!
#
# Calling Peaks with Macs2
#
# 2024-09-09 21:49:06 : Peak Calling Parameters!, 0.004 mins elapsed.
#                                   Group nCells nCellsUsed nReplicates nMin nMax
# C1_RGLike                     C1_RGLike   8967       2076           5  193  500
# C2_TriIPCLike             C2_TriIPCLike   1988       1176           5   50  500
# C3_IPCLike                   C3_IPCLike   3887       1888           5  297  500
# C4_OPCLike                   C4_OPCLike  18892       2500           5  500  500
# C5_COPLike                   C5_COPLike   6074        835           3  138  500
# C6_ACLike                     C6_ACLike   6957       2463           5  463  500
# C7_CiliaLike               C7_CiliaLike   1927        748           4   66  500
# C8_TDLike                     C8_TDLike  28077       2413           5  413  500
# C9_GWLike                     C9_GWLike   3947       1454           5  121  500
# C10_GBLike                   C10_GBLike   3205       1910           5  180  500
# C11_Oligodendrocyte C11_Oligodendrocyte  15321       2500           5  500  500
# C12_OPC                         C12_OPC   2548        742           5   41  500
# C13_Astrocyte             C13_Astrocyte   2894       1680           5  235  500
# C14_Neuron                   C14_Neuron   2632       1259           5   93  500
# C15_MonoNeutrophil   C15_MonoNeutrophil   2785       1658           5   99  500
# C16_C1Q                         C16_C1Q   4252       2159           5  294  500
# C17_LipidLaden           C17_LipidLaden   1611       1180           5   69  500
# C18_Scavenger             C18_Scavenger   3346       1665           5  213  500
# C19_IL1B                       C19_IL1B   1073        975           5   80  420
# C20_Homeostatic         C20_Homeostatic   1139        914           5   62  500
# C21_Lymphoid               C21_Lymphoid    856        655           5   79  169
# C22_Endothelial         C22_Endothelial    684        684           4   49  294
# C23_Mural                     C23_Mural    898        898           4  144  283
#                     maxPeaks
# C1_RGLike             150000
# C2_TriIPCLike         150000
# C3_IPCLike            150000
# C4_OPCLike            150000
# C5_COPLike            150000
# C6_ACLike             150000
# C7_CiliaLike          150000
# C8_TDLike             150000
# C9_GWLike             150000
# C10_GBLike            150000
# C11_Oligodendrocyte   150000
# C12_OPC               150000
# C13_Astrocyte         150000
# C14_Neuron            150000
# C15_MonoNeutrophil    150000
# C16_C1Q               150000
# C17_LipidLaden        150000
# C18_Scavenger         150000
# C19_IL1B              150000
# C20_Homeostatic       150000
# C21_Lymphoid          150000
# C22_Endothelial       150000
# C23_Mural             150000
# 2024-09-09 21:49:06 : Batching Peak Calls!, 0.004 mins elapsed.
#
# 2024-09-09 21:49:06 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# 2024-09-09 21:52:15 : Identifying Reproducible Peaks!, 3.167 mins elapsed.
#
# 2024-09-09 21:52:46 : Creating Union Peak Set!, 3.676 mins elapsed.
#
# Converged after 13 iterations!
#
# Plotting Ggplot!
#
# 2024-09-09 21:53:09 : Finished Creating Union Peak Set (558767)!, 4.066 mins elapsed.

# %%
dmg_atlas <- addPeakMatrix(dmg_atlas, force=TRUE)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addPeakMatrix-3aed7a7a57ba4e-Date-2024-09-09_Time-21-53-09.log
# If there is an issue, please report to github with logFile!
#
# 2024-09-09 21:53:09 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# Overriding previous entry for ReadsInPeaks
#
# Overriding previous entry for FRIP
#
# ArchR logging successful to : ArchRLogs/ArchR-addPeakMatrix-3aed7a7a57ba4e-Date-2024-09-09_Time-21-53-09.log

# %% [markdown]
# ### Subsetting malignant cells

# %%
sc <- import("scanpy")
adata <- sc$read_h5ad("../mosaic_integration_scglue/dmg_atac_emb_malignant_full_PEAKS.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 84494 × 378298
#     obs: 'total', 'duplicate', 'chimeric', 'unmapped', 'lowmapq', 'mitochondrial', 'nonprimary', 'passed_filters', 'is__cell_barcode', 'excluded_reason', 'TSS_fragments', 'DNase_sensitive_region_fragments', 'enhancer_region_fragments', 'promoter_region_fragments', 'on_target_fragments', 'blacklist_region_fragments', 'peak_region_fragments', 'peak_region_cutsites', 'nCount_ATAC', 'nFeature_ATAC', 'SampleID', 'nucleosome_signal', 'nucleosome_percentile', 'TSS.enrichment', 'TSS.percentile', 'pct_reads_in_peaks', 'blacklist_ratio', 'high.tss', 'nucleosome_group', 'scDblFinder.score', 'scDblFinder.class', 'amulet_pvalue', 'amulet_qvalue', 'scDblFinder.p', 'dbl_combined_score', 'ID', 'Study', 'Institute', 'Preservation_method', 'Diagnosis', 'Tumor_type', 'Tumor_subtype', 'Location', 'Source', 'Clinical_status', 'Isolation_method', 'Sc_platform_RNA', 'Sc_platform_ATAC', 'Sc_multiome', 'Raw_data_available', 'Counts', 'Genome_version', 'Paired_sample', 'Multisector', 'Gender', 'Age_years', 'Dexamethasone_prior_surgery', 'Survival', 'Survival_months', 'Mitosis', 'Ki67', 'Methylation_array', 'H3F3A', 'H3C3', 'HIST1H3B', 'HIST2H3C', 'TP53', 'EGFR', 'PDGFRA', 'SUFU', 'NF1', 'pTERT', 'PIK3CA', 'PIK3R1', 'ATRX', 'PTEN', 'ASXL1', 'BCOR', 'BCORL1', 'SMC1A', 'WT1', 'PPM1D', 'ACVR1', 'TSHR', 'BRAF', 'GNAQ', 'LMNA', 'KIT', 'ARID1A', 'KRAS', 'Other', 'predicted.id.filtered', 'Batch_for_correction', 'cell_id', 'modality', 'domain', 'gex_barcode', 'atac_barcode', 'is_cell', 'gex_raw_reads', 'gex_mapped_reads', 'gex_conf_intergenic_reads', 'gex_conf_exonic_reads', 'gex_conf_intronic_reads', 'gex_conf_exonic_unique_reads', 'gex_conf_exonic_antisense_reads', 'gex_conf_exonic_dup_reads', 'gex_exonic_umis', 'gex_conf_intronic_unique_reads', 'gex_conf_intronic_antisense_reads', 'gex_conf_intronic_dup_reads', 'gex_intronic_umis', 'gex_conf_txomic_unique_reads', 'gex_umis_count', 'gex_genes_count', 'atac_raw_reads', 'atac_unmapped_reads', 'atac_lowmapq', 'atac_dup_reads', 'atac_chimeric_reads', 'atac_mitochondrial_reads', 'atac_TSS_fragments', 'atac_peak_region_fragments', 'atac_peak_region_cutsites', 'batch', 'n_counts', 'leiden_1', 'leiden_1_3', 'leiden_1_5', 'leiden_1_8', 'leiden_2', 'leiden_2_3', 'leiden_2_5', 'leiden_2_8', 'leiden_3', 'louvain_1', 'louvain_1_3', 'louvain_1_5', 'louvain_1_8', 'louvain_2', 'louvain_2_3', 'louvain_2_5', 'louvain_2_8', 'louvain_3', 'iCNV', 'MP'
#     var: 'count-0', 'percentile-0', 'count-1', 'percentile-1', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'chrom', 'chromStart', 'chromEnd'
#     uns: 'Batch_for_correction_colors', 'MP_colors', 'Study_colors', 'cell_id_colors', 'domain_colors', 'hvg', 'leiden_1_3_colors', 'log1p', 'modality_colors', 'neighbors', 'umap'
#     obsm: 'X_glue', 'X_lsi', 'X_umap'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
# Access the cellnames
cell_names <- adata$obs_names$to_list()

# Define the pattern and replacement
pattern <- "(.*)_(.*)$"
replacement <- "\\1#\\2"

# Apply the pattern and replacement using sub
cell_names <- sub(pattern, replacement, cell_names)
head(cell_names)
tail(cell_names)
# Out:
# [1] "atac_T19-91014#AAACGAAAGACCCTAT-1" "atac_T19-91014#AAACGAAAGTGTAATG-1"
# [3] "atac_T19-91014#AAACGAACAAATGCTC-1" "atac_T19-91014#AAACGAACACGCCGAT-1"
# [5] "atac_T19-91014#AAACGAAGTACGGAGT-1" "atac_T19-91014#AAACGAAGTATCCCTC-1"
# [1] "multiome_P-6774_S-10146#TTTGTGGCATTATGAC-1"
# [2] "multiome_P-6774_S-10146#TTTGTGTTCCTAGTAA-1"
# [3] "multiome_P-6774_S-10146#TTTGTTGGTAGGATTT-1"
# [4] "multiome_P-6774_S-10146#TTTGTTGGTTGGATAT-1"
# [5] "multiome_P-6774_S-10146#TTTGTTGGTTGTAACG-1"
# [6] "multiome_P-6774_S-10146#TTTGTTGGTTTATCGC-1"

# %%
idx <- BiocGenerics::which(dmg_atlas$cellNames %in% cell_names)
head(idx)
length(idx)
# Out:
# [1] 1 2 3 4 5 6
# [1] 83921

# %%
cellsAtlas <- dmg_atlas$cellNames[idx]
head(cellsAtlas)
# Out:
# [1] "atac_MUV1#CCCTAACCATGGAGGT-1" "atac_MUV1#GGGTCTGTCGGAGTTT-1"
# [3] "atac_MUV1#GTGTCCTGTGAGTCGA-1" "atac_MUV1#AGCTGATCATGTATCG-1"
# [5] "atac_MUV1#GTGTCAAGTATCGCGC-1" "atac_MUV1#CAAAGCTCAGCGTGAA-1"

# %%
length(cellsAtlas)
# Out:
# [1] 83921

# %%
# to avoid any errors (Error in .Call2("map_positions", run_lens, pos, method, PACKAGE = "S4Vectors"): subscript contains NAs)
# the exact name of cells must be inside the archr object
# addditonal cell names will lead to the error above 
# also see https://github.com/GreenleafLab/ArchR/issues/212

malignant <- subsetArchRProject(
  ArchRProj = dmg_atlas,
  cells = cellsAtlas,
  outputDirectory = "ArchR_malignant_FINAL",
  dropCells = TRUE,
  logFile = NULL,
  force = FALSE
)
# Out:
# Dropping ImputeWeights Since You Are Subsetting Cells! ImputeWeights is a cell-x-cell Matrix!
#
# Copying ArchRProject to new outputDirectory : /gpfs/work2/0/einf2548/cruiz/dmg/notebooks/scATAC/archr/ArchR_malignant_FINAL
#
# Copying Arrow Files...
#
# Getting ImputeWeights
#
# No imputeWeights found, returning NULL
#
# Copying Other Files...
#
# Copying Other Files (1 of 9): Annotations
#
# Copying Other Files (2 of 9): Background-Peaks.rds
#
# Copying Other Files (3 of 9): Embeddings
#
# Copying Other Files (4 of 9): GroupCoverages
#
# Copying Other Files (5 of 9): IterativeLSI
#
# Copying Other Files (6 of 9): Peak2GeneLinks
#
# Copying Other Files (7 of 9): PeakCalls
#
# Copying Other Files (8 of 9): Plots
#
# Copying Other Files (9 of 9): RNAIntegration
#
# Saving ArchRProject...
#
# Loading ArchRProject...
#
# Successfully loaded ArchRProject!
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|

# %%
meta <- adata$obs

# Access the cellnames
cell_names <- rownames(meta)

# Define the pattern and replacement
pattern <- "(.*)_(.*)$"
replacement <- "\\1#\\2"

# Apply the pattern and replacement using sub
rownames(meta) <- sub(pattern, replacement, cell_names)

umap <- as.data.frame(adata$obsm['X_umap'])
rownames(umap) <- rownames(meta)
umap
# Out:
#                                            V1          V2
# atac_T19-91014#AAACGAAAGACCCTAT-1           0.93885583  9.48983574
# atac_T19-91014#AAACGAAAGTGTAATG-1          -0.39190325  8.68987465
# atac_T19-91014#AAACGAACAAATGCTC-1          11.50920200 -0.73884124
# atac_T19-91014#AAACGAACACGCCGAT-1           0.09302062  8.87163258
# atac_T19-91014#AAACGAAGTACGGAGT-1          -0.65333027  6.87637520
# atac_T19-91014#AAACGAAGTATCCCTC-1          11.56124592  0.48556212
# atac_T19-91014#AAACGAAGTATCTCAG-1           6.63970757  9.99974823
# atac_T19-91014#AAACGAAGTCAGACGA-1           2.37885690 10.27817726
# atac_T19-91014#AAACGAAGTGAAACAT-1           0.13185956  8.55276203
# multiome_P-6774_S-10146#TTTGTGAAGTTAGCTA-1  0.87867433 -1.94479549
# multiome_P-6774_S-10146#TTTGTGGCAAGGAATC-1  4.27788162  1.18950987
# multiome_P-6774_S-10146#TTTGTGGCAAGGTACG-1  7.81696081  3.02147031
# multiome_P-6774_S-10146#TTTGTGGCACCTCGCT-1  2.35289598  0.03686435
# multiome_P-6774_S-10146#TTTGTGGCACGTAATT-1  1.23917997 -1.23317134
# multiome_P-6774_S-10146#TTTGTGGCACTTGTTC-1  7.26561975  4.02905273
# multiome_P-6774_S-10146#TTTGTGGCAGCAAATA-1  0.44558963 -2.62466288
# multiome_P-6774_S-10146#TTTGTGGCAGCAACAG-1  4.79523420  1.57179308
# multiome_P-6774_S-10146#TTTGTGGCATGCTATG-1 10.92336559  5.40270615
# multiome_P-6774_S-10146#TTTGTGGCATTATGAC-1  1.33749235  0.49774149
# multiome_P-6774_S-10146#TTTGTGTTCCTAGTAA-1  1.53514683 -1.66423488
# multiome_P-6774_S-10146#TTTGTTGGTAGGATTT-1 -0.04654404 -2.13198853
# multiome_P-6774_S-10146#TTTGTTGGTTGGATAT-1  2.20434856 -0.10689471
# multiome_P-6774_S-10146#TTTGTTGGTTGTAACG-1  1.13399243  0.86559564
# multiome_P-6774_S-10146#TTTGTTGGTTTATCGC-1  3.32167339  1.91878927

# %%
saveArchRProject(ArchRProj = malignant, outputDirectory = "./ArchR_malignant_FINAL/")
# Out:
# Saving ArchRProject...
#
# Loading ArchRProject...
#
# Successfully loaded ArchRProject!
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
#
#
#
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
# class: ArchRProject
# outputDirectory: /gpfs/work2/0/einf2548/cruiz/dmg/notebooks/scATAC/archr/ArchR_malignant_FINAL
# samples(21): multiome_P-1709_S-1709 multiome_P-1701_S-1701 ...
#   atac_P-2687_S-2688 atac_P-6255_S-8500
# sampleColData names(1): ArrowFiles
# cellColData names(21): Sample TSSEnrichment ... FRIP MPv2
# numberOfCells(1): 83921
# medianTSS(1): 8.532
# medianFrags(1): 11219

# %% [markdown]
# ### Bulk ATAC comparison

# %%
malignant <- loadArchRProject('./ArchR_malignant_FINAL/')
malignant
# Out:
# Successfully loaded ArchRProject!
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
#
#
#
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
# class: ArchRProject
# outputDirectory: /gpfs/work2/0/einf2548/cruiz/dmg/notebooks/scATAC/archr/ArchR_malignant_FINAL
# samples(21): multiome_P-1709_S-1709 multiome_P-1701_S-1701 ...
#   atac_P-2687_S-2688 atac_P-6255_S-8500
# sampleColData names(1): ArrowFiles
# cellColData names(21): Sample TSSEnrichment ... FRIP MPv2
# numberOfCells(1): 83921
# medianTSS(1): 8.532
# medianFrags(1): 11219

# %%
malignant <- addMotifAnnotations(ArchRProj = malignant, motifSet = "cisbp", name = "Motif", force = TRUE)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addMotifAnnotations-a455f6dbd9e57-Date-2024-08-07_Time-16-10-19.log
# If there is an issue, please report to github with logFile!
#
# peakAnnotation name already exists! Overriding.
#
# 2024-08-07 16:10:19 : Gettting Motif Set, Species : Homo sapiens, 0.001 mins elapsed.
#
# Using version 2 motifs!
#
# 2024-08-07 16:10:21 : Finding Motif Positions with motifmatchr!, 0.02 mins elapsed.
#
# 2024-08-07 16:22:32 : Filtering Motif Annotations with 0 overlaps :
#
#  ENSG00000250542_156
#
# , 12.203 mins elapsed.
#
# 2024-08-07 16:22:32 : Creating Motif Overlap Matrix, 12.207 mins elapsed.
#
# 2024-08-07 16:22:39 : Finished Getting Motif Info!, 12.33 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addMotifAnnotations-a455f6dbd9e57-Date-2024-08-07_Time-16-10-19.log

# %%
malignant <- addArchRAnnotations(ArchRProj = malignant, collection = "ATAC")
# Out:
# ArchR logging to : ArchRLogs/ArchR-addArchRAnnotations-a455f73945b7c-Date-2024-08-07_Time-16-29-33.log
# If there is an issue, please report to github with logFile!
#
# Annotating Chromosomes
#
# 2024-08-07 16:29:33 :
#
# 	Annotating Chr: chr1
#
# 2024-08-07 16:29:33 :
#
# 	Annotating Chr: chr2
#
# 2024-08-07 16:29:33 :
#
# 	Annotating Chr: chr3
#
# 2024-08-07 16:29:33 :
#
# 	Annotating Chr: chr4
#
# 2024-08-07 16:29:34 :
#
# 	Annotating Chr: chr5
#
# 2024-08-07 16:29:34 :
#
# 	Annotating Chr: chr6
#
# 2024-08-07 16:29:34 :
#
# 	Annotating Chr: chr7
#
# 2024-08-07 16:29:34 :
#
# 	Annotating Chr: chr8
#
# 2024-08-07 16:29:34 :
#
# 	Annotating Chr: chr9
#
# 2024-08-07 16:29:34 :
#
# 	Annotating Chr: chr10
#
# 2024-08-07 16:29:35 :
#
# 	Annotating Chr: chr11
#
# 2024-08-07 16:29:35 :
#
# 	Annotating Chr: chr12
#
# 2024-08-07 16:29:35 :
#
# 	Annotating Chr: chr13
#
# 2024-08-07 16:29:35 :
#
# 	Annotating Chr: chr14
#
# 2024-08-07 16:29:35 :
#
# 	Annotating Chr: chr15
#
# 2024-08-07 16:29:35 :
#
# 	Annotating Chr: chr16
#
# 2024-08-07 16:29:36 :
#
# 	Annotating Chr: chr17
#
# 2024-08-07 16:29:36 :
#
# 	Annotating Chr: chr18
#
# 2024-08-07 16:29:36 :
#
# 	Annotating Chr: chr19
#
# 2024-08-07 16:29:36 :
#
# 	Annotating Chr: chr20
#
# 2024-08-07 16:29:36 :
#
# 	Annotating Chr: chr21
#
# 2024-08-07 16:29:37 :
#
# 	Annotating Chr: chr22
#
# 2024-08-07 16:29:37 :
#
# 	Annotating Chr: chrX
#
# 2024-08-07 16:29:37 :
#
# 2024-08-07 16:29:38 : All Regions Overlap at least 1 peak!, 0.083 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addArchRAnnotations-a455f73945b7c-Date-2024-08-07_Time-16-29-33.log

# %%
markersPeaks <- getMarkerFeatures(
    ArchRProj = malignant, 
    useMatrix = "PeakMatrix", 
    groupBy = "MP",
  bias = c("TSSEnrichment", "log10(nFrags)"),
  testMethod = "wilcoxon"
)
# Out:
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-2f1e1666595d63-Date-2024-09-10_Time-10-33-07.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2024-09-10 10:33:10 : Matching Known Biases, 0.043 mins elapsed.
#
# ###########
# 2024-09-10 10:35:57 : Completed Pairwise Tests, 2.841 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-2f1e1666595d63-Date-2024-09-10_Time-10-33-07.log

# %%
enrichATAC <- peakAnnoEnrichment(
    seMarker = markersPeaks,
    ArchRProj = malignant,
    peakAnnotation = "ATAC",
    cutOff = "FDR <= 0.1 & Log2FC >= 0.5"
  )
# Out:
# ArchR logging to : ArchRLogs/ArchR-peakAnnoEnrichment-2f1e163fe6ea91-Date-2024-09-10_Time-10-36-44.log
# If there is an issue, please report to github with logFile!
#
# 2024-09-10 10:37:04 : Computing Enrichments 1 of 10, 0.331 mins elapsed.
#
# 2024-09-10 10:37:04 : Computing Enrichments 2 of 10, 0.337 mins elapsed.
#
# 2024-09-10 10:37:04 : Computing Enrichments 3 of 10, 0.342 mins elapsed.
#
# 2024-09-10 10:37:06 : Computing Enrichments 4 of 10, 0.364 mins elapsed.
#
# 2024-09-10 10:37:06 : Computing Enrichments 5 of 10, 0.367 mins elapsed.
#
# 2024-09-10 10:37:06 : Computing Enrichments 6 of 10, 0.371 mins elapsed.
#
# 2024-09-10 10:37:06 : Computing Enrichments 7 of 10, 0.374 mins elapsed.
#
# 2024-09-10 10:37:07 : Computing Enrichments 8 of 10, 0.379 mins elapsed.
#
# 2024-09-10 10:37:07 : Computing Enrichments 9 of 10, 0.382 mins elapsed.
#
# 2024-09-10 10:37:07 : Computing Enrichments 10 of 10, 0.387 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-peakAnnoEnrichment-2f1e163fe6ea91-Date-2024-09-10_Time-10-36-44.log

# %%
heatmapATAC <- plotEnrichHeatmap(enrichATAC, n = 7, transpose = TRUE)
# Out:
# ArchR logging to : ArchRLogs/ArchR-plotEnrichHeatmap-2f1e1631658db3-Date-2024-09-10_Time-10-37-08.log
# If there is an issue, please report to github with logFile!
#
# Adding Annotations..
#
# Preparing Main Heatmap..

# %%
ComplexHeatmap::draw(heatmapATAC, heatmap_legend_side = "bot", annotation_legend_side = "bot")
# Out:
# plot without title

# %%
heatmapATAC <- plotEnrichHeatmap(enrichATAC, n = 7, transpose = TRUE, 
                                clusterCols = FALSE,
                                 binaryClusterRows = TRUE)
# Out:
# ArchR logging to : ArchRLogs/ArchR-plotEnrichHeatmap-2f1e1659902b71-Date-2024-09-10_Time-10-38-56.log
# If there is an issue, please report to github with logFile!
#
# Adding Annotations..
#
# Preparing Main Heatmap..

# %%
ComplexHeatmap::draw(heatmapATAC, heatmap_legend_side = "bot", annotation_legend_side = "bot")
# Out:
# plot without title

# %%
plotPDF(heatmapATAC, name = "ATAC-Enriched-Marker-Heatmap", width = 8, height = 6, 
        ArchRProj = malignant, addDOC = FALSE)
# Out:
# Plotting ComplexHeatmap!

# %% [markdown]
# ### Mannens et al. comparison

# %%
library(data.table)
library(GenomicRanges)
library(future)
library(future.apply)

# Define the directory containing your .tsv.gz files
tsv_dir <- "/projects/0/einf2548/cruiz/dmg/notebooks/scATAC/pycistopic_fetal/pseudobulk_bed_files/glial"

# List your .tsv.gz files
tsv_files <- list.files(tsv_dir, pattern = "*.tsv.gz", full.names = TRUE)

# Create a named list, removing the directory and extension
CustomPeaks <- setNames(tsv_files, sub(".*/(.*).fragments.tsv.gz$", "\\1", tsv_files))

# Plan to use multiple cores
plan(multisession, workers = 48)

# Parallel file processing
CustomPeaksGR <- future_lapply(CustomPeaks, function(tsv_file) {
  df <- fread(cmd = paste("zcat", tsv_file), col.names = c("chr", "start", "end", "barcode", "score"), nThread = 48)
  df[, name := paste0(chr, ":", start, "-", end)]
  df[, strand := "+"]
  df[, barcode := NULL]
  gr <- makeGRangesFromDataFrame(df, keep.extra.columns = TRUE)
  return(gr)
})

# %%
malignant <- addPeakAnnotations(ArchRProj = malignant, regions = CustomPeaksGR, name = "fetal")
# Out:
# ArchR logging to : ArchRLogs/ArchR-addPeakAnnotations-19b4be7e8f269c-Date-2024-09-11_Time-16-45-37.log
# If there is an issue, please report to github with logFile!
#
# 2024-09-11 16:48:54 : Creating Peak Overlap Matrix, 3.288 mins elapsed.
#
# 2024-09-11 16:50:33 : All Regions Overlap at least 1 peak!, 4.933 mins elapsed.

# %%
enrichRegions <- peakAnnoEnrichment(
    seMarker = markersPeaks,
    ArchRProj = malignant,
    peakAnnotation = "fetal",
    cutOff = "FDR <= 0.2 & Log2FC >= 0.25"
  )
# Out:
# ArchR logging to : ArchRLogs/ArchR-peakAnnoEnrichment-19b4be2e740fb4-Date-2024-09-11_Time-16-51-45.log
# If there is an issue, please report to github with logFile!
#
# 2024-09-11 16:52:06 : Computing Enrichments 1 of 10, 0.356 mins elapsed.
#
# 2024-09-11 16:52:07 : Computing Enrichments 2 of 10, 0.361 mins elapsed.
#
# 2024-09-11 16:52:07 : Computing Enrichments 3 of 10, 0.365 mins elapsed.
#
# 2024-09-11 16:52:07 : Computing Enrichments 4 of 10, 0.369 mins elapsed.
#
# 2024-09-11 16:52:07 : Computing Enrichments 5 of 10, 0.373 mins elapsed.
#
# 2024-09-11 16:52:08 : Computing Enrichments 6 of 10, 0.378 mins elapsed.
#
# 2024-09-11 16:52:08 : Computing Enrichments 7 of 10, 0.382 mins elapsed.
#
# 2024-09-11 16:52:08 : Computing Enrichments 8 of 10, 0.386 mins elapsed.
#
# 2024-09-11 16:52:08 : Computing Enrichments 9 of 10, 0.391 mins elapsed.
#
# 2024-09-11 16:52:09 : Computing Enrichments 10 of 10, 0.395 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-peakAnnoEnrichment-19b4be2e740fb4-Date-2024-09-11_Time-16-51-45.log

# %%
heatmapRegions <- plotEnrichHeatmap(enrichRegions, n = 135, transpose = TRUE)
# Out:
# ArchR logging to : ArchRLogs/ArchR-plotEnrichHeatmap-19b4be2d055c2-Date-2024-09-11_Time-16-52-09.log
# If there is an issue, please report to github with logFile!
#
# Adding Annotations..
#
# Preparing Main Heatmap..

# %%
ComplexHeatmap::draw(heatmapRegions, heatmap_legend_side = "bot", annotation_legend_side = "bot")
# Out:
# plot without title

# %%
heatmapRegions <- plotEnrichHeatmap(enrichRegions, n = 135, transpose = TRUE,
                                   clusterCols = FALSE,
                                 binaryClusterRows = TRUE,
                                   rastr = FALSE)
# Out:
# ArchR logging to : ArchRLogs/ArchR-plotEnrichHeatmap-19b4be5452b796-Date-2024-09-11_Time-16-54-26.log
# If there is an issue, please report to github with logFile!
#
# Adding Annotations..
#
# Preparing Main Heatmap..

# %%
ComplexHeatmap::draw(heatmapRegions, heatmap_legend_side = "bot", annotation_legend_side = "bot")
# Out:
# plot without title

# %%
plotPDF(heatmapRegions, name = "Mannens-Enriched-Marker-Heatmap", width = 5, height = 6, 
        ArchRProj = malignant, addDOC = FALSE)
# Out:
# Plotting ComplexHeatmap!
