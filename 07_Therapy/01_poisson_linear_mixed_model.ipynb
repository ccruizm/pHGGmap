# %% [markdown]
# `conda activate r_env_standr`

# %% [markdown]
# Taken from https://doi.org/10.1038/s43587-024-00613-3

# %%
suppressPackageStartupMessages({
    library(reticulate)
    library(ggplot2)
    library(Seurat)
    library(dplyr)
    library(tidyr)
    library(tibble)
    library(stringr)
    library(lme4)
    library(numDeriv)
    library(dittoSeq)
    library(future)
    library(data.table)
    library(scales)
    plan("multicore", workers = 12)
    options(future.globals.maxSize = 1000 * 1024^5)
    options(stringsAsFactors = FALSE)
    set.seed(123)
})
# Out:
# Warning message:
# “package ‘ggplot2’ was built under R version 4.3.3”

# %%
path_ref <- '/projects/0/einf2548/cruiz/dmg/data/rna_dmg_atlas_scglue_embbeding.rds'
dmg <- readRDS(path_ref)
dmg
# Out:
# An object of class Seurat
# 19248 features across 397794 samples within 1 assay
# Active assay: RNA (19248 features, 2000 variable features)
#  3 layers present: counts, data, scale.data
#  2 dimensional reductions calculated: pca, umap

# %%
meta <- dmg@meta.data %>% filter(lvl_2 %in% c('Stem_like', 'Differentiated_like', 'Myeloid'))
meta
# Out:
#                                            nCount_RNA nFeature_RNA nCount_RAW
# BT042_PD_CCGTTCATCTATGTGG-1                10775      3338         10838
# BT042_PD_CTACCTGGTATGAAAC-1                 9031      3613          9139
# BT042_PD_TTGCATTTCCTGTAGA-1                 7641      2960          7697
# BT042_PD_GTGCTGGGTAACGCGA-1                 7135      3151          7290
# BT042_PD_CTTCTAAAGACGCATG-1                 5720      2362          5834
# BT042_PD_CCTCACACAAAGCTAA-1                 5471      1911          5554
# BT042_PD_TGCGATAAGCCATCCG-1                 4960      2065          4994
# BT042_PD_GAATAGAGTTTATGCG-1                 4726      2219          4867
# BT042_PD_CCTGCATAGGTCACAG-1                 4652      1813          4668
# BT042_PD_CGGAGAACAACTGCTA-1                 4820      2178          4903
# BT042_PD_ACAAGCTGTGGCTAGA-1                 4619      1845          4691
# BT042_PD_AGGGCTCCAACTCGTA-1                 4537      1881          4567
# BT042_PD_TTCCGGTAGGGAGTTC-1                 4439      2218          4480
# BT042_PD_GAGGCCTCACAGACGA-1                 4003      1859          4017
# BT042_PD_ACACTGACATAATCCG-1                 3750      1920          3805
# BT042_PD_TTCACGCTCGAGTGAG-1                 3620      1835          3644
# BT042_PD_ATGAGTCCAATCGCAT-1                 3547      1914          3607
# BT042_PD_GGATGTTGTAGAGCTG-1                 3566      2060          3644
# BT042_PD_TGTGGCGTCTATACTC-1                 3354      1510          3384
# BT042_PD_AGCGCTGCATTGCAAC-1                 3371      1815          3434
# BT042_PD_TGACGCGCAAAGGGCT-1                 3090      1720          3107
# BT042_PD_AAGTCGTTCAATCGGT-1                 3211      1772          3294
# BT042_PD_CGGGTCACACGTGAGA-1                 3143      1768          3280
# BT042_PD_GTGTTCCTCATTGTTC-1                 3068      1788          3172
# BT042_PD_GCGATCGAGGTATAGT-1                 3042      1513          3072
# BT042_PD_CCTGTTGAGTGTTCAC-1                 2906      1549          2982
# BT042_PD_TACTTACCAAGTACCT-1                 2848      1260          2858
# BT042_PD_TTCAGGAGTAGTGTGG-1                 2931      1594          2977
# BT042_PD_AGGTGTTGTCGTCGGT-1                 2877      1467          2904
# BT042_PD_ACCTGTCGTCTGTGAT-1                 2751      1678          2796
# ⋮                                          ⋮          ⋮            ⋮
# multiome_P-6774_S-10146_TGCAAGCGTTAAGTGT-1 249        214          652
# multiome_P-6774_S-10146_GGAGCGATCATAGCCG-1 307        246          661
# multiome_P-6774_S-10146_TTGTCCATCCTTAGTT-1 296        245          636
# multiome_P-6774_S-10146_TAGGAACCAAGGACCA-1 300        233          657
# multiome_P-6774_S-10146_TCGGTTCTCTAAGTGC-1 270        205          635
# multiome_P-6774_S-10146_CCGCTTAGTTAACACG-1 435        350          651
# multiome_P-6774_S-10146_GAGTGTTTCTAGCGTG-1 439        362          649
# multiome_P-6774_S-10146_GACTAATGTGTTGCTT-1 262        221          630
# multiome_P-6774_S-10146_GGAGTGAGTAAACAAG-1 279        231          620
# multiome_P-6774_S-10146_GTACTGGTCCGTGACA-1 267        209          610
# multiome_P-6774_S-10146_CGAATCTAGTTTAACG-1 304        263          609
# multiome_P-6774_S-10146_TTAGACTCATCATGTG-1 283        236          617
# multiome_P-6774_S-10146_GCGGTTGGTGGATTAT-1 403        289          631
# multiome_P-6774_S-10146_TTGGATTCACGTAAGG-1 403        271          600
# multiome_P-6774_S-10146_TGAGGGCCAGGCATGA-1 274        225          599
# multiome_P-6774_S-10146_GTGCGCAGTAAACAAG-1 410        282          621
# multiome_P-6774_S-10146_GCCTCAAAGGATTGCT-1 260        204          609
# multiome_P-6774_S-10146_ACTTAGTCACTAGGTC-1 285        259          601
# multiome_P-6774_S-10146_TCAAGGAAGCGGATTT-1 306        222          583
# multiome_P-6774_S-10146_TCAGCGATCCGTGACA-1 275        202          604
# multiome_P-6774_S-10146_CGCTTACTCCGTTAAA-1 272        216          542
# multiome_P-6774_S-10146_CTTTATCAGGAAGCTA-1 254        208          558
# multiome_P-6774_S-10146_GGCTTCAAGTTATGGC-1 339        269          557
# multiome_P-6774_S-10146_CCTGTTGGTGACCTGG-1 237        209          543
# multiome_P-6774_S-10146_TACCGCAAGCGCCTTT-1 314        260          544
# multiome_P-6774_S-10146_GAGTGATCAAGTGTTT-1 302        242          525
# multiome_P-6774_S-10146_GGTCAGGAGTGCTGTG-1 342        251          506
# multiome_P-6774_S-10146_TGGATTCAGACAAGTG-1 302        226          461
# multiome_P-6774_S-10146_TCCAGGTCAATTGAAG-1 283        221          447
# multiome_P-6774_S-10146_CTAGTAATCTAAGTGC-1 238        207          408
#                                            nFeature_RAW DF.class DF.score
# BT042_PD_CCGTTCATCTATGTGG-1                3366         Singlet  0.10909091
# BT042_PD_CTACCTGGTATGAAAC-1                3644         Singlet  0.12727273
# BT042_PD_TTGCATTTCCTGTAGA-1                2987         Singlet  0.10909091
# BT042_PD_GTGCTGGGTAACGCGA-1                3183         Singlet  0.07272727
# BT042_PD_CTTCTAAAGACGCATG-1                2405         Singlet  0.09090909
# BT042_PD_CCTCACACAAAGCTAA-1                1948         Singlet  0.12727273
# BT042_PD_TGCGATAAGCCATCCG-1                2080         Singlet  0.10909091
# BT042_PD_GAATAGAGTTTATGCG-1                2231         Singlet  0.07272727
# BT042_PD_CCTGCATAGGTCACAG-1                1824         Singlet  0.12727273
# BT042_PD_CGGAGAACAACTGCTA-1                2192         Singlet  0.14545455
# BT042_PD_ACAAGCTGTGGCTAGA-1                1874         Singlet  0.10909091
# BT042_PD_AGGGCTCCAACTCGTA-1                1899         Singlet  0.09090909
# BT042_PD_TTCCGGTAGGGAGTTC-1                2242         Singlet  0.10909091
# BT042_PD_GAGGCCTCACAGACGA-1                1870         Singlet  0.10909091
# BT042_PD_ACACTGACATAATCCG-1                1938         Singlet  0.10909091
# BT042_PD_TTCACGCTCGAGTGAG-1                1849         Singlet  0.12727273
# BT042_PD_ATGAGTCCAATCGCAT-1                1928         Singlet  0.10909091
# BT042_PD_GGATGTTGTAGAGCTG-1                2076         Singlet  0.10909091
# BT042_PD_TGTGGCGTCTATACTC-1                1525         Singlet  0.10909091
# BT042_PD_AGCGCTGCATTGCAAC-1                1831         Singlet  0.10909091
# BT042_PD_TGACGCGCAAAGGGCT-1                1726         Singlet  0.10909091
# BT042_PD_AAGTCGTTCAATCGGT-1                1792         Singlet  0.09090909
# BT042_PD_CGGGTCACACGTGAGA-1                1783         Singlet  0.12727273
# BT042_PD_GTGTTCCTCATTGTTC-1                1810         Singlet  0.12727273
# BT042_PD_GCGATCGAGGTATAGT-1                1524         Singlet  0.09090909
# BT042_PD_CCTGTTGAGTGTTCAC-1                1568         Singlet  0.09090909
# BT042_PD_TACTTACCAAGTACCT-1                1265         Singlet  0.09090909
# BT042_PD_TTCAGGAGTAGTGTGG-1                1610         Singlet  0.10909091
# BT042_PD_AGGTGTTGTCGTCGGT-1                1480         Singlet  0.09090909
# BT042_PD_ACCTGTCGTCTGTGAT-1                1695         Singlet  0.09090909
# ⋮                                          ⋮            ⋮        ⋮
# multiome_P-6774_S-10146_TGCAAGCGTTAAGTGT-1 557          Singlet  0.08415629
# multiome_P-6774_S-10146_GGAGCGATCATAGCCG-1 545          Singlet  0.03778446
# multiome_P-6774_S-10146_TTGTCCATCCTTAGTT-1 524          Singlet  0.12065264
# multiome_P-6774_S-10146_TAGGAACCAAGGACCA-1 536          Singlet  0.23958781
# multiome_P-6774_S-10146_TCGGTTCTCTAAGTGC-1 526          Singlet  0.22370116
# multiome_P-6774_S-10146_CCGCTTAGTTAACACG-1 532          Singlet  0.20781451
# multiome_P-6774_S-10146_GAGTGTTTCTAGCGTG-1 542          Singlet  0.19793903
# multiome_P-6774_S-10146_GACTAATGTGTTGCTT-1 536          Singlet  0.13310434
# multiome_P-6774_S-10146_GGAGTGAGTAAACAAG-1 527          Singlet  0.21940747
# multiome_P-6774_S-10146_GTACTGGTCCGTGACA-1 502          Singlet  0.21769000
# multiome_P-6774_S-10146_CGAATCTAGTTTAACG-1 525          Singlet  0.15242593
# multiome_P-6774_S-10146_TTAGACTCATCATGTG-1 515          Singlet  0.21854873
# multiome_P-6774_S-10146_GCGGTTGGTGGATTAT-1 492          Singlet  0.21382568
# multiome_P-6774_S-10146_TTGGATTCACGTAAGG-1 431          Singlet  0.19622155
# multiome_P-6774_S-10146_TGAGGGCCAGGCATGA-1 514          Singlet  0.20695578
# multiome_P-6774_S-10146_GTGCGCAGTAAACAAG-1 459          Singlet  0.18548733
# multiome_P-6774_S-10146_GCCTCAAAGGATTGCT-1 495          Singlet  0.24602834
# multiome_P-6774_S-10146_ACTTAGTCACTAGGTC-1 526          Singlet  0.10004294
# multiome_P-6774_S-10146_TCAAGGAAGCGGATTT-1 465          Singlet  0.16358952
# multiome_P-6774_S-10146_TCAGCGATCCGTGACA-1 481          Singlet  0.03864319
# multiome_P-6774_S-10146_CGCTTACTCCGTTAAA-1 454          Singlet  0.24130528
# multiome_P-6774_S-10146_CTTTATCAGGAAGCTA-1 477          Singlet  0.20609704
# multiome_P-6774_S-10146_GGCTTCAAGTTATGGC-1 460          Singlet  0.16831258
# multiome_P-6774_S-10146_CCTGTTGGTGACCTGG-1 489          Singlet  0.11807643
# multiome_P-6774_S-10146_TACCGCAAGCGCCTTT-1 461          Singlet  0.18205238
# multiome_P-6774_S-10146_GAGTGATCAAGTGTTT-1 441          Singlet  0.15242593
# multiome_P-6774_S-10146_GGTCAGGAGTGCTGTG-1 396          Singlet  0.18033491
# multiome_P-6774_S-10146_TGGATTCAGACAAGTG-1 366          Singlet  0.14297982
# multiome_P-6774_S-10146_TCCAGGTCAATTGAAG-1 362          Singlet  0.15586088
# multiome_P-6774_S-10146_CTAGTAATCTAAGTGC-1 355          Singlet  0.10433663
#                                            scDblFinder.class scDblFinder.score
# BT042_PD_CCGTTCATCTATGTGG-1                Singlet           0.66635233
# BT042_PD_CTACCTGGTATGAAAC-1                Singlet           0.66635233
# BT042_PD_TTGCATTTCCTGTAGA-1                Singlet           0.42149284
# BT042_PD_GTGCTGGGTAACGCGA-1                Doublet           0.98795068
# BT042_PD_CTTCTAAAGACGCATG-1                Singlet           0.33930978
# BT042_PD_CCTCACACAAAGCTAA-1                Singlet           0.31077635
# BT042_PD_TGCGATAAGCCATCCG-1                Singlet           0.76924258
# BT042_PD_GAATAGAGTTTATGCG-1                Singlet           0.24659014
# BT042_PD_CCTGCATAGGTCACAG-1                Singlet           0.08938396
# BT042_PD_CGGAGAACAACTGCTA-1                Doublet           0.99548411
# BT042_PD_ACAAGCTGTGGCTAGA-1                Singlet           0.39984679
# BT042_PD_AGGGCTCCAACTCGTA-1                Singlet           0.47738504
# BT042_PD_TTCCGGTAGGGAGTTC-1                Singlet           0.55307186
# BT042_PD_GAGGCCTCACAGACGA-1                Singlet           0.39733049
# BT042_PD_ACACTGACATAATCCG-1                Singlet           0.75327098
# BT042_PD_TTCACGCTCGAGTGAG-1                Singlet           0.26683545
# BT042_PD_ATGAGTCCAATCGCAT-1                Singlet           0.51619869
# BT042_PD_GGATGTTGTAGAGCTG-1                Singlet           0.47524789
# BT042_PD_TGTGGCGTCTATACTC-1                Singlet           0.26410073
# BT042_PD_AGCGCTGCATTGCAAC-1                Singlet           0.41683626
# BT042_PD_TGACGCGCAAAGGGCT-1                Singlet           0.44201136
# BT042_PD_AAGTCGTTCAATCGGT-1                Singlet           0.71990490
# BT042_PD_CGGGTCACACGTGAGA-1                Singlet           0.59689492
# BT042_PD_GTGTTCCTCATTGTTC-1                Singlet           0.46599516
# BT042_PD_GCGATCGAGGTATAGT-1                Singlet           0.59356058
# BT042_PD_CCTGTTGAGTGTTCAC-1                Singlet           0.53575867
# BT042_PD_TACTTACCAAGTACCT-1                Singlet           0.48334393
# BT042_PD_TTCAGGAGTAGTGTGG-1                Singlet           0.44463229
# BT042_PD_AGGTGTTGTCGTCGGT-1                Singlet           0.49025270
# BT042_PD_ACCTGTCGTCTGTGAT-1                Singlet           0.46512797
# ⋮                                          ⋮                 ⋮
# multiome_P-6774_S-10146_TGCAAGCGTTAAGTGT-1 Singlet           5.719457e-05
# multiome_P-6774_S-10146_GGAGCGATCATAGCCG-1 Singlet           3.297045e-04
# multiome_P-6774_S-10146_TTGTCCATCCTTAGTT-1 Singlet           8.444056e-05
# multiome_P-6774_S-10146_TAGGAACCAAGGACCA-1 Singlet           1.905597e-04
# multiome_P-6774_S-10146_TCGGTTCTCTAAGTGC-1 Singlet           1.410171e-04
# multiome_P-6774_S-10146_CCGCTTAGTTAACACG-1 Singlet           2.242342e-05
# multiome_P-6774_S-10146_GAGTGTTTCTAGCGTG-1 Singlet           6.478943e-05
# multiome_P-6774_S-10146_GACTAATGTGTTGCTT-1 Singlet           7.825657e-05
# multiome_P-6774_S-10146_GGAGTGAGTAAACAAG-1 Singlet           1.396935e-04
# multiome_P-6774_S-10146_GTACTGGTCCGTGACA-1 Singlet           7.295709e-05
# multiome_P-6774_S-10146_CGAATCTAGTTTAACG-1 Singlet           6.602362e-05
# multiome_P-6774_S-10146_TTAGACTCATCATGTG-1 Singlet           2.329112e-04
# multiome_P-6774_S-10146_GCGGTTGGTGGATTAT-1 Singlet           1.642857e-04
# multiome_P-6774_S-10146_TTGGATTCACGTAAGG-1 Singlet           3.489021e-05
# multiome_P-6774_S-10146_TGAGGGCCAGGCATGA-1 Singlet           1.680016e-04
# multiome_P-6774_S-10146_GTGCGCAGTAAACAAG-1 Singlet           5.685459e-05
# multiome_P-6774_S-10146_GCCTCAAAGGATTGCT-1 Singlet           7.201255e-05
# multiome_P-6774_S-10146_ACTTAGTCACTAGGTC-1 Singlet           2.502547e-05
# multiome_P-6774_S-10146_TCAAGGAAGCGGATTT-1 Singlet           1.870321e-04
# multiome_P-6774_S-10146_TCAGCGATCCGTGACA-1 Singlet           3.583328e-04
# multiome_P-6774_S-10146_CGCTTACTCCGTTAAA-1 Singlet           2.634595e-04
# multiome_P-6774_S-10146_CTTTATCAGGAAGCTA-1 Singlet           6.667899e-05
# multiome_P-6774_S-10146_GGCTTCAAGTTATGGC-1 Singlet           5.375483e-05
# multiome_P-6774_S-10146_CCTGTTGGTGACCTGG-1 Singlet           7.255303e-05
# multiome_P-6774_S-10146_TACCGCAAGCGCCTTT-1 Singlet           5.071286e-05
# multiome_P-6774_S-10146_GAGTGATCAAGTGTTT-1 Singlet           4.204729e-05
# multiome_P-6774_S-10146_GGTCAGGAGTGCTGTG-1 Singlet           4.284992e-05
# multiome_P-6774_S-10146_TGGATTCAGACAAGTG-1 Singlet           5.928063e-05
# multiome_P-6774_S-10146_TCCAGGTCAATTGAAG-1 Singlet           2.334795e-05
# multiome_P-6774_S-10146_CTAGTAATCTAAGTGC-1 Singlet           3.599050e-05
#                                            ID
# BT042_PD_CCGTTCATCTATGTGG-1                T18-90532
# BT042_PD_CTACCTGGTATGAAAC-1                T18-90532
# BT042_PD_TTGCATTTCCTGTAGA-1                T18-90532
# BT042_PD_GTGCTGGGTAACGCGA-1                T18-90532
# BT042_PD_CTTCTAAAGACGCATG-1                T18-90532
# BT042_PD_CCTCACACAAAGCTAA-1                T18-90532
# BT042_PD_TGCGATAAGCCATCCG-1                T18-90532
# BT042_PD_GAATAGAGTTTATGCG-1                T18-90532
# BT042_PD_CCTGCATAGGTCACAG-1                T18-90532
# BT042_PD_CGGAGAACAACTGCTA-1                T18-90532
# BT042_PD_ACAAGCTGTGGCTAGA-1                T18-90532
# BT042_PD_AGGGCTCCAACTCGTA-1                T18-90532
# BT042_PD_TTCCGGTAGGGAGTTC-1                T18-90532
# BT042_PD_GAGGCCTCACAGACGA-1                T18-90532
# BT042_PD_ACACTGACATAATCCG-1                T18-90532
# BT042_PD_TTCACGCTCGAGTGAG-1                T18-90532
# BT042_PD_ATGAGTCCAATCGCAT-1                T18-90532
# BT042_PD_GGATGTTGTAGAGCTG-1                T18-90532
# BT042_PD_TGTGGCGTCTATACTC-1                T18-90532
# BT042_PD_AGCGCTGCATTGCAAC-1                T18-90532
# BT042_PD_TGACGCGCAAAGGGCT-1                T18-90532
# BT042_PD_AAGTCGTTCAATCGGT-1                T18-90532
# BT042_PD_CGGGTCACACGTGAGA-1                T18-90532
# BT042_PD_GTGTTCCTCATTGTTC-1                T18-90532
# BT042_PD_GCGATCGAGGTATAGT-1                T18-90532
# BT042_PD_CCTGTTGAGTGTTCAC-1                T18-90532
# BT042_PD_TACTTACCAAGTACCT-1                T18-90532
# BT042_PD_TTCAGGAGTAGTGTGG-1                T18-90532
# BT042_PD_AGGTGTTGTCGTCGGT-1                T18-90532
# BT042_PD_ACCTGTCGTCTGTGAT-1                T18-90532
# ⋮                                          ⋮
# multiome_P-6774_S-10146_TGCAAGCGTTAAGTGT-1 P-6774_S-10146
# multiome_P-6774_S-10146_GGAGCGATCATAGCCG-1 P-6774_S-10146
# multiome_P-6774_S-10146_TTGTCCATCCTTAGTT-1 P-6774_S-10146
# multiome_P-6774_S-10146_TAGGAACCAAGGACCA-1 P-6774_S-10146
# multiome_P-6774_S-10146_TCGGTTCTCTAAGTGC-1 P-6774_S-10146
# multiome_P-6774_S-10146_CCGCTTAGTTAACACG-1 P-6774_S-10146
# multiome_P-6774_S-10146_GAGTGTTTCTAGCGTG-1 P-6774_S-10146
# multiome_P-6774_S-10146_GACTAATGTGTTGCTT-1 P-6774_S-10146
# multiome_P-6774_S-10146_GGAGTGAGTAAACAAG-1 P-6774_S-10146
# multiome_P-6774_S-10146_GTACTGGTCCGTGACA-1 P-6774_S-10146
# multiome_P-6774_S-10146_CGAATCTAGTTTAACG-1 P-6774_S-10146
# multiome_P-6774_S-10146_TTAGACTCATCATGTG-1 P-6774_S-10146
# multiome_P-6774_S-10146_GCGGTTGGTGGATTAT-1 P-6774_S-10146
# multiome_P-6774_S-10146_TTGGATTCACGTAAGG-1 P-6774_S-10146
# multiome_P-6774_S-10146_TGAGGGCCAGGCATGA-1 P-6774_S-10146
# multiome_P-6774_S-10146_GTGCGCAGTAAACAAG-1 P-6774_S-10146
# multiome_P-6774_S-10146_GCCTCAAAGGATTGCT-1 P-6774_S-10146
# multiome_P-6774_S-10146_ACTTAGTCACTAGGTC-1 P-6774_S-10146
# multiome_P-6774_S-10146_TCAAGGAAGCGGATTT-1 P-6774_S-10146
# multiome_P-6774_S-10146_TCAGCGATCCGTGACA-1 P-6774_S-10146
# multiome_P-6774_S-10146_CGCTTACTCCGTTAAA-1 P-6774_S-10146
# multiome_P-6774_S-10146_CTTTATCAGGAAGCTA-1 P-6774_S-10146
# multiome_P-6774_S-10146_GGCTTCAAGTTATGGC-1 P-6774_S-10146
# multiome_P-6774_S-10146_CCTGTTGGTGACCTGG-1 P-6774_S-10146
# multiome_P-6774_S-10146_TACCGCAAGCGCCTTT-1 P-6774_S-10146
# multiome_P-6774_S-10146_GAGTGATCAAGTGTTT-1 P-6774_S-10146
# multiome_P-6774_S-10146_GGTCAGGAGTGCTGTG-1 P-6774_S-10146
# multiome_P-6774_S-10146_TGGATTCAGACAAGTG-1 P-6774_S-10146
# multiome_P-6774_S-10146_TCCAGGTCAATTGAAG-1 P-6774_S-10146
# multiome_P-6774_S-10146_CTAGTAATCTAAGTGC-1 P-6774_S-10146
#                                            SampleID                ⋯
# BT042_PD_CCGTTCATCTATGTGG-1                BT042_PD                ⋯
# BT042_PD_CTACCTGGTATGAAAC-1                BT042_PD                ⋯
# BT042_PD_TTGCATTTCCTGTAGA-1                BT042_PD                ⋯
# BT042_PD_GTGCTGGGTAACGCGA-1                BT042_PD                ⋯
# BT042_PD_CTTCTAAAGACGCATG-1                BT042_PD                ⋯
# BT042_PD_CCTCACACAAAGCTAA-1                BT042_PD                ⋯
# BT042_PD_TGCGATAAGCCATCCG-1                BT042_PD                ⋯
# BT042_PD_GAATAGAGTTTATGCG-1                BT042_PD                ⋯
# BT042_PD_CCTGCATAGGTCACAG-1                BT042_PD                ⋯
# BT042_PD_CGGAGAACAACTGCTA-1                BT042_PD                ⋯
# BT042_PD_ACAAGCTGTGGCTAGA-1                BT042_PD                ⋯
# BT042_PD_AGGGCTCCAACTCGTA-1                BT042_PD                ⋯
# BT042_PD_TTCCGGTAGGGAGTTC-1                BT042_PD                ⋯
# BT042_PD_GAGGCCTCACAGACGA-1                BT042_PD                ⋯
# BT042_PD_ACACTGACATAATCCG-1                BT042_PD                ⋯
# BT042_PD_TTCACGCTCGAGTGAG-1                BT042_PD                ⋯
# BT042_PD_ATGAGTCCAATCGCAT-1                BT042_PD                ⋯
# BT042_PD_GGATGTTGTAGAGCTG-1                BT042_PD                ⋯
# BT042_PD_TGTGGCGTCTATACTC-1                BT042_PD                ⋯
# BT042_PD_AGCGCTGCATTGCAAC-1                BT042_PD                ⋯
# BT042_PD_TGACGCGCAAAGGGCT-1                BT042_PD                ⋯
# BT042_PD_AAGTCGTTCAATCGGT-1                BT042_PD                ⋯
# BT042_PD_CGGGTCACACGTGAGA-1                BT042_PD                ⋯
# BT042_PD_GTGTTCCTCATTGTTC-1                BT042_PD                ⋯
# BT042_PD_GCGATCGAGGTATAGT-1                BT042_PD                ⋯
# BT042_PD_CCTGTTGAGTGTTCAC-1                BT042_PD                ⋯
# BT042_PD_TACTTACCAAGTACCT-1                BT042_PD                ⋯
# BT042_PD_TTCAGGAGTAGTGTGG-1                BT042_PD                ⋯
# BT042_PD_AGGTGTTGTCGTCGGT-1                BT042_PD                ⋯
# BT042_PD_ACCTGTCGTCTGTGAT-1                BT042_PD                ⋯
# ⋮                                          ⋮                       ⋱
# multiome_P-6774_S-10146_TGCAAGCGTTAAGTGT-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_GGAGCGATCATAGCCG-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_TTGTCCATCCTTAGTT-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_TAGGAACCAAGGACCA-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_TCGGTTCTCTAAGTGC-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_CCGCTTAGTTAACACG-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_GAGTGTTTCTAGCGTG-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_GACTAATGTGTTGCTT-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_GGAGTGAGTAAACAAG-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_GTACTGGTCCGTGACA-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_CGAATCTAGTTTAACG-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_TTAGACTCATCATGTG-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_GCGGTTGGTGGATTAT-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_TTGGATTCACGTAAGG-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_TGAGGGCCAGGCATGA-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_GTGCGCAGTAAACAAG-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_GCCTCAAAGGATTGCT-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_ACTTAGTCACTAGGTC-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_TCAAGGAAGCGGATTT-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_TCAGCGATCCGTGACA-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_CGCTTACTCCGTTAAA-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_CTTTATCAGGAAGCTA-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_GGCTTCAAGTTATGGC-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_CCTGTTGGTGACCTGG-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_TACCGCAAGCGCCTTT-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_GAGTGATCAAGTGTTT-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_GGTCAGGAGTGCTGTG-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_TGGATTCAGACAAGTG-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_TCCAGGTCAATTGAAG-1 P-6774_S-10146_Multiome ⋯
# multiome_P-6774_S-10146_CTAGTAATCTAAGTGC-1 P-6774_S-10146_Multiome ⋯
#                                            predicted.annotation_level_4 iCNV
# BT042_PD_CCGTTCATCTATGTGG-1                NPC-like Prolif              normal
# BT042_PD_CTACCTGGTATGAAAC-1                NPC-like Prolif              normal
# BT042_PD_TTGCATTTCCTGTAGA-1                OPC                          normal
# BT042_PD_GTGCTGGGTAACGCGA-1                OPC                          normal
# BT042_PD_CTTCTAAAGACGCATG-1                OPC                          normal
# BT042_PD_CCTCACACAAAGCTAA-1                OPC-like                     normal
# BT042_PD_TGCGATAAGCCATCCG-1                TAM-BDM anti-infl            normal
# BT042_PD_GAATAGAGTTTATGCG-1                TAM-BDM anti-infl            normal
# BT042_PD_CCTGCATAGGTCACAG-1                TAM-BDM anti-infl            normal
# BT042_PD_CGGAGAACAACTGCTA-1                TAM-BDM anti-infl            normal
# BT042_PD_ACAAGCTGTGGCTAGA-1                OPC-like                     normal
# BT042_PD_AGGGCTCCAACTCGTA-1                TAM-BDM anti-infl            normal
# BT042_PD_TTCCGGTAGGGAGTTC-1                NPC-like Prolif              normal
# BT042_PD_GAGGCCTCACAGACGA-1                TAM-BDM anti-infl            normal
# BT042_PD_ACACTGACATAATCCG-1                TAM-BDM anti-infl            normal
# BT042_PD_TTCACGCTCGAGTGAG-1                TAM-BDM anti-infl            normal
# BT042_PD_ATGAGTCCAATCGCAT-1                TAM-BDM hypoxia/MES          normal
# BT042_PD_GGATGTTGTAGAGCTG-1                TAM-BDM anti-infl            normal
# BT042_PD_TGTGGCGTCTATACTC-1                TAM-BDM anti-infl            normal
# BT042_PD_AGCGCTGCATTGCAAC-1                TAM-BDM anti-infl            normal
# BT042_PD_TGACGCGCAAAGGGCT-1                TAM-BDM hypoxia/MES          normal
# BT042_PD_AAGTCGTTCAATCGGT-1                TAM-BDM anti-infl            normal
# BT042_PD_CGGGTCACACGTGAGA-1                TAM-BDM hypoxia/MES          normal
# BT042_PD_GTGTTCCTCATTGTTC-1                TAM-BDM anti-infl            normal
# BT042_PD_GCGATCGAGGTATAGT-1                TAM-BDM anti-infl            normal
# BT042_PD_CCTGTTGAGTGTTCAC-1                TAM-BDM anti-infl            normal
# BT042_PD_TACTTACCAAGTACCT-1                TAM-BDM hypoxia/MES          normal
# BT042_PD_TTCAGGAGTAGTGTGG-1                TAM-BDM hypoxia/MES          normal
# BT042_PD_AGGTGTTGTCGTCGGT-1                TAM-BDM anti-infl            normal
# BT042_PD_ACCTGTCGTCTGTGAT-1                TAM-BDM anti-infl            normal
# ⋮                                          ⋮                            ⋮
# multiome_P-6774_S-10146_TGCAAGCGTTAAGTGT-1 NPC-like OPC                 normal
# multiome_P-6774_S-10146_GGAGCGATCATAGCCG-1 NPC-like OPC                 tumor
# multiome_P-6774_S-10146_TTGTCCATCCTTAGTT-1 NPC-like OPC                 normal
# multiome_P-6774_S-10146_TAGGAACCAAGGACCA-1 NPC-like OPC                 normal
# multiome_P-6774_S-10146_TCGGTTCTCTAAGTGC-1 AC-like                      normal
# multiome_P-6774_S-10146_CCGCTTAGTTAACACG-1 TAM-BDM anti-infl            normal
# multiome_P-6774_S-10146_GAGTGTTTCTAGCGTG-1 TAM-BDM hypoxia/MES          normal
# multiome_P-6774_S-10146_GACTAATGTGTTGCTT-1 MES-like hypoxia/MHC         tumor
# multiome_P-6774_S-10146_GGAGTGAGTAAACAAG-1 NPC-like OPC                 tumor
# multiome_P-6774_S-10146_GTACTGGTCCGTGACA-1 AC-like                      normal
# multiome_P-6774_S-10146_CGAATCTAGTTTAACG-1 NPC-like OPC                 tumor
# multiome_P-6774_S-10146_TTAGACTCATCATGTG-1 AC-like                      normal
# multiome_P-6774_S-10146_GCGGTTGGTGGATTAT-1 TAM-BDM anti-infl            normal
# multiome_P-6774_S-10146_TTGGATTCACGTAAGG-1 TAM-BDM anti-infl            normal
# multiome_P-6774_S-10146_TGAGGGCCAGGCATGA-1 MES-like hypoxia/MHC         normal
# multiome_P-6774_S-10146_GTGCGCAGTAAACAAG-1 B cell                       normal
# multiome_P-6774_S-10146_GCCTCAAAGGATTGCT-1 NPC-like OPC                 tumor
# multiome_P-6774_S-10146_ACTTAGTCACTAGGTC-1 NPC-like OPC                 tumor
# multiome_P-6774_S-10146_TCAAGGAAGCGGATTT-1 MES-like hypoxia independent normal
# multiome_P-6774_S-10146_TCAGCGATCCGTGACA-1 NPC-like OPC                 tumor
# multiome_P-6774_S-10146_CGCTTACTCCGTTAAA-1 MES-like hypoxia independent normal
# multiome_P-6774_S-10146_CTTTATCAGGAAGCTA-1 AC-like                      normal
# multiome_P-6774_S-10146_GGCTTCAAGTTATGGC-1 B cell                       normal
# multiome_P-6774_S-10146_CCTGTTGGTGACCTGG-1 NPC-like OPC                 tumor
# multiome_P-6774_S-10146_TACCGCAAGCGCCTTT-1 TAM-MG aging sig             normal
# multiome_P-6774_S-10146_GAGTGATCAAGTGTTT-1 TAM-MG aging sig             normal
# multiome_P-6774_S-10146_GGTCAGGAGTGCTGTG-1 B cell                       normal
# multiome_P-6774_S-10146_TGGATTCAGACAAGTG-1 TAM-MG prolif                normal
# multiome_P-6774_S-10146_TCCAGGTCAATTGAAG-1 TAM-BDM hypoxia/MES          normal
# multiome_P-6774_S-10146_CTAGTAATCTAAGTGC-1 B cell                       normal
#                                            cell_id
# BT042_PD_CCGTTCATCTATGTGG-1                Stem_like_normal
# BT042_PD_CTACCTGGTATGAAAC-1                Stem_like_normal
# BT042_PD_TTGCATTTCCTGTAGA-1                Stem_like_normal
# BT042_PD_GTGCTGGGTAACGCGA-1                Stem_like_normal
# BT042_PD_CTTCTAAAGACGCATG-1                Stem_like_normal
# BT042_PD_CCTCACACAAAGCTAA-1                Stem_like_normal
# BT042_PD_TGCGATAAGCCATCCG-1                TAM_BDM
# BT042_PD_GAATAGAGTTTATGCG-1                TAM_BDM
# BT042_PD_CCTGCATAGGTCACAG-1                TAM_BDM
# BT042_PD_CGGAGAACAACTGCTA-1                TAM_BDM
# BT042_PD_ACAAGCTGTGGCTAGA-1                Stem_like_normal
# BT042_PD_AGGGCTCCAACTCGTA-1                TAM_BDM
# BT042_PD_TTCCGGTAGGGAGTTC-1                Stem_like_normal
# BT042_PD_GAGGCCTCACAGACGA-1                TAM_BDM
# BT042_PD_ACACTGACATAATCCG-1                TAM_BDM
# BT042_PD_TTCACGCTCGAGTGAG-1                TAM_BDM
# BT042_PD_ATGAGTCCAATCGCAT-1                TAM_BDM
# BT042_PD_GGATGTTGTAGAGCTG-1                TAM_BDM
# BT042_PD_TGTGGCGTCTATACTC-1                TAM_BDM
# BT042_PD_AGCGCTGCATTGCAAC-1                TAM_BDM
# BT042_PD_TGACGCGCAAAGGGCT-1                TAM_BDM
# BT042_PD_AAGTCGTTCAATCGGT-1                TAM_BDM
# BT042_PD_CGGGTCACACGTGAGA-1                TAM_BDM
# BT042_PD_GTGTTCCTCATTGTTC-1                TAM_BDM
# BT042_PD_GCGATCGAGGTATAGT-1                TAM_BDM
# BT042_PD_CCTGTTGAGTGTTCAC-1                TAM_BDM
# BT042_PD_TACTTACCAAGTACCT-1                TAM_BDM
# BT042_PD_TTCAGGAGTAGTGTGG-1                TAM_BDM
# BT042_PD_AGGTGTTGTCGTCGGT-1                TAM_BDM
# BT042_PD_ACCTGTCGTCTGTGAT-1                TAM_BDM
# ⋮                                          ⋮
# multiome_P-6774_S-10146_TGCAAGCGTTAAGTGT-1 Stem_like_normal
# multiome_P-6774_S-10146_GGAGCGATCATAGCCG-1 Stem_like_tumor
# multiome_P-6774_S-10146_TTGTCCATCCTTAGTT-1 Stem_like_normal
# multiome_P-6774_S-10146_TAGGAACCAAGGACCA-1 Stem_like_normal
# multiome_P-6774_S-10146_TCGGTTCTCTAAGTGC-1 Differentiated_like_normal
# multiome_P-6774_S-10146_CCGCTTAGTTAACACG-1 TAM_BDM
# multiome_P-6774_S-10146_GAGTGTTTCTAGCGTG-1 TAM_BDM
# multiome_P-6774_S-10146_GACTAATGTGTTGCTT-1 Differentiated_like_tumor
# multiome_P-6774_S-10146_GGAGTGAGTAAACAAG-1 Stem_like_tumor
# multiome_P-6774_S-10146_GTACTGGTCCGTGACA-1 Differentiated_like_normal
# multiome_P-6774_S-10146_CGAATCTAGTTTAACG-1 Stem_like_tumor
# multiome_P-6774_S-10146_TTAGACTCATCATGTG-1 Differentiated_like_normal
# multiome_P-6774_S-10146_GCGGTTGGTGGATTAT-1 TAM_BDM
# multiome_P-6774_S-10146_TTGGATTCACGTAAGG-1 TAM_BDM
# multiome_P-6774_S-10146_TGAGGGCCAGGCATGA-1 Differentiated_like_normal
# multiome_P-6774_S-10146_GTGCGCAGTAAACAAG-1 B_cell
# multiome_P-6774_S-10146_GCCTCAAAGGATTGCT-1 Stem_like_tumor
# multiome_P-6774_S-10146_ACTTAGTCACTAGGTC-1 Stem_like_tumor
# multiome_P-6774_S-10146_TCAAGGAAGCGGATTT-1 Differentiated_like_normal
# multiome_P-6774_S-10146_TCAGCGATCCGTGACA-1 Stem_like_tumor
# multiome_P-6774_S-10146_CGCTTACTCCGTTAAA-1 Differentiated_like_normal
# multiome_P-6774_S-10146_CTTTATCAGGAAGCTA-1 Differentiated_like_normal
# multiome_P-6774_S-10146_GGCTTCAAGTTATGGC-1 B_cell
# multiome_P-6774_S-10146_CCTGTTGGTGACCTGG-1 Stem_like_tumor
# multiome_P-6774_S-10146_TACCGCAAGCGCCTTT-1 TAM_MG
# multiome_P-6774_S-10146_GAGTGATCAAGTGTTT-1 TAM_MG
# multiome_P-6774_S-10146_GGTCAGGAGTGCTGTG-1 B_cell
# multiome_P-6774_S-10146_TGGATTCAGACAAGTG-1 TAM_MG
# multiome_P-6774_S-10146_TCCAGGTCAATTGAAG-1 TAM_BDM
# multiome_P-6774_S-10146_CTAGTAATCTAAGTGC-1 B_cell
#                                            lvl_0          lvl_1
# BT042_PD_CCGTTCATCTATGTGG-1                Neoplastic     Malignant
# BT042_PD_CTACCTGGTATGAAAC-1                Neoplastic     Malignant
# BT042_PD_TTGCATTTCCTGTAGA-1                Neoplastic     Malignant
# BT042_PD_GTGCTGGGTAACGCGA-1                Neoplastic     Malignant
# BT042_PD_CTTCTAAAGACGCATG-1                Neoplastic     Malignant
# BT042_PD_CCTCACACAAAGCTAA-1                Neoplastic     Malignant
# BT042_PD_TGCGATAAGCCATCCG-1                Non_neoplastic Immune
# BT042_PD_GAATAGAGTTTATGCG-1                Non_neoplastic Immune
# BT042_PD_CCTGCATAGGTCACAG-1                Non_neoplastic Immune
# BT042_PD_CGGAGAACAACTGCTA-1                Non_neoplastic Immune
# BT042_PD_ACAAGCTGTGGCTAGA-1                Neoplastic     Malignant
# BT042_PD_AGGGCTCCAACTCGTA-1                Non_neoplastic Immune
# BT042_PD_TTCCGGTAGGGAGTTC-1                Neoplastic     Malignant
# BT042_PD_GAGGCCTCACAGACGA-1                Non_neoplastic Immune
# BT042_PD_ACACTGACATAATCCG-1                Non_neoplastic Immune
# BT042_PD_TTCACGCTCGAGTGAG-1                Non_neoplastic Immune
# BT042_PD_ATGAGTCCAATCGCAT-1                Non_neoplastic Immune
# BT042_PD_GGATGTTGTAGAGCTG-1                Non_neoplastic Immune
# BT042_PD_TGTGGCGTCTATACTC-1                Non_neoplastic Immune
# BT042_PD_AGCGCTGCATTGCAAC-1                Non_neoplastic Immune
# BT042_PD_TGACGCGCAAAGGGCT-1                Non_neoplastic Immune
# BT042_PD_AAGTCGTTCAATCGGT-1                Non_neoplastic Immune
# BT042_PD_CGGGTCACACGTGAGA-1                Non_neoplastic Immune
# BT042_PD_GTGTTCCTCATTGTTC-1                Non_neoplastic Immune
# BT042_PD_GCGATCGAGGTATAGT-1                Non_neoplastic Immune
# BT042_PD_CCTGTTGAGTGTTCAC-1                Non_neoplastic Immune
# BT042_PD_TACTTACCAAGTACCT-1                Non_neoplastic Immune
# BT042_PD_TTCAGGAGTAGTGTGG-1                Non_neoplastic Immune
# BT042_PD_AGGTGTTGTCGTCGGT-1                Non_neoplastic Immune
# BT042_PD_ACCTGTCGTCTGTGAT-1                Non_neoplastic Immune
# ⋮                                          ⋮              ⋮
# multiome_P-6774_S-10146_TGCAAGCGTTAAGTGT-1 Neoplastic     Malignant
# multiome_P-6774_S-10146_GGAGCGATCATAGCCG-1 Neoplastic     Malignant
# multiome_P-6774_S-10146_TTGTCCATCCTTAGTT-1 Neoplastic     Malignant
# multiome_P-6774_S-10146_TAGGAACCAAGGACCA-1 Neoplastic     Malignant
# multiome_P-6774_S-10146_TCGGTTCTCTAAGTGC-1 Neoplastic     Malignant
# multiome_P-6774_S-10146_CCGCTTAGTTAACACG-1 Non_neoplastic Immune
# multiome_P-6774_S-10146_GAGTGTTTCTAGCGTG-1 Non_neoplastic Immune
# multiome_P-6774_S-10146_GACTAATGTGTTGCTT-1 Neoplastic     Malignant
# multiome_P-6774_S-10146_GGAGTGAGTAAACAAG-1 Neoplastic     Malignant
# multiome_P-6774_S-10146_GTACTGGTCCGTGACA-1 Neoplastic     Malignant
# multiome_P-6774_S-10146_CGAATCTAGTTTAACG-1 Neoplastic     Malignant
# multiome_P-6774_S-10146_TTAGACTCATCATGTG-1 Neoplastic     Malignant
# multiome_P-6774_S-10146_GCGGTTGGTGGATTAT-1 Non_neoplastic Immune
# multiome_P-6774_S-10146_TTGGATTCACGTAAGG-1 Non_neoplastic Immune
# multiome_P-6774_S-10146_TGAGGGCCAGGCATGA-1 Neoplastic     Malignant
# multiome_P-6774_S-10146_GTGCGCAGTAAACAAG-1 Non_neoplastic Immune
# multiome_P-6774_S-10146_GCCTCAAAGGATTGCT-1 Neoplastic     Malignant
# multiome_P-6774_S-10146_ACTTAGTCACTAGGTC-1 Neoplastic     Malignant
# multiome_P-6774_S-10146_TCAAGGAAGCGGATTT-1 Neoplastic     Malignant
# multiome_P-6774_S-10146_TCAGCGATCCGTGACA-1 Neoplastic     Malignant
# multiome_P-6774_S-10146_CGCTTACTCCGTTAAA-1 Neoplastic     Malignant
# multiome_P-6774_S-10146_CTTTATCAGGAAGCTA-1 Neoplastic     Malignant
# multiome_P-6774_S-10146_GGCTTCAAGTTATGGC-1 Non_neoplastic Immune
# multiome_P-6774_S-10146_CCTGTTGGTGACCTGG-1 Neoplastic     Malignant
# multiome_P-6774_S-10146_TACCGCAAGCGCCTTT-1 Non_neoplastic Immune
# multiome_P-6774_S-10146_GAGTGATCAAGTGTTT-1 Non_neoplastic Immune
# multiome_P-6774_S-10146_GGTCAGGAGTGCTGTG-1 Non_neoplastic Immune
# multiome_P-6774_S-10146_TGGATTCAGACAAGTG-1 Non_neoplastic Immune
# multiome_P-6774_S-10146_TCCAGGTCAATTGAAG-1 Non_neoplastic Immune
# multiome_P-6774_S-10146_CTAGTAATCTAAGTGC-1 Non_neoplastic Immune
#                                            lvl_2
# BT042_PD_CCGTTCATCTATGTGG-1                Stem_like
# BT042_PD_CTACCTGGTATGAAAC-1                Stem_like
# BT042_PD_TTGCATTTCCTGTAGA-1                Stem_like
# BT042_PD_GTGCTGGGTAACGCGA-1                Stem_like
# BT042_PD_CTTCTAAAGACGCATG-1                Stem_like
# BT042_PD_CCTCACACAAAGCTAA-1                Differentiated_like
# BT042_PD_TGCGATAAGCCATCCG-1                Myeloid
# BT042_PD_GAATAGAGTTTATGCG-1                Myeloid
# BT042_PD_CCTGCATAGGTCACAG-1                Myeloid
# BT042_PD_CGGAGAACAACTGCTA-1                Myeloid
# BT042_PD_ACAAGCTGTGGCTAGA-1                Differentiated_like
# BT042_PD_AGGGCTCCAACTCGTA-1                Myeloid
# BT042_PD_TTCCGGTAGGGAGTTC-1                Stem_like
# BT042_PD_GAGGCCTCACAGACGA-1                Myeloid
# BT042_PD_ACACTGACATAATCCG-1                Myeloid
# BT042_PD_TTCACGCTCGAGTGAG-1                Myeloid
# BT042_PD_ATGAGTCCAATCGCAT-1                Myeloid
# BT042_PD_GGATGTTGTAGAGCTG-1                Myeloid
# BT042_PD_TGTGGCGTCTATACTC-1                Myeloid
# BT042_PD_AGCGCTGCATTGCAAC-1                Myeloid
# BT042_PD_TGACGCGCAAAGGGCT-1                Myeloid
# BT042_PD_AAGTCGTTCAATCGGT-1                Myeloid
# BT042_PD_CGGGTCACACGTGAGA-1                Myeloid
# BT042_PD_GTGTTCCTCATTGTTC-1                Myeloid
# BT042_PD_GCGATCGAGGTATAGT-1                Myeloid
# BT042_PD_CCTGTTGAGTGTTCAC-1                Myeloid
# BT042_PD_TACTTACCAAGTACCT-1                Myeloid
# BT042_PD_TTCAGGAGTAGTGTGG-1                Myeloid
# BT042_PD_AGGTGTTGTCGTCGGT-1                Myeloid
# BT042_PD_ACCTGTCGTCTGTGAT-1                Myeloid
# ⋮                                          ⋮
# multiome_P-6774_S-10146_TGCAAGCGTTAAGTGT-1 Differentiated_like
# multiome_P-6774_S-10146_GGAGCGATCATAGCCG-1 Differentiated_like
# multiome_P-6774_S-10146_TTGTCCATCCTTAGTT-1 Differentiated_like
# multiome_P-6774_S-10146_TAGGAACCAAGGACCA-1 Differentiated_like
# multiome_P-6774_S-10146_TCGGTTCTCTAAGTGC-1 Differentiated_like
# multiome_P-6774_S-10146_CCGCTTAGTTAACACG-1 Myeloid
# multiome_P-6774_S-10146_GAGTGTTTCTAGCGTG-1 Myeloid
# multiome_P-6774_S-10146_GACTAATGTGTTGCTT-1 Differentiated_like
# multiome_P-6774_S-10146_GGAGTGAGTAAACAAG-1 Differentiated_like
# multiome_P-6774_S-10146_GTACTGGTCCGTGACA-1 Differentiated_like
# multiome_P-6774_S-10146_CGAATCTAGTTTAACG-1 Differentiated_like
# multiome_P-6774_S-10146_TTAGACTCATCATGTG-1 Differentiated_like
# multiome_P-6774_S-10146_GCGGTTGGTGGATTAT-1 Myeloid
# multiome_P-6774_S-10146_TTGGATTCACGTAAGG-1 Myeloid
# multiome_P-6774_S-10146_TGAGGGCCAGGCATGA-1 Differentiated_like
# multiome_P-6774_S-10146_GTGCGCAGTAAACAAG-1 Myeloid
# multiome_P-6774_S-10146_GCCTCAAAGGATTGCT-1 Differentiated_like
# multiome_P-6774_S-10146_ACTTAGTCACTAGGTC-1 Stem_like
# multiome_P-6774_S-10146_TCAAGGAAGCGGATTT-1 Differentiated_like
# multiome_P-6774_S-10146_TCAGCGATCCGTGACA-1 Differentiated_like
# multiome_P-6774_S-10146_CGCTTACTCCGTTAAA-1 Differentiated_like
# multiome_P-6774_S-10146_CTTTATCAGGAAGCTA-1 Differentiated_like
# multiome_P-6774_S-10146_GGCTTCAAGTTATGGC-1 Myeloid
# multiome_P-6774_S-10146_CCTGTTGGTGACCTGG-1 Differentiated_like
# multiome_P-6774_S-10146_TACCGCAAGCGCCTTT-1 Myeloid
# multiome_P-6774_S-10146_GAGTGATCAAGTGTTT-1 Myeloid
# multiome_P-6774_S-10146_GGTCAGGAGTGCTGTG-1 Myeloid
# multiome_P-6774_S-10146_TGGATTCAGACAAGTG-1 Myeloid
# multiome_P-6774_S-10146_TCCAGGTCAATTGAAG-1 Myeloid
# multiome_P-6774_S-10146_CTAGTAATCTAAGTGC-1 Myeloid
#                                            lvl_3
# BT042_PD_CCGTTCATCTATGTGG-1                Stem_intermediate
# BT042_PD_CTACCTGGTATGAAAC-1                Stem_intermediate
# BT042_PD_TTGCATTTCCTGTAGA-1                Stem_intermediate
# BT042_PD_GTGCTGGGTAACGCGA-1                Stem_intermediate
# BT042_PD_CTTCTAAAGACGCATG-1                Stem_intermediate
# BT042_PD_CCTCACACAAAGCTAA-1                Oligodendroglial_fate
# BT042_PD_TGCGATAAGCCATCCG-1                MDM
# BT042_PD_GAATAGAGTTTATGCG-1                MDM
# BT042_PD_CCTGCATAGGTCACAG-1                MDM
# BT042_PD_CGGAGAACAACTGCTA-1                MDM
# BT042_PD_ACAAGCTGTGGCTAGA-1                Oligodendroglial_fate
# BT042_PD_AGGGCTCCAACTCGTA-1                MDM
# BT042_PD_TTCCGGTAGGGAGTTC-1                Stem_intermediate
# BT042_PD_GAGGCCTCACAGACGA-1                MDM
# BT042_PD_ACACTGACATAATCCG-1                MDM
# BT042_PD_TTCACGCTCGAGTGAG-1                Monocyte
# BT042_PD_ATGAGTCCAATCGCAT-1                MDM
# BT042_PD_GGATGTTGTAGAGCTG-1                MDM
# BT042_PD_TGTGGCGTCTATACTC-1                MDM
# BT042_PD_AGCGCTGCATTGCAAC-1                Monocyte
# BT042_PD_TGACGCGCAAAGGGCT-1                MDM
# BT042_PD_AAGTCGTTCAATCGGT-1                Monocyte
# BT042_PD_CGGGTCACACGTGAGA-1                MDM
# BT042_PD_GTGTTCCTCATTGTTC-1                MDM
# BT042_PD_GCGATCGAGGTATAGT-1                MDM
# BT042_PD_CCTGTTGAGTGTTCAC-1                MDM
# BT042_PD_TACTTACCAAGTACCT-1                MDM
# BT042_PD_TTCAGGAGTAGTGTGG-1                MDM
# BT042_PD_AGGTGTTGTCGTCGGT-1                MDM
# BT042_PD_ACCTGTCGTCTGTGAT-1                Monocyte
# ⋮                                          ⋮
# multiome_P-6774_S-10146_TGCAAGCGTTAAGTGT-1 Astroglial_fate
# multiome_P-6774_S-10146_GGAGCGATCATAGCCG-1 Oligodendroglial_fate
# multiome_P-6774_S-10146_TTGTCCATCCTTAGTT-1 Astroglial_fate
# multiome_P-6774_S-10146_TAGGAACCAAGGACCA-1 Astroglial_fate
# multiome_P-6774_S-10146_TCGGTTCTCTAAGTGC-1 Astroglial_fate
# multiome_P-6774_S-10146_CCGCTTAGTTAACACG-1 MDM
# multiome_P-6774_S-10146_GAGTGTTTCTAGCGTG-1 Neutrophil
# multiome_P-6774_S-10146_GACTAATGTGTTGCTT-1 TME_induced
# multiome_P-6774_S-10146_GGAGTGAGTAAACAAG-1 TME_induced
# multiome_P-6774_S-10146_GTACTGGTCCGTGACA-1 Astroglial_fate
# multiome_P-6774_S-10146_CGAATCTAGTTTAACG-1 Astroglial_fate
# multiome_P-6774_S-10146_TTAGACTCATCATGTG-1 Astroglial_fate
# multiome_P-6774_S-10146_GCGGTTGGTGGATTAT-1 MDM
# multiome_P-6774_S-10146_TTGGATTCACGTAAGG-1 MDM
# multiome_P-6774_S-10146_TGAGGGCCAGGCATGA-1 TME_induced
# multiome_P-6774_S-10146_GTGCGCAGTAAACAAG-1 MDM
# multiome_P-6774_S-10146_GCCTCAAAGGATTGCT-1 Astroglial_fate
# multiome_P-6774_S-10146_ACTTAGTCACTAGGTC-1 Stem_primordial
# multiome_P-6774_S-10146_TCAAGGAAGCGGATTT-1 Astroglial_fate
# multiome_P-6774_S-10146_TCAGCGATCCGTGACA-1 Oligodendroglial_fate
# multiome_P-6774_S-10146_CGCTTACTCCGTTAAA-1 TME_induced
# multiome_P-6774_S-10146_CTTTATCAGGAAGCTA-1 TME_induced
# multiome_P-6774_S-10146_GGCTTCAAGTTATGGC-1 MDM
# multiome_P-6774_S-10146_CCTGTTGGTGACCTGG-1 Astroglial_fate
# multiome_P-6774_S-10146_TACCGCAAGCGCCTTT-1 MDM
# multiome_P-6774_S-10146_GAGTGATCAAGTGTTT-1 MDM
# multiome_P-6774_S-10146_GGTCAGGAGTGCTGTG-1 MDM
# multiome_P-6774_S-10146_TGGATTCAGACAAGTG-1 MDM
# multiome_P-6774_S-10146_TCCAGGTCAATTGAAG-1 MDM
# multiome_P-6774_S-10146_CTAGTAATCTAAGTGC-1 MDM
#                                            lvl_4
# BT042_PD_CCGTTCATCTATGTGG-1                OPC_like
# BT042_PD_CTACCTGGTATGAAAC-1                OPC_like
# BT042_PD_TTGCATTTCCTGTAGA-1                OPC_like
# BT042_PD_GTGCTGGGTAACGCGA-1                OPC_like
# BT042_PD_CTTCTAAAGACGCATG-1                OPC_like
# BT042_PD_CCTCACACAAAGCTAA-1                COP_like
# BT042_PD_TGCGATAAGCCATCCG-1                TAM_scavenger
# BT042_PD_GAATAGAGTTTATGCG-1                TAM_scavenger
# BT042_PD_CCTGCATAGGTCACAG-1                TAM_scavenger
# BT042_PD_CGGAGAACAACTGCTA-1                TAM_scavenger
# BT042_PD_ACAAGCTGTGGCTAGA-1                COP_like
# BT042_PD_AGGGCTCCAACTCGTA-1                TAM_scavenger
# BT042_PD_TTCCGGTAGGGAGTTC-1                OPC_like
# BT042_PD_GAGGCCTCACAGACGA-1                TAM_scavenger
# BT042_PD_ACACTGACATAATCCG-1                TAM_scavenger
# BT042_PD_TTCACGCTCGAGTGAG-1                Mono_neutrophil
# BT042_PD_ATGAGTCCAATCGCAT-1                TAM_C1Q
# BT042_PD_GGATGTTGTAGAGCTG-1                TAM_C1Q
# BT042_PD_TGTGGCGTCTATACTC-1                TAM_scavenger
# BT042_PD_AGCGCTGCATTGCAAC-1                Mono_neutrophil
# BT042_PD_TGACGCGCAAAGGGCT-1                TAM_lipid_laden
# BT042_PD_AAGTCGTTCAATCGGT-1                Mono_neutrophil
# BT042_PD_CGGGTCACACGTGAGA-1                TAM_scavenger
# BT042_PD_GTGTTCCTCATTGTTC-1                TAM_C1Q
# BT042_PD_GCGATCGAGGTATAGT-1                TAM_scavenger
# BT042_PD_CCTGTTGAGTGTTCAC-1                TAM_scavenger
# BT042_PD_TACTTACCAAGTACCT-1                TAM_lipid_laden
# BT042_PD_TTCAGGAGTAGTGTGG-1                TAM_scavenger
# BT042_PD_AGGTGTTGTCGTCGGT-1                TAM_scavenger
# BT042_PD_ACCTGTCGTCTGTGAT-1                Mono_neutrophil
# ⋮                                          ⋮
# multiome_P-6774_S-10146_TGCAAGCGTTAAGTGT-1 AC_like
# multiome_P-6774_S-10146_GGAGCGATCATAGCCG-1 COP_like
# multiome_P-6774_S-10146_TTGTCCATCCTTAGTT-1 AC_like
# multiome_P-6774_S-10146_TAGGAACCAAGGACCA-1 AC_like
# multiome_P-6774_S-10146_TCGGTTCTCTAAGTGC-1 AC_like
# multiome_P-6774_S-10146_CCGCTTAGTTAACACG-1 TAM_scavenger
# multiome_P-6774_S-10146_GAGTGTTTCTAGCGTG-1 Mono_neutrophil
# multiome_P-6774_S-10146_GACTAATGTGTTGCTT-1 TD_like
# multiome_P-6774_S-10146_GGAGTGAGTAAACAAG-1 TD_like
# multiome_P-6774_S-10146_GTACTGGTCCGTGACA-1 AC_like
# multiome_P-6774_S-10146_CGAATCTAGTTTAACG-1 AC_like
# multiome_P-6774_S-10146_TTAGACTCATCATGTG-1 AC_like
# multiome_P-6774_S-10146_GCGGTTGGTGGATTAT-1 TAM_lipid_laden
# multiome_P-6774_S-10146_TTGGATTCACGTAAGG-1 TAM_lipid_laden
# multiome_P-6774_S-10146_TGAGGGCCAGGCATGA-1 TD_like
# multiome_P-6774_S-10146_GTGCGCAGTAAACAAG-1 TAM_scavenger
# multiome_P-6774_S-10146_GCCTCAAAGGATTGCT-1 AC_like
# multiome_P-6774_S-10146_ACTTAGTCACTAGGTC-1 RG_like
# multiome_P-6774_S-10146_TCAAGGAAGCGGATTT-1 AC_like
# multiome_P-6774_S-10146_TCAGCGATCCGTGACA-1 COP_like
# multiome_P-6774_S-10146_CGCTTACTCCGTTAAA-1 GB_like
# multiome_P-6774_S-10146_CTTTATCAGGAAGCTA-1 GB_like
# multiome_P-6774_S-10146_GGCTTCAAGTTATGGC-1 TAM_scavenger
# multiome_P-6774_S-10146_CCTGTTGGTGACCTGG-1 AC_like
# multiome_P-6774_S-10146_TACCGCAAGCGCCTTT-1 TAM_scavenger
# multiome_P-6774_S-10146_GAGTGATCAAGTGTTT-1 TAM_scavenger
# multiome_P-6774_S-10146_GGTCAGGAGTGCTGTG-1 TAM_lipid_laden
# multiome_P-6774_S-10146_TGGATTCAGACAAGTG-1 TAM_lipid_laden
# multiome_P-6774_S-10146_TCCAGGTCAATTGAAG-1 TAM_lipid_laden
# multiome_P-6774_S-10146_CTAGTAATCTAAGTGC-1 TAM_scavenger
#                                            lvl_5                    Material
# BT042_PD_CCGTTCATCTATGTGG-1                OPC_like_proliferating   nuclei
# BT042_PD_CTACCTGGTATGAAAC-1                OPC_like_proliferating   nuclei
# BT042_PD_TTGCATTTCCTGTAGA-1                OPC_like_proliferating   nuclei
# BT042_PD_GTGCTGGGTAACGCGA-1                OPC_like                 nuclei
# BT042_PD_CTTCTAAAGACGCATG-1                OPC_like_proliferating   nuclei
# BT042_PD_CCTCACACAAAGCTAA-1                COP_like                 nuclei
# BT042_PD_TGCGATAAGCCATCCG-1                MDM_scavenger_stress     nuclei
# BT042_PD_GAATAGAGTTTATGCG-1                MDM_scavenger_stress     nuclei
# BT042_PD_CCTGCATAGGTCACAG-1                MDM_scavenger_stress     nuclei
# BT042_PD_CGGAGAACAACTGCTA-1                MDM_scavenger_stress     nuclei
# BT042_PD_ACAAGCTGTGGCTAGA-1                COP_like                 nuclei
# BT042_PD_AGGGCTCCAACTCGTA-1                MDM_scavenger_stress     nuclei
# BT042_PD_TTCCGGTAGGGAGTTC-1                OPC_like_proliferating   nuclei
# BT042_PD_GAGGCCTCACAGACGA-1                MDM_scavenger_stress     nuclei
# BT042_PD_ACACTGACATAATCCG-1                MDM_scavenger_stress     nuclei
# BT042_PD_TTCACGCTCGAGTGAG-1                Monocyte                 nuclei
# BT042_PD_ATGAGTCCAATCGCAT-1                MDM_C1Q                  nuclei
# BT042_PD_GGATGTTGTAGAGCTG-1                MDM_C1Q                  nuclei
# BT042_PD_TGTGGCGTCTATACTC-1                MDM_scavenger_stress     nuclei
# BT042_PD_AGCGCTGCATTGCAAC-1                Monocyte                 nuclei
# BT042_PD_TGACGCGCAAAGGGCT-1                MDM_lipid_metab_hypoxia  nuclei
# BT042_PD_AAGTCGTTCAATCGGT-1                Monocyte                 nuclei
# BT042_PD_CGGGTCACACGTGAGA-1                MDM_scavenger_stress     nuclei
# BT042_PD_GTGTTCCTCATTGTTC-1                MDM_C1Q                  nuclei
# BT042_PD_GCGATCGAGGTATAGT-1                MDM_scavenger_stress     nuclei
# BT042_PD_CCTGTTGAGTGTTCAC-1                MDM_scavenger_stress     nuclei
# BT042_PD_TACTTACCAAGTACCT-1                MDM_lipid_metab_hypoxia  nuclei
# BT042_PD_TTCAGGAGTAGTGTGG-1                MDM_scavenger_stress     nuclei
# BT042_PD_AGGTGTTGTCGTCGGT-1                MDM_scavenger_stress     nuclei
# BT042_PD_ACCTGTCGTCTGTGAT-1                Monocyte                 nuclei
# ⋮                                          ⋮                        ⋮
# multiome_P-6774_S-10146_TGCAAGCGTTAAGTGT-1 Astroglial_fate          nuclei
# multiome_P-6774_S-10146_GGAGCGATCATAGCCG-1 COP_like                 nuclei
# multiome_P-6774_S-10146_TTGTCCATCCTTAGTT-1 Astroglial_fate          nuclei
# multiome_P-6774_S-10146_TAGGAACCAAGGACCA-1 Astroglial_fate          nuclei
# multiome_P-6774_S-10146_TCGGTTCTCTAAGTGC-1 Astroglial_fate          nuclei
# multiome_P-6774_S-10146_CCGCTTAGTTAACACG-1 MDM_scavenger_stress     nuclei
# multiome_P-6774_S-10146_GAGTGTTTCTAGCGTG-1 Neutrophil               nuclei
# multiome_P-6774_S-10146_GACTAATGTGTTGCTT-1 Dedifferentiated_hypoxia nuclei
# multiome_P-6774_S-10146_GGAGTGAGTAAACAAG-1 Dedifferentiated         nuclei
# multiome_P-6774_S-10146_GTACTGGTCCGTGACA-1 Astroglial_fate          nuclei
# multiome_P-6774_S-10146_CGAATCTAGTTTAACG-1 Astroglial_fate          nuclei
# multiome_P-6774_S-10146_TTAGACTCATCATGTG-1 Astroglial_fate          nuclei
# multiome_P-6774_S-10146_GCGGTTGGTGGATTAT-1 MDM_lipid_metab_hypoxia  nuclei
# multiome_P-6774_S-10146_TTGGATTCACGTAAGG-1 MDM_lipid_metab_hypoxia  nuclei
# multiome_P-6774_S-10146_TGAGGGCCAGGCATGA-1 Dedifferentiated_hypoxia nuclei
# multiome_P-6774_S-10146_GTGCGCAGTAAACAAG-1 MDM_scavenger_stress     nuclei
# multiome_P-6774_S-10146_GCCTCAAAGGATTGCT-1 Astroglial_fate          nuclei
# multiome_P-6774_S-10146_ACTTAGTCACTAGGTC-1 RG_like                  nuclei
# multiome_P-6774_S-10146_TCAAGGAAGCGGATTT-1 Astroglial_fate          nuclei
# multiome_P-6774_S-10146_TCAGCGATCCGTGACA-1 COP_like                 nuclei
# multiome_P-6774_S-10146_CGCTTACTCCGTTAAA-1 GW_dedifferentiated      nuclei
# multiome_P-6774_S-10146_CTTTATCAGGAAGCTA-1 GW_dedifferentiated      nuclei
# multiome_P-6774_S-10146_GGCTTCAAGTTATGGC-1 MDM_scavenger_stress     nuclei
# multiome_P-6774_S-10146_CCTGTTGGTGACCTGG-1 Astroglial_fate          nuclei
# multiome_P-6774_S-10146_TACCGCAAGCGCCTTT-1 MDM_scavenger            nuclei
# multiome_P-6774_S-10146_GAGTGATCAAGTGTTT-1 MDM_scavenger_stress     nuclei
# multiome_P-6774_S-10146_GGTCAGGAGTGCTGTG-1 MDM_lipid_metab_hypoxia  nuclei
# multiome_P-6774_S-10146_TGGATTCAGACAAGTG-1 MDM_lipid_metab_hypoxia  nuclei
# multiome_P-6774_S-10146_TCCAGGTCAATTGAAG-1 MDM_lipid_metab_hypoxia  nuclei
# multiome_P-6774_S-10146_CTAGTAATCTAAGTGC-1 MDM_scavenger_stress     nuclei

# %%
library("data.table")
library("tidyverse")
library("ggpubr")
library("magrittr")
library("lme4")
library("numDeriv")
library("scales")
library("stringr")
# Out:
# ── Attaching core tidyverse packages ─────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ forcats   1.0.0     ✔ purrr     1.0.2
# ✔ lubridate 1.9.3     ✔ readr     2.1.5
# ── Conflicts ───────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ data.table::between() masks dplyr::between()
# ✖ readr::col_factor()   masks scales::col_factor()
# ✖ purrr::discard()      masks scales::discard()
# ✖ Matrix::expand()      masks tidyr::expand()
# ✖ dplyr::filter()       masks stats::filter()
# ✖ data.table::first()   masks dplyr::first()
# ✖ lubridate::hour()     masks data.table::hour()
# ✖ lubridate::isoweek()  masks data.table::isoweek()
# ✖ dplyr::lag()          masks stats::lag()
# ✖ data.table::last()    masks dplyr::last()
# ✖ lubridate::mday()     masks data.table::mday()
# ✖ lubridate::minute()   masks data.table::minute()
# ✖ lubridate::month()    masks data.table::month()
# ✖ Matrix::pack()        masks tidyr::pack()
# ✖ lubridate::quarter()  masks data.table::quarter()
# ✖ lubridate::second()   masks data.table::second()
# ✖ purrr::transpose()    masks data.table::transpose()
# ✖ Matrix::unpack()      masks tidyr::unpack()
# ✖ lubridate::wday()     masks data.table::wday()
# ✖ lubridate::week()     masks data.table::week()
# ✖ lubridate::yday()     masks data.table::yday()
# ✖ lubridate::year()     masks data.table::year()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘magrittr’
#
#
# The following object is masked from ‘package:purrr’:
#
#     set_names
#
#
# The following object is masked from ‘package:tidyr’:
#
#     extract

# %%
# Method and initial implementation by Natsuhiko Kumasaka (natsuhiko@github)
# refactored and maintained by Ni Huang (nh3@github)

#' Make cell type by sample count matrix
#'
#' This function makes cell type by sample count matrix from a cell level annotation table
#'
#' @param obs_tbl Cell level annotation table, such as AnnData.obs (data.frame-like object)
#' @param colSample Column in "obs_tbl" specifying sample ID (str)
#' @param colCelltype Column in "obs_tbl" specifying cell type annotation (str)
#'
#' @return matrix containing cell type counts of dimension nSample x nCelltype
#'
#' @import magrittr
.make_count_matrix <- function(obs_tbl, colSample, colCelltype) {
  cnt_mat <- table(obs_tbl[[colSample]], obs_tbl[[colCelltype]]) %>% as.matrix()
  cnt_mat
}

#' Make sample level metadata table
#'
#' This function makes sample level metadata table from a cell level annotation table
#'
#' @param obs_tbl Cell level annotation table, such as AnnData.obs (data.frame-like object)
#' @param colSample Column in "obs_tbl" specifying sample ID (str)
#' @param colVarCats Columns in "obs_tbl" specifying categorical variables to control for (vector of str)
#' @param colVarNums Columns in "obs_tbl" specifying numerical variables to control for (vector of str)
#' @param extra_term Extra term(s) to be added to the model (str or vector of str)
#'
#' @return tibble containing metadata for each sample, one per row
#'
#' @import dplyr
.make_sample_metadata <- function(obs_tbl, colSample, colVarCats = c(), colVarNums = c(), extra_term = NULL) {
  if (!is.null(extra_term)) {
    extra_vars <- unique(unlist(strsplit(extra_term, ":", fixed = T)))
    extra_vars <- extra_vars[extra_vars %in% colnames(obs_tbl)]
  } else {
    extra_vars <- c()
  }
  metadata_tbl <- obs_tbl %>%
    select(one_of(unique(c(colSample, colVarCats, colVarNums, extra_vars)))) %>%
    unique()
  metadata_tbl
}

#' Make input data for model fitting
#'
#' This function makes input data for model fitting by assembling sample level
#' metadata and cell type by sample count matrix
#'
#' @param Y Cell type by sample count matrix (matrix of dimension nSample x nCelltype)
#' @param metadata_tbl Sample level metadata table (data.frame-like object)
#'
#' @return tibble containing counts and metadata for each cell type in each sample
#'
#' @import tibble
#' @import dplyr
.make_input_for_glmer <- function(Y, metadata_tbl, colSample) {
  samples <- rownames(Y)
  celltypes <- colnames(Y)
  nSample <- length(samples)
  nCelltype <- length(celltypes)

  metadata_tbl <- metadata_tbl[match(samples, metadata_tbl[[colSample]]), ]

  input_tbl <- bind_cols(
    metadata_tbl[rep(1:nSample, nCelltype), ],
    enframe(factor(rep(celltypes, rep(nSample, nCelltype))), name = NULL, value = "Celltype")
  )

  input_tbl$Y <- as.vector(Y)
  cat("input prepared\n")

  input_tbl
}

#' Make model formula
#'
#' This function makes a formula for a GLMM with random effects for each
#' specified categorical variables and interactions between each variable and
#' cell type
#'
#' @param colSample Column in "obs_tbl" specifying sample ID (str)
#' @param colVarCats Columns in "obs_tbl" specifying categorical variables to control for (vector of str)
#' @param colVarNums Columns in "obs_tbl" specifying numerical variables to control for (vector of str)
#' @param extra_term Extra term(s) to be added to the model (str or vector of str)
#'
#' @return formula specifying a GLMM model
.make_formula <- function(colSample, colCelltype, colVarCats, colVarNums, extra_term = NULL) {
  if (!is.null(extra_term)) {
    extra_vars <- unique(unlist(strsplit(extra_term, ":", fixed = T)))
    extra_vars[extra_vars == colCelltype] <- "Celltype"
    extra_term <- sprintf("(1|%s)", paste(extra_vars, collapse = ":"))
  }
  terms <- c(
    colVarNums,
    sprintf("(1|%s)", c(colSample, colVarCats)),
    sprintf("(%s-1|Celltype)", colVarNums),
    sprintf("(1|%s:Celltype)", c(colSample, colVarCats))
  )
  formula_str <- paste(c("I(Y) ~ (1|Celltype)", terms, extra_term), collapse = "+")
  cat(paste0(formula_str, "\n"))
  as.formula(formula_str)
}

#' Get mean estimate of random effects and LTSR values for all specified variables
#'
#' This function extracts random effect estimates (mean and sd) of specified
#' variables, calculates LTSR using a z-score test and prepare categories in
#' specified orders for plotting
#'
#' @param ranef_tbl Table of random effect estimates (mean and sd) extracted from fitted model
#'     (data.frame-like object)
#' @param vars A list specifying required categorical sample metadata variables and their order,
#'     e.g. list(size=c('small', 'medium', 'big'), price=c('cheap', 'expensive'))
#' @param celltypes If specified, only keep those cell types (vector of str)
#' @param references If specified, fold changes are calculated relative to the specified level
#'     instead of global mean. Must be a list, e.g. list(size='small', price='cheap')
#'
#' @return tibble containing mean random effects and respective LTSR
#'
#' @import dplyr
#' @import tidyr
#' @import stringr
.getCondValLtsr <- function(ranef_tbl, vars, celltypes = NULL, references = NULL) {
  if (!is.list(vars)) stop('"vars" must be a list of which names are co-variables to plot', call. = F)
  if (!is.null(references) && !is.list(references)) stop('"references" must be a list of which names match that of "vars"', call. = F)

  cat_ranef_tbl <- ranef_tbl %>%
    filter(
      grepl(":Celltype$", grpvar)
    ) %>%
    mutate(
      grpvar = factor(sub(":Celltype$", "", grpvar)),
      grp = factor(ifelse(
        grepl(":.*:", grp),
        sapply(str_split(grp, ":"), function(x) paste(paste(x[-length(x)], collapse = ","), x[length(x)], sep = ":")),
        as.character(grp)
      ))
    ) %>%
    separate(
      grp,
      into = c("grpval", "Celltype"), sep = ":"
    )

  num_ranef_tbl <- ranef_tbl %>%
    filter(
      grpvar == "Celltype" & term != "(Intercept)"
    ) %>%
    mutate(
      grpvar = factor(term),
      grpval= paste("Slope",term, sep = "-"),
      Celltype = grp
    ) %>%
    select (
      -grp
    )

  if (!is.null(references)) {
    cat_ranef_tbl <- bind_rows(
      lapply(names(vars), function(vname) {
        if (vname %in% names(references)) {
          ref <- references[[vname]]
          full_join(
            cat_ranef_tbl %>% filter(grpvar == vname, grpval != ref),
            cat_ranef_tbl %>% filter(grpvar == vname, grpval == ref) %>% select(grpvar, Celltype, condval, condsd),
            by = c("grpvar", "Celltype")
          ) %>%
            mutate(
              condval = condval.x - condval.y,
              condsd = sqrt(condsd.x^2 + condsd.y^2)
            ) %>%
            select(-condval.x, -condval.y, -condsd.x, -condsd.y)
        } else {
          return(cat_ranef_tbl %>% filter(grpvar == vname))
        }
      })
    )
  }

  ranef_tbl <- bind_rows(cat_ranef_tbl, num_ranef_tbl)

  ranef_tbl <- ranef_tbl %>%
    mutate(
      lfsr = pnorm(condval, 0, condsd)
    ) %>%
    mutate(
      lfsr = ifelse(lfsr > 0.5, 1 - lfsr, lfsr)
    ) %>%
    mutate(
      ltsr = 1 - lfsr
    ) %>%
    select(
      grpvar, grpval, Celltype, condval, ltsr
    )

  if (!is.null(celltypes)) ranef_tbl <- ranef_tbl %>% filter(Celltype %in% celltypes)

  ranef_tbl <- ranef_tbl %>%
    filter(
      grpvar %in% names(vars)
    ) %>%
    mutate(
      grpvar = factor(grpvar, levels = names(vars)),
      grpval = factor(grpval, levels = unlist(vars, use.names = F))
    )

  ranef_tbl
}

#' Cell type composition analysis
#'
#' This function performs cell type composition analysis across samples grouped by certain metadata
#' variable while controling for other variables, by fitting a Poisson Generalised Linear Mixed
#' Model
#'
#' @param obs_tbl Cell level annotation table, such as AnnData.obs (data.frame-like object)
#' @param colSample Column in "obs_tbl" specifying sample ID (str)
#' @param colCelltype Column in "obs_tbl" specifying cell type annotation (str)
#' @param colVarCats Columns in "obs_tbl" specifying categorical variables to control for (vector of str)
#' @param colVarNums Columns in "obs_tbl" specifying numerical variables to control for (vector of str)
#' @param extra_term Extra term(s) to be added to the model (str or vector of str)
#' @param save If specified, used as file name prefix to save returned values (str)
#'
#' @return list containing two tables, 1) estimated random effects, 2) estimated explained variance
#'     (in the form of standard deviation)
#'
#' @import tibble
#' @import dplyr
#' @import tidyr
#' @import lme4
#' @import numDeriv
#'
#' @export
CellTypeCompositionAnalysis <- function(obs_tbl, colSample, colCelltype, colVarCats, colVarNums = NULL, extra_term = NULL, save = NULL) {
  metadata_tbl <- .make_sample_metadata(obs_tbl, colSample, colVarCats, colVarNums, extra_term = extra_term)
  Y <- .make_count_matrix(obs_tbl, colSample, colCelltype)

  input_tbl <- .make_input_for_glmer(Y, metadata_tbl, colSample)

  f <- .make_formula(colSample, colCelltype, colVarCats, colVarNums, extra_term = extra_term)
  cat("model constructed\n")
  res.prop <- glmer(
    f,
    data = input_tbl, family = poisson,
    control = glmerControl(optimizer = "bobyqa", optCtrl = list(maxfun = 2e5))
  )
  cat("model fitted\n")

  # standard errors of standard deviations (squre root of the variance parameters)
  devfun <- update(res.prop, devFunOnly = T)
  pars <- getME(res.prop, c("theta", "fixef"))
  hess <- hessian(devfun, unlist(pars))
  sdse.prop <- data.frame(sd = unlist(pars), se = sqrt(diag(solve(hess))))
  sdse_tbl <- sdse.prop %>%
    rownames_to_column() %>%
    as_tibble()
  # posterior means and their standard deviations
  res.prop.ranef <- ranef(res.prop)
  ranef_tbl <- data.frame(res.prop.ranef) %>% as_tibble()

  if (is.character(save)) {
    output_dir <- ifelse(grepl("[/]$", save), save, dirname(save))
    if (!dir.exists(output_dir)) dir.create(output_dir, recursive = T)
    output_sep <- ifelse(grepl("[/.]$", save), "", ".")
    write_tsv(ranef_tbl, paste(save, "ranef.tsv", sep = output_sep))
    write_tsv(sdse_tbl, paste(save, "sdse.tsv", sep = output_sep))
  }

  list(ranef = ranef_tbl, sdse = sdse_tbl)
}

#' Plot variable explained variance
#'
#' This function plots (square root of) variance explained by variables as a forest plot
#'
#' @param sdse_tbl Table containing square-root of estimated explained variance and standard errors
#'     (data.frame-like object)
#' @param colSample Column in "obs_tbl" specifying sample ID (str)
#' @param ci Confidence interval level (numeric between 0 and 1, default 0.95)
#'
#' @return ggplot object of a forest plot
#'
#' @import dplyr
#' @import ggplot2
#'
#' @export
plot_sdse <- function(sdse_tbl, colSample, ci = 0.95, xlim = c(-0.5, 1.5)) {
  n_se <- qnorm(1 - (1 - ci) / 2)
  p_tbl <- sdse_tbl %>%
    filter(
      grepl(":Celltype.\\(Intercept\\)", rowname)
    ) %>%
    mutate(
      rowname = sub(paste0("^", colSample, "$"), "Residual", sub("theta.(.*):Celltype.*", "\\1", rowname))
    ) %>%
    arrange(sd) %>%
    mutate(
      rowname = factor(rowname, levels = c("Residual", rowname[rowname != "Residual"]))
    ) %>%
    mutate(ci_l = sd - se * n_se, ci_h = sd + se * n_se)
  p <- (
    ggplot(p_tbl, aes(x = sd, y = rowname)) +
      geom_point(shape = 18, size = 3) +
      geom_errorbarh(aes(xmin = ci_l, xmax = ci_h), height = 0) +
      geom_vline(xintercept = 0, lty = 2) +
      xlab("Square root of explained variance") +
      coord_cartesian(xlim = xlim) +
      theme_bw() +
      theme(axis.title.y = element_blank())
  )
}

#' Plot estimated random effects of variables
#'
#' This function plots random effects of variables on cell type composition as a dot plot
#'
#' @param ranef_tbl Table of random effect estimates (mean and sd) extracted from fitted model
#'     (data.frame-like object)
#' @param vars A list specifying required categorical sample metadata variables and their order,
#'     e.g. list(size=c('small', 'medium', 'big'), price=c('cheap', 'expensive'))
#' @param celltypes If specified, only keep those cell types (vector of str)
#' @param celltype_order Determine how cell types are ordered. Either "hclust" which orders by
#'     hierarchical clustering, or a vector of cell types. (str or vector of str)
#' @param references If specified, fold changes are calculated relative to the specified level
#'     instead of global mean. Must be a list, e.g. list(size='small', price='cheap')
#' @param maxFC Cap fold change by this value (numeric, default 3)
#' @param LTSR2p Whether to convert LTSR to p value (logical, default FALSE)
#' @param filterLtsr Only keeps cell types of which at least one LTSR is greater or equal to
#'     specified value. (numeric, default 0)
#' @param swap_axes Whether to swap axis when plotting (logical, default FALSE)
#'
#' @return ggplot object of a dot plot
#'
#' @import dplyr
#' @import ggplot2
#' @importFrom scales squish
#'
#' @export
plot_ranef <- function(ranef_tbl, vars, celltypes = NULL, celltype_order = "hclust", references = NULL,
                       maxFC = 3, LTSR2p = F, highlightLtsr = 0.0, filterLtsr = 0.0, swap_axes = F) {
  ranef_tbl <- .getCondValLtsr(ranef_tbl, vars, celltypes = celltypes, references = references)

  condval_mat <- ranef_tbl %>%
    select(
      Celltype, grpval, condval
    ) %>%
    spread(
      "grpval", "condval"
    ) %>%
    column_to_rownames(
      var = "Celltype"
    ) %>%
    as.matrix()
  if (length(celltype_order) == 1 && celltype_order == "hclust") {
    dendy <- hclust(dist(condval_mat))
    ordered_celltype <- rownames(condval_mat)[dendy$ord]
  } else if (!is.null(celltype_order) && length(celltype_order) == dim(condval_mat)[1]) {
    ordered_celltype <- celltype_order
  }

  ranef_tbl <- ranef_tbl %>% mutate(
    Celltype = factor(Celltype, levels = ordered_celltype),
    condval = condval %>% pmin(log(maxFC)) %>% pmax(log(1 / maxFC)),
    ltsr = ltsr %>% pmin(0.9999) %>% pmax(0.5)
  )

  if (swap_axes) {
    ranef_tbl$Celltype <- factor(ranef_tbl$Celltype, levels = rev(levels(ranef_tbl$Celltype)))
    ranef_tbl$grpval <- factor(ranef_tbl$grpval, levels = rev(levels(ranef_tbl$grpval)))
  }

  if (filterLtsr > 0) {
    filtered_celltypes <- ranef_tbl %>%
      group_by(Celltype) %>%
      summarise(maxLtsr = max(ltsr)) %>%
      dplyr::filter(maxLtsr >= filterLtsr) %>%
      select(Celltype) %>%
      unlist(use.names = F)
    ranef_tbl <- ranef_tbl %>% dplyr::filter(Celltype %in% filtered_celltypes)
  }

  geom_dots <- geom_point(
    aes(
      fill = log2(exp(condval)),
      size = -log10(1 - ltsr)
    ),
    color = "white",
    shape = 21
  )

  if (swap_axes) {
    p <- (
      ggplot(ranef_tbl, aes(y = grpval, x = Celltype)) +
        facet_grid(grpvar ~ ., scales = "free_y", space = "free_y", switch = "x") +
        geom_dots
    )
  } else {
    p <- (
      ggplot(ranef_tbl, aes(x = grpval, y = Celltype)) +
        facet_grid(. ~ grpvar, scales = "free_x", space = "free_x", switch = "x") +
        geom_dots
    )
  }

  p <- (
    p + scale_fill_distiller(
      palette = "RdBu",
      limits = log2(c(1 / maxFC, maxFC)),
      breaks = log2(c(1 / maxFC, maxFC)),
      labels = c(paste0("1/", maxFC), maxFC),
      oob = squish,
      guide = guide_colorbar(
        title = "Fold change", title.position = "top", direction = "horizontal",
        barwidth = 5, barheight = 0.75, raster = F, order = 1)
    )
    + scale_size(
      limits = -log10(1 - c(0.5, 0.9999)),
      breaks = -log10(1 - c(0.5, 0.9, 0.99, 0.999, 0.9999)),
      range = c(0.5, 9),
      labels = ifelse(
        rep(LTSR2p, 5),
        c("0.5", "0.1", "0.01", "0.001", "<0.0001"),
        c("0.5", "0.9", "0.99", "0.999", ">0.9999")
      ),
      guide = guide_legend(
        title = ifelse(LTSR2p, "p", "LTSR"), reverse = T, order = 2,
        override.aes = list(fill = "black", color = "white")
      )
    )
    + theme_bw()
    + theme(
      axis.title.x = element_blank(),
      axis.title.y = element_blank(),
      strip.placement = "outside",
      strip.background = element_blank(),
      legend.spacing.y = unit(0.5, "line")
    )
  )

  if (highlightLtsr > 0) {
    p <- (
      p + geom_point(
        aes(
          color = ltsr > highlightLtsr,
          alpha = ltsr > highlightLtsr
        ),
        shape = 21, size = 9
      )
      + scale_color_manual(
        label = c(
          "", ifelse(LTSR2p, paste0("p < ", 1 - highlightLtsr), paste0("LTSR > ", highlightLtsr))
        ),
        values = c("white", "red"),
        guide = guide_legend(title = NULL, override.aes = list(size = 9), reverse = T, order = 3)
      )
      + scale_alpha_manual(values = c(0, 1), guide = F)
    )
  }

  p
}

#' Theme that mimics dotplots generated by Natsuhiko's code
#'
#' This function sets a number of options in ggplot2::theme() to mimic the style
#' of dotplots generated by Natsuhiko's code
#'
#' @param ... options passed to ggplot2::theme()
#'
#' @importFrom ggplot2 theme
#'
#' @export
theme_ctca <- function(...) {
  theme(
    axis.text.x = element_text(angle = 45, hjust = 1),
    axis.ticks = element_blank(),
    strip.text = element_blank(),
    panel.grid = element_blank(),
    panel.border = element_blank(),
    ...
  )
}

# %%
meta$Age_years <- as.numeric(meta$Age_years) 
# Create age groups
age_groups <- cut(meta$Age_years,
                  breaks = c(0, 4, 9, 15, 21),
                  labels = c("0-4", "5-9", "10-15", "16-21"),
                  right = TRUE, include.lowest = TRUE)

# Add the age groups as a new column to the Seurat object metadata
meta$Age_Groups <- age_groups

# %%
ltsr <- CellTypeCompositionAnalysis(obs_tbl=meta, 
                            colSample='ID', 
                            colCelltype='lvl_4', 
                            colVarCats=c('Clinical_status','Tumor_type','Tumor_subtype','Gender','Location','Dexamethasone_prior_surgery', 'Age_Groups', 'Material'))
# Out:
# input prepared
# I(Y) ~ (1|Celltype)+(1|ID)+(1|Clinical_status)+(1|Tumor_type)+(1|Tumor_subtype)+(1|Gender)+(1|Location)+(1|Dexamethasone_prior_surgery)+(1|Age_Groups)+(1|Material)+(1|ID:Celltype)+(1|Clinical_status:Celltype)+(1|Tumor_type:Celltype)+(1|Tumor_subtype:Celltype)+(1|Gender:Celltype)+(1|Location:Celltype)+(1|Dexamethasone_prior_surgery:Celltype)+(1|Age_Groups:Celltype)+(1|Material:Celltype)
# model constructed
# boundary (singular) fit: see help('isSingular')
# model fitted
# Warning message in sqrt(diag(solve(hess))):
# “NaNs produced”

# %%
p <- plot_sdse(ltsr$sdse, 'ID')
p
# Out:
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_errorbarh()`).”
# plot without title

# %%
library(ggplot2)
library(dplyr)

plot_sdse2 <- function(sdse_tbl, colSample, ci = 0.95, xlim = c(-0.5, 1.5)) {
  n_se <- qnorm(1 - (1 - ci) / 2)

  p_tbl <- sdse_tbl %>%
    filter(grepl(":Celltype.\\(Intercept\\)", rowname)) %>%
    mutate(
      rowname_clean = sub("theta.(.*):Celltype.*", "\\1", rowname),
      rowname_clean = ifelse(rowname_clean == colSample, "Residual", rowname_clean)
    ) %>%
    arrange(sd) %>%
    mutate(
      rowname_clean = factor(rowname_clean, levels = c("Residual", unique(rowname_clean[rowname_clean != "Residual"]))),
      ci_l = sd - se * n_se,
      ci_h = sd + se * n_se
    )

  ggplot(p_tbl, aes(x = sd, y = rowname_clean)) +
    geom_point(shape = 18, size = 5, color = "#0072B2") +
    geom_errorbarh(aes(xmin = ci_l, xmax = ci_h), height = 0.2, color = "#0072B2") +
    geom_vline(xintercept = 0, linetype = "dashed", color = "gray50") +
    scale_x_continuous(limits = xlim, expand = c(0.01, 0.01)) +
    labs(
      x = "Square root of explained variance",
      y = NULL
    ) +
    theme_minimal(base_size = 12) +
    theme(
      axis.text.y = element_text(size = 11),
      axis.text.x = element_text(size = 11),
      panel.grid.major.y = element_line(color = "gray90"),
      panel.grid.minor = element_blank()
    )
}

 plot_sdse2(ltsr$sdse, 'ID')
# Out:
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_point()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range (`geom_errorbarh()`).”
# plot without title
