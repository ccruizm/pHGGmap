# %%
source("/projects/0/einf2548/cruiz/dmg/notebooks/nmf/scripts/utils_plotting_Ruiz_Sussman.R")
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.3.3”
# ── Attaching core tidyverse packages ──────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ forcats   1.0.0     ✔ readr     2.1.5
# ✔ ggplot2   3.5.1     ✔ stringr   1.5.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter()   masks stats::filter()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ readr::read_csv() masks anndata::read_csv()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘cowplot’
#
#
# The following object is masked from ‘package:lubridate’:
#
#     stamp
#
#
# Loading required package: grid
#
# ========================================
# ComplexHeatmap version 2.15.4
# Bioconductor page: http://bioconductor.org/packages/ComplexHeatmap/
# Github page: https://github.com/jokergoo/ComplexHeatmap
# Documentation: http://jokergoo.github.io/ComplexHeatmap-reference
#
# If you use it in published research, please cite either one:
# - Gu, Z. Complex Heatmap Visualization. iMeta 2022.
# - Gu, Z. Complex heatmaps reveal patterns and correlations in multidimensional
#     genomic data. Bioinformatics 2016.
#
#
# The new InteractiveComplexHeatmap package can directly export static
# complex heatmaps into an interactive Shiny app with zero effort. Have a try!
#
# This message can be suppressed by:
#   suppressPackageStartupMessages(library(ComplexHeatmap))
# ========================================
#
#
#
# Attaching package: ‘patchwork’
#
#
# The following object is masked from ‘package:cowplot’:
#
#     align_plots
#
#
# Warning message:
# “no DISPLAY variable so Tk is not available”

# %%
source("/projects/0/einf2548/cruiz/dmg/notebooks/nmf/scripts/utils.R")

# %%
options(repr.plot.height = 7, repr.plot.width = 7)
plot.landscape(data$uns$trajectories$palantir$branch.probs %>% py_to_r %>% mutate(diff=h3k27m-h3wt) %>% dplyr::select(diff),
               embedding = 'X_all_3d_phate',
               smoothened = F,
               size = 10,
               cols = green2purple.less.white,
               legend.position = c(3,3))
# Out:
# plot without title

# %%
ggsave('/projects/0/einf2548/cruiz/dmg/data/beyond/figures/phate_communities_Ruiz_Sussman.pdf', height = 7, width = )
# Out:
# Saving 6.67 x 7 in image

# %%
# Local similarities of participants based on cellular environments
data$obsp <- list()
for(e in c("X_all_3d_phate","X_umap","X_tsne")) 
  data$obsp[[paste0("similarity_", e)]] <- embedding.similarity(data$obsm[[e]], knn = 5)

# %%
plot.landscape(c('rg.2','gb.5','tri.1','ipc.4','opc.0','cop.1','ac.6','cilia.7','gw.2','td.3',
                 'neumono.1','c1q.2','lipid.3','scav.0','homeo.4','il1b.5'), 
               embedding = 'X_all_3d_phate',
               enforce.same.color.scale = FALSE, smoothened = TRUE, ncol=4)
# Out:
# plot without title

# %%
plot.landscape(c('rg.2','gb.5','tri.1','ipc.4','opc.0','cop.1','ac.6','cilia.7','gw.2','td.3',
                 'neumono.1','c1q.2','lipid.3','scav.0','homeo.4','il1b.5'), 
               embedding = 'X_all_3d_phate',size=10,
               enforce.same.color.scale = FALSE, smoothened = TRUE, ncol=4)
# Out:
# plot without title

# %%
ggsave('/projects/0/einf2548/cruiz/dmg/data/beyond/figures/phate_communities_per_celltype_Ruiz_Sussman.pdf', 
      height=20, width=20)
